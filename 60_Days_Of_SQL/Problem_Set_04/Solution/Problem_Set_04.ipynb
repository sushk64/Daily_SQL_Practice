# %%
#importing all the libraries
import pandas as pd
import sqlite3

#installing ipython-sql library 
# !pip install ipython-sql

# %%
df = pd.read_csv(r'/Users/sushantkumbhar/Documents/Stevens Academics/Skills Imporvement/SQL/SQL practice/Day_04_Practice/Dataset_04.csv')

cnn = sqlite3.connect('Problem_set_04.db')

df.to_sql('employee',cnn)

# %load_ext sql

# %sql sqlite:///Problem_set_04.db

# %%
# %%sql
#
# SELECT * FROM employee
# LIMIT 5;
# Out:
#  * sqlite:///Problem_set_04.db
# Done.
# [(0, 330, 'Rose', 5, 2248),
#  (1, 330, 'Rose', 5, 2248),
#  (2, 330, 'Rose', 5, 2248),
#  (3, 330, 'Rose', 5, 2248),
#  (4, 330, 'Rose', 5, 2248)]

# %% [markdown]
# ## Problem 1: Write a query that prints a list of employee names (i.e.: the name attribute) from the Employee table in alphabetical order.

# %%
# %%sql
#
# SELECT DISTINCT(name) # Adding Distinct to limit the result so you don't have to keep scrolling for the next question
# FROM employee
# ORDER BY name;
# Out:
#  * sqlite:///Problem_set_04.db
# Done.
# [('Alan',),
#  ('Amy',),
#  ('Andrew',),
#  ('Angela',),
#  ('Ann',),
#  ('Anna',),
#  ('Anthony',),
#  ('Antonio',),
#  ('Benjamin',),
#  ('Bonnie',),
#  ('Brandon',),
#  ('Brian',),
#  ('Carol',),
#  ('Charles',),
#  ('Christina',),
#  ('Christine',),
#  ('David',),
#  ('Debra',),
#  ('Diana',),
#  ('Donna',),
#  ('Dorothy',),
#  ('Earl',),
#  ('Elizabeth',),
#  ('Emily',),
#  ('Evelyn',),
#  ('Frank',),
#  ('Gerald',),
#  ('Gloria',),
#  ('Gregory',),
#  ('Harry',),
#  ('Jacqueline',),
#  ('James',),
#  ('Jean',),
#  ('Jennifer',),
#  ('Jesse',),
#  ('Joe',),
#  ('John',),
#  ('Jonathan',),
#  ('Joseph',),
#  ('Joyce',),
#  ('Julia',),
#  ('Keith',),
#  ('Kelly',),
#  ('Kevin',),
#  ('Kimberly',),
#  ('Lawrence',),
#  ('Lillian',),
#  ('Linda',),
#  ('Lisa',),
#  ('Lori',),
#  ('Louise',),
#  ('Maria',),
#  ('Marilyn',),
#  ('Martha',),
#  ('Martin',),
#  ('Matthew',),
#  ('Melissa',),
#  ('Michael',),
#  ('Michelle',),
#  ('Nancy',),
# ...

# %% [markdown]
# ## 2.	Write a query that prints a list of employee names (i.e.: the name attribute) for employees in Employee having a salary greater than 2000 dollars per month who have been employees for less than 10 months. Sort your result by ascending employee_id.

# %%
# %%sql
#
# SELECT name
# FROM employee
# WHERE salary > 2000 and months < 10
# ORDER BY employee_id;
# Out:
#  * sqlite:///Problem_set_04.db
# Done.
# [('Rose',),
#  ('Rose',),
#  ('Rose',),
#  ('Rose',),
#  ('Rose',),
#  ('Patrick',),
#  ('Patrick',),
#  ('Patrick',),
#  ('Patrick',),
#  ('Patrick',),
#  ('Lisa',),
#  ('Lisa',),
#  ('Lisa',),
#  ('Lisa',),
#  ('Lisa',),
#  ('Amy',),
#  ('Amy',),
#  ('Amy',),
#  ('Amy',),
#  ('Amy',),
#  ('Pamela',),
#  ('Pamela',),
#  ('Pamela',),
#  ('Pamela',),
#  ('Pamela',),
#  ('Jennifer',),
#  ('Jennifer',),
#  ('Jennifer',),
#  ('Jennifer',),
#  ('Jennifer',),
#  ('Julia',),
#  ('Julia',),
#  ('Julia',),
#  ('Julia',),
#  ('Julia',),
#  ('Kevin',),
#  ('Kevin',),
#  ('Kevin',),
#  ('Kevin',),
#  ('Kevin',),
#  ('Paul',),
#  ('Paul',),
#  ('Paul',),
#  ('Paul',),
#  ('Paul',),
#  ('Donna',),
#  ('Donna',),
#  ('Donna',),
#  ('Donna',),
#  ('Donna',),
#  ('Michelle',),
#  ('Michelle',),
#  ('Michelle',),
#  ('Michelle',),
#  ('Michelle',),
#  ('Christina',),
#  ('Christina',),
#  ('Christina',),
#  ('Christina',),
#  ('Christina',),
#  ('Brandon',),
# ...

# %% [markdown]
# ## Problem 3: Find the number of Most Senior Employees.

# %%
# %%sql
#
# SELECT COUNT(*)
# FROM employee
# GROUP BY months
# ORDER BY months DESC
# LIMIT 1;
# Out:
#  * sqlite:///Problem_set_04.db
# Done.
# [(40,)]

# %% [markdown]
# ## Problem 4: We define an employee's total earnings to be their monthly salary x months worked, and the maximum total earnings to be the maximum total earnings for any employee in the Employee table. Write a query to find the maximum total earnings for all employees as well as the total number of employees who have maximum total earnings. Then print these values as 2 space-separated integers.

# %%
# %%sql
#
# SELECT salary*months AS Total_Earnings, COUNT(*) AS NNumber_of_Top_Earners
# FROM employee
# GROUP BY 1
# ORDER BY 1 DESC
# Limit 1;
# Out:
#  * sqlite:///Problem_set_04.db
# Done.
# [(108064, 35)]
