# %%
#importing all the libraries
import pandas as pd
import sqlite3

# %%
#installing ipython-sql library 
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in ./opt/anaconda3/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: six in ./opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in ./opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.3.20)
# Requirement already satisfied: ipython>=1.0 in ./opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (7.19.0)
# Requirement already satisfied: prettytable<1 in ./opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: ipython-genutils>=0.1.0 in ./opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: sqlparse in ./opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.4.1)
# Requirement already satisfied: jedi>=0.10 in ./opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.17.1)
# Requirement already satisfied: traitlets>=4.2 in ./opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.0.5)
# Requirement already satisfied: pickleshare in ./opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: backcall in ./opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (3.0.8)
# Requirement already satisfied: setuptools>=18.5 in ./opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (50.3.1.post20201107)
# Requirement already satisfied: appnope; sys_platform == "darwin" in ./opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: decorator in ./opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.4.2)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in ./opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: pygments in ./opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (2.7.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in ./opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in ./opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in ./opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=1.0->ipython-sql) (0.6.0)

# %%
df = pd.read_csv(r'/Users/sushantkumbhar/Documents/Stevens Academics/Skills Imporvement/SQL/SQL practice/Scraped data from github/60_days_of_sql_ps_1.csv')

# %%
cnn = sqlite3.connect('Problem_set_01.db')

# %%
df.to_sql('city',cnn)
# Out:
# /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:2605: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
# %load_ext sql

# %%
# %sql sqlite:///Problem_set_01.db

# %%
# %%sql
# SELECT * FROM city;
# Out:
#  * sqlite:///Problem_set_01.db
# Done.
# [(0, 6, 'Rotterdam', 'NLD', 'Zuid-Holland', 593321),
#  (1, 6, 'Rotterdam', 'NLD', 'Zuid-Holland', 593321),
#  (2, 6, 'Rotterdam', 'NLD', 'Zuid-Holland', 593321),
#  (3, 6, 'Rotterdam', 'NLD', 'Zuid-Holland', 593321),
#  (4, 6, 'Rotterdam', 'NLD', 'Zuid-Holland', 593321),
#  (5, 6, 'Rotterdam', 'NLD', 'Zuid-Holland', 593321),
#  (6, 19, 'Zaanstad', 'NLD', 'Noord-Holland', 135621),
#  (7, 19, 'Zaanstad', 'NLD', 'Noord-Holland', 135621),
#  (8, 19, 'Zaanstad', 'NLD', 'Noord-Holland', 135621),
#  (9, 19, 'Zaanstad', 'NLD', 'Noord-Holland', 135621),
#  (10, 19, 'Zaanstad', 'NLD', 'Noord-Holland', 135621),
#  (11, 19, 'Zaanstad', 'NLD', 'Noord-Holland', 135621),
#  (12, 214, 'Porto Alegre', 'BRA', 'Rio Grande do Sul', 1314032),
#  (13, 214, 'Porto Alegre', 'BRA', 'Rio Grande do Sul', 1314032),
#  (14, 214, 'Porto Alegre', 'BRA', 'Rio Grande do Sul', 1314032),
#  (15, 214, 'Porto Alegre', 'BRA', 'Rio Grande do Sul', 1314032),
#  (16, 214, 'Porto Alegre', 'BRA', 'Rio Grande do Sul', 1314032),
#  (17, 214, 'Porto Alegre', 'BRA', 'Rio Grande do Sul', 1314032),
#  (18, 397, 'Lauro de Freitas', 'BRA', 'Bahia', 109236),
#  (19, 397, 'Lauro de Freitas', 'BRA', 'Bahia', 109236),
#  (20, 397, 'Lauro de Freitas', 'BRA', 'Bahia', 109236),
#  (21, 397, 'Lauro de Freitas', 'BRA', 'Bahia', 109236),
#  (22, 397, 'Lauro de Freitas', 'BRA', 'Bahia', 109236),
#  (23, 397, 'Lauro de Freitas', 'BRA', 'Bahia', 109236),
#  (24, 547, 'Dobric', 'BGR', 'Varna', 100399),
#  (25, 547, 'Dobric', 'BGR', 'Varna', 100399),
#  (26, 547, 'Dobric', 'BGR', 'Varna', 100399),
#  (27, 547, 'Dobric', 'BGR', 'Varna', 100399),
#  (28, 547, 'Dobric', 'BGR', 'Varna', 100399),
#  (29, 547, 'Dobric', 'BGR', 'Varna', 100399),
#  (30, 552, 'Bujumbura', 'BDI', 'Bujumbura', 300000),
#  (31, 552, 'Bujumbura', 'BDI', 'Bujumbura', 300000),
#  (32, 552, 'Bujumbura', 'BDI', 'Bujumbura', 300000),
#  (33, 552, 'Bujumbura', 'BDI', 'Bujumbura', 300000),
#  (34, 552, 'Bujumbura', 'BDI', 'Bujumbura', 300000),
#  (35, 552, 'Bujumbura', 'BDI', 'Bujumbura', 300000),
#  (36, 554, 'Santiago de Chile', 'CHL', 'Santiago', 4703954),
#  (37, 554, 'Santiago de Chile', 'CHL', 'Santiago', 4703954),
#  (38, 554, 'Santiago de Chile', 'CHL', 'Santiago', 4703954),
#  (39, 554, 'Santiago de Chile', 'CHL', 'Santiago', 4703954),
#  (40, 554, 'Santiago de Chile', 'CHL', 'Santiago', 4703954),
#  (41, 554, 'Santiago de Chile', 'CHL', 'Santiago', 4703954),
#  (42, 626, 'al-Minya', 'EGY', 'al-Minya', 201360),
#  (43, 626, 'al-Minya', 'EGY', 'al-Minya', 201360),
#  (44, 626, 'al-Minya', 'EGY', 'al-Minya', 201360),
#  (45, 626, 'al-Minya', 'EGY', 'al-Minya', 201360),
#  (46, 626, 'al-Minya', 'EGY', 'al-Minya', 201360),
#  (47, 626, 'al-Minya', 'EGY', 'al-Minya', 201360),
#  (48, 646, 'Santa Ana', 'SLV', 'Santa Ana', 139389),
#  (49, 646, 'Santa Ana', 'SLV', 'Santa Ana', 139389),
#  (50, 646, 'Santa Ana', 'SLV', 'Santa Ana', 139389),
#  (51, 646, 'Santa Ana', 'SLV', 'Santa Ana', 139389),
#  (52, 646, 'Santa Ana', 'SLV', 'Santa Ana', 139389),
#  (53, 646, 'Santa Ana', 'SLV', 'Santa Ana', 139389),
#  (54, 762, 'Bahir Dar', 'ETH', 'Amhara', 96140),
#  (55, 762, 'Bahir Dar', 'ETH', 'Amhara', 96140),
#  (56, 762, 'Bahir Dar', 'ETH', 'Amhara', 96140),
#  (57, 762, 'Bahir Dar', 'ETH', 'Amhara', 96140),
#  (58, 762, 'Bahir Dar', 'ETH', 'Amhara', 96140),
#  (59, 762, 'Bahir Dar', 'ETH', 'Amhara', 96140),
#  (60, 796, 'Baguio', 'PHL', 'CAR', 252386),
#  (61, 796, 'Baguio', 'PHL', 'CAR', 252386),
#  (62, 796, 'Baguio', 'PHL', 'CAR', 252386),
#  (63, 796, 'Baguio', 'PHL', 'CAR', 252386),
#  (64, 796, 'Baguio', 'PHL', 'CAR', 252386),
#  (65, 796, 'Baguio', 'PHL', 'CAR', 252386),
#  (66, 896, 'Malungon', 'PHL', 'Southern Mindanao', 93232),
#  (67, 896, 'Malungon', 'PHL', 'Southern Mindanao', 93232),
#  (68, 896, 'Malungon', 'PHL', 'Southern Mindanao', 93232),
#  (69, 896, 'Malungon', 'PHL', 'Southern Mindanao', 93232),
#  (70, 896, 'Malungon', 'PHL', 'Southern Mindanao', 93232),
#  (71, 896, 'Malungon', 'PHL', 'Southern Mindanao', 93232),
#  (72, 904, 'Banjul', 'GMB', 'Banjul', 42326),
#  (73, 904, 'Banjul', 'GMB', 'Banjul', 42326),
#  (74, 904, 'Banjul', 'GMB', 'Banjul', 42326),
#  (75, 904, 'Banjul', 'GMB', 'Banjul', 42326),
#  (76, 904, 'Banjul', 'GMB', 'Banjul', 42326),
#  (77, 904, 'Banjul', 'GMB', 'Banjul', 42326),
#  (78, 924, 'Villa Nueva', 'GTM', 'Guatemala', 101295),
#  (79, 924, 'Villa Nueva', 'GTM', 'Guatemala', 101295),
#  (80, 924, 'Villa Nueva', 'GTM', 'Guatemala', 101295),
#  (81, 924, 'Villa Nueva', 'GTM', 'Guatemala', 101295),
#  (82, 924, 'Villa Nueva', 'GTM', 'Guatemala', 101295),
#  (83, 924, 'Villa Nueva', 'GTM', 'Guatemala', 101295),
#  (84, 990, 'Waru', 'IDN', 'East Java', 124300),
#  (85, 990, 'Waru', 'IDN', 'East Java', 124300),
#  (86, 990, 'Waru', 'IDN', 'East Java', 124300),
#  (87, 990, 'Waru', 'IDN', 'East Java', 124300),
#  (88, 990, 'Waru', 'IDN', 'East Java', 124300),
#  (89, 990, 'Waru', 'IDN', 'East Java', 124300),
#  (90, 1155, 'Latur', 'IND', 'Maharashtra', 197408),
#  (91, 1155, 'Latur', 'IND', 'Maharashtra', 197408),
#  (92, 1155, 'Latur', 'IND', 'Maharashtra', 197408),
#  (93, 1155, 'Latur', 'IND', 'Maharashtra', 197408),
#  (94, 1155, 'Latur', 'IND', 'Maharashtra', 197408),
#  (95, 1155, 'Latur', 'IND', 'Maharashtra', 197408),
#  (96, 1222, 'Tenali', 'IND', 'Andhra Pradesh', 143726),
#  (97, 1222, 'Tenali', 'IND', 'Andhra Pradesh', 143726),
#  (98, 1222, 'Tenali', 'IND', 'Andhra Pradesh', 143726),
#  (99, 1222, 'Tenali', 'IND', 'Andhra Pradesh', 143726),
#  (100, 1222, 'Tenali', 'IND', 'Andhra Pradesh', 143726),
#  (101, 1222, 'Tenali', 'IND', 'Andhra Pradesh', 143726),
#  (102, 1235, 'Tirunelveli', 'IND', 'Tamil Nadu', 135825),
#  (103, 1235, 'Tirunelveli', 'IND', 'Tamil Nadu', 135825),
#  (104, 1235, 'Tirunelveli', 'IND', 'Tamil Nadu', 135825),
#  (105, 1235, 'Tirunelveli', 'IND', 'Tamil Nadu', 135825),
#  (106, 1235, 'Tirunelveli', 'IND', 'Tamil Nadu', 135825),
#  (107, 1235, 'Tirunelveli', 'IND', 'Tamil Nadu', 135825),
#  (108, 1256, 'Alandur', 'IND', 'Tamil Nadu', 125244),
#  (109, 1256, 'Alandur', 'IND', 'Tamil Nadu', 125244),
#  (110, 1256, 'Alandur', 'IND', 'Tamil Nadu', 125244),
#  (111, 1256, 'Alandur', 'IND', 'Tamil Nadu', 125244),
#  (112, 1256, 'Alandur', 'IND', 'Tamil Nadu', 125244),
#  (113, 1256, 'Alandur', 'IND', 'Tamil Nadu', 125244),
#  (114, 1279, 'Neyveli', 'IND', 'Tamil Nadu', 118080),
#  (115, 1279, 'Neyveli', 'IND', 'Tamil Nadu', 118080),
#  (116, 1279, 'Neyveli', 'IND', 'Tamil Nadu', 118080),
#  (117, 1279, 'Neyveli', 'IND', 'Tamil Nadu', 118080),
#  (118, 1279, 'Neyveli', 'IND', 'Tamil Nadu', 118080),
#  (119, 1279, 'Neyveli', 'IND', 'Tamil Nadu', 118080),
#  (120, 1293, 'Pallavaram', 'IND', 'Tamil Nadu', 111866),
#  (121, 1293, 'Pallavaram', 'IND', 'Tamil Nadu', 111866),
#  (122, 1293, 'Pallavaram', 'IND', 'Tamil Nadu', 111866),
#  (123, 1293, 'Pallavaram', 'IND', 'Tamil Nadu', 111866),
#  (124, 1293, 'Pallavaram', 'IND', 'Tamil Nadu', 111866),
#  (125, 1293, 'Pallavaram', 'IND', 'Tamil Nadu', 111866),
#  (126, 1350, 'Dehri', 'IND', 'Bihar', 94526),
#  (127, 1350, 'Dehri', 'IND', 'Bihar', 94526),
#  (128, 1350, 'Dehri', 'IND', 'Bihar', 94526),
#  (129, 1350, 'Dehri', 'IND', 'Bihar', 94526),
#  (130, 1350, 'Dehri', 'IND', 'Bihar', 94526),
#  (131, 1350, 'Dehri', 'IND', 'Bihar', 94526),
#  (132, 1383, 'Tabriz', 'IRN', 'East Azerbaidzan', 1191043),
#  (133, 1383, 'Tabriz', 'IRN', 'East Azerbaidzan', 1191043),
#  (134, 1383, 'Tabriz', 'IRN', 'East Azerbaidzan', 1191043),
#  (135, 1383, 'Tabriz', 'IRN', 'East Azerbaidzan', 1191043),
#  (136, 1383, 'Tabriz', 'IRN', 'East Azerbaidzan', 1191043),
#  (137, 1383, 'Tabriz', 'IRN', 'East Azerbaidzan', 1191043),
#  (138, 1385, 'Karaj', 'IRN', 'Teheran', 940968),
#  (139, 1385, 'Karaj', 'IRN', 'Teheran', 940968),
#  (140, 1385, 'Karaj', 'IRN', 'Teheran', 940968),
#  (141, 1385, 'Karaj', 'IRN', 'Teheran', 940968),
#  (142, 1385, 'Karaj', 'IRN', 'Teheran', 940968),
#  (143, 1385, 'Karaj', 'IRN', 'Teheran', 940968),
#  (144, 1508, 'Bolzano', 'ITA', 'Trentino-Alto Adige', 97232),
#  (145, 1508, 'Bolzano', 'ITA', 'Trentino-Alto Adige', 97232),
#  (146, 1508, 'Bolzano', 'ITA', 'Trentino-Alto Adige', 97232),
#  (147, 1508, 'Bolzano', 'ITA', 'Trentino-Alto Adige', 97232),
#  (148, 1508, 'Bolzano', 'ITA', 'Trentino-Alto Adige', 97232),
#  (149, 1508, 'Bolzano', 'ITA', 'Trentino-Alto Adige', 97232),
#  (150, 1520, 'Cesena', 'ITA', 'Emilia-Romagna', 89852),
#  (151, 1520, 'Cesena', 'ITA', 'Emilia-Romagna', 89852),
#  (152, 1520, 'Cesena', 'ITA', 'Emilia-Romagna', 89852),
#  (153, 1520, 'Cesena', 'ITA', 'Emilia-Romagna', 89852),
#  (154, 1520, 'Cesena', 'ITA', 'Emilia-Romagna', 89852),
#  (155, 1520, 'Cesena', 'ITA', 'Emilia-Romagna', 89852),
#  (156, 1613, 'Neyagawa', 'JPN', 'Osaka', 257315),
#  (157, 1613, 'Neyagawa', 'JPN', 'Osaka', 257315),
#  (158, 1613, 'Neyagawa', 'JPN', 'Osaka', 257315),
#  (159, 1613, 'Neyagawa', 'JPN', 'Osaka', 257315),
#  (160, 1613, 'Neyagawa', 'JPN', 'Osaka', 257315),
#  (161, 1613, 'Neyagawa', 'JPN', 'Osaka', 257315),
#  (162, 1630, 'Ageo', 'JPN', 'Saitama', 209442),
#  (163, 1630, 'Ageo', 'JPN', 'Saitama', 209442),
#  (164, 1630, 'Ageo', 'JPN', 'Saitama', 209442),
#  (165, 1630, 'Ageo', 'JPN', 'Saitama', 209442),
#  (166, 1630, 'Ageo', 'JPN', 'Saitama', 209442),
#  (167, 1630, 'Ageo', 'JPN', 'Saitama', 209442),
#  (168, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (169, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (170, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (171, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (172, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (173, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (174, 1681, 'Omuta', 'JPN', 'Fukuoka', 142889),
#  (175, 1681, 'Omuta', 'JPN', 'Fukuoka', 142889),
#  (176, 1681, 'Omuta', 'JPN', 'Fukuoka', 142889),
#  (177, 1681, 'Omuta', 'JPN', 'Fukuoka', 142889),
#  (178, 1681, 'Omuta', 'JPN', 'Fukuoka', 142889),
#  (179, 1681, 'Omuta', 'JPN', 'Fukuoka', 142889),
#  (180, 1739, 'Tokuyama', 'JPN', 'Yamaguchi', 107078),
#  (181, 1739, 'Tokuyama', 'JPN', 'Yamaguchi', 107078),
#  (182, 1739, 'Tokuyama', 'JPN', 'Yamaguchi', 107078),
#  (183, 1739, 'Tokuyama', 'JPN', 'Yamaguchi', 107078),
#  (184, 1739, 'Tokuyama', 'JPN', 'Yamaguchi', 107078),
#  (185, 1739, 'Tokuyama', 'JPN', 'Yamaguchi', 107078),
#  (186, 1793, 'Novi Sad', 'YUG', 'Vojvodina', 179626),
#  (187, 1793, 'Novi Sad', 'YUG', 'Vojvodina', 179626),
#  (188, 1793, 'Novi Sad', 'YUG', 'Vojvodina', 179626),
#  (189, 1793, 'Novi Sad', 'YUG', 'Vojvodina', 179626),
#  (190, 1793, 'Novi Sad', 'YUG', 'Vojvodina', 179626),
#  (191, 1793, 'Novi Sad', 'YUG', 'Vojvodina', 179626),
#  (192, 1857, 'Kelowna', 'CAN', 'British Colombia', 89442),
#  (193, 1857, 'Kelowna', 'CAN', 'British Colombia', 89442),
#  (194, 1857, 'Kelowna', 'CAN', 'British Colombia', 89442),
#  (195, 1857, 'Kelowna', 'CAN', 'British Colombia', 89442),
#  (196, 1857, 'Kelowna', 'CAN', 'British Colombia', 89442),
#  (197, 1857, 'Kelowna', 'CAN', 'British Colombia', 89442),
#  (198, 1895, 'Harbin', 'CHN', 'Heilongjiang', 4289800),
#  (199, 1895, 'Harbin', 'CHN', 'Heilongjiang', 4289800),
#  (200, 1895, 'Harbin', 'CHN', 'Heilongjiang', 4289800),
#  (201, 1895, 'Harbin', 'CHN', 'Heilongjiang', 4289800),
#  (202, 1895, 'Harbin', 'CHN', 'Heilongjiang', 4289800),
#  (203, 1895, 'Harbin', 'CHN', 'Heilongjiang', 4289800),
#  (204, 1900, 'Changchun', 'CHN', 'Jilin', 2812000),
#  (205, 1900, 'Changchun', 'CHN', 'Jilin', 2812000),
#  (206, 1900, 'Changchun', 'CHN', 'Jilin', 2812000),
#  (207, 1900, 'Changchun', 'CHN', 'Jilin', 2812000),
#  (208, 1900, 'Changchun', 'CHN', 'Jilin', 2812000),
#  (209, 1900, 'Changchun', 'CHN', 'Jilin', 2812000),
#  (210, 1913, 'Lanzhou', 'CHN', 'Gansu', 1565800),
#  (211, 1913, 'Lanzhou', 'CHN', 'Gansu', 1565800),
#  (212, 1913, 'Lanzhou', 'CHN', 'Gansu', 1565800),
#  (213, 1913, 'Lanzhou', 'CHN', 'Gansu', 1565800),
#  (214, 1913, 'Lanzhou', 'CHN', 'Gansu', 1565800),
#  (215, 1913, 'Lanzhou', 'CHN', 'Gansu', 1565800),
#  (216, 1947, 'Changzhou', 'CHN', 'Jiangsu', 530000),
#  (217, 1947, 'Changzhou', 'CHN', 'Jiangsu', 530000),
#  (218, 1947, 'Changzhou', 'CHN', 'Jiangsu', 530000),
#  (219, 1947, 'Changzhou', 'CHN', 'Jiangsu', 530000),
#  (220, 1947, 'Changzhou', 'CHN', 'Jiangsu', 530000),
#  (221, 1947, 'Changzhou', 'CHN', 'Jiangsu', 530000),
#  (222, 2070, 'Dezhou', 'CHN', 'Shandong', 195485),
#  (223, 2070, 'Dezhou', 'CHN', 'Shandong', 195485),
#  (224, 2070, 'Dezhou', 'CHN', 'Shandong', 195485),
#  (225, 2070, 'Dezhou', 'CHN', 'Shandong', 195485),
#  (226, 2070, 'Dezhou', 'CHN', 'Shandong', 195485),
#  (227, 2070, 'Dezhou', 'CHN', 'Shandong', 195485),
#  (228, 2081, 'Heze', 'CHN', 'Shandong', 189293),
#  (229, 2081, 'Heze', 'CHN', 'Shandong', 189293),
#  (230, 2081, 'Heze', 'CHN', 'Shandong', 189293),
#  (231, 2081, 'Heze', 'CHN', 'Shandong', 189293),
#  (232, 2081, 'Heze', 'CHN', 'Shandong', 189293),
#  (233, 2081, 'Heze', 'CHN', 'Shandong', 189293),
#  (234, 2111, 'Chenzhou', 'CHN', 'Hunan', 169400),
#  (235, 2111, 'Chenzhou', 'CHN', 'Hunan', 169400),
#  (236, 2111, 'Chenzhou', 'CHN', 'Hunan', 169400),
#  (237, 2111, 'Chenzhou', 'CHN', 'Hunan', 169400),
#  (238, 2111, 'Chenzhou', 'CHN', 'Hunan', 169400),
#  (239, 2111, 'Chenzhou', 'CHN', 'Hunan', 169400),
#  (240, 2153, 'Xianning', 'CHN', 'Hubei', 136811),
#  (241, 2153, 'Xianning', 'CHN', 'Hubei', 136811),
#  (242, 2153, 'Xianning', 'CHN', 'Hubei', 136811),
#  (243, 2153, 'Xianning', 'CHN', 'Hubei', 136811),
#  (244, 2153, 'Xianning', 'CHN', 'Hubei', 136811),
#  (245, 2153, 'Xianning', 'CHN', 'Hubei', 136811),
#  (246, 2192, 'Lhasa', 'CHN', 'Tibet', 120000),
#  (247, 2192, 'Lhasa', 'CHN', 'Tibet', 120000),
#  (248, 2192, 'Lhasa', 'CHN', 'Tibet', 120000),
#  (249, 2192, 'Lhasa', 'CHN', 'Tibet', 120000),
#  (250, 2192, 'Lhasa', 'CHN', 'Tibet', 120000),
#  (251, 2192, 'Lhasa', 'CHN', 'Tibet', 120000),
#  (252, 2193, 'Lianyuan', 'CHN', 'Hunan', 118858),
#  (253, 2193, 'Lianyuan', 'CHN', 'Hunan', 118858),
#  (254, 2193, 'Lianyuan', 'CHN', 'Hunan', 118858),
#  (255, 2193, 'Lianyuan', 'CHN', 'Hunan', 118858),
#  (256, 2193, 'Lianyuan', 'CHN', 'Hunan', 118858),
#  (257, 2193, 'Lianyuan', 'CHN', 'Hunan', 118858),
#  (258, 2227, 'Xingcheng', 'CHN', 'Liaoning', 102384),
#  (259, 2227, 'Xingcheng', 'CHN', 'Liaoning', 102384),
#  (260, 2227, 'Xingcheng', 'CHN', 'Liaoning', 102384),
#  (261, 2227, 'Xingcheng', 'CHN', 'Liaoning', 102384),
#  (262, 2227, 'Xingcheng', 'CHN', 'Liaoning', 102384),
#  (263, 2227, 'Xingcheng', 'CHN', 'Liaoning', 102384),
#  (264, 2273, 'Villavicencio', 'COL', 'Meta', 273140),
#  (265, 2273, 'Villavicencio', 'COL', 'Meta', 273140),
#  (266, 2273, 'Villavicencio', 'COL', 'Meta', 273140),
#  (267, 2273, 'Villavicencio', 'COL', 'Meta', 273140),
#  (268, 2273, 'Villavicencio', 'COL', 'Meta', 273140),
#  (269, 2273, 'Villavicencio', 'COL', 'Meta', 273140),
#  (270, 2384, 'Tong-yong', 'KOR', 'Kyongsangnam', 131717),
#  (271, 2384, 'Tong-yong', 'KOR', 'Kyongsangnam', 131717),
#  (272, 2384, 'Tong-yong', 'KOR', 'Kyongsangnam', 131717),
#  (273, 2384, 'Tong-yong', 'KOR', 'Kyongsangnam', 131717),
#  (274, 2384, 'Tong-yong', 'KOR', 'Kyongsangnam', 131717),
#  (275, 2384, 'Tong-yong', 'KOR', 'Kyongsangnam', 131717),
#  (276, 2386, 'Yongju', 'KOR', 'Kyongsangbuk', 131097),
#  (277, 2386, 'Yongju', 'KOR', 'Kyongsangbuk', 131097),
#  (278, 2386, 'Yongju', 'KOR', 'Kyongsangbuk', 131097),
#  (279, 2386, 'Yongju', 'KOR', 'Kyongsangbuk', 131097),
#  (280, 2386, 'Yongju', 'KOR', 'Kyongsangbuk', 131097),
#  (281, 2386, 'Yongju', 'KOR', 'Kyongsangbuk', 131097),
#  (282, 2387, 'Chinhae', 'KOR', 'Kyongsangnam', 125997),
#  (283, 2387, 'Chinhae', 'KOR', 'Kyongsangnam', 125997),
#  (284, 2387, 'Chinhae', 'KOR', 'Kyongsangnam', 125997),
#  (285, 2387, 'Chinhae', 'KOR', 'Kyongsangnam', 125997),
#  (286, 2387, 'Chinhae', 'KOR', 'Kyongsangnam', 125997),
#  (287, 2387, 'Chinhae', 'KOR', 'Kyongsangnam', 125997),
#  (288, 2388, 'Sangju', 'KOR', 'Kyongsangbuk', 124116),
#  (289, 2388, 'Sangju', 'KOR', 'Kyongsangbuk', 124116),
#  (290, 2388, 'Sangju', 'KOR', 'Kyongsangbuk', 124116),
#  (291, 2388, 'Sangju', 'KOR', 'Kyongsangbuk', 124116),
#  (292, 2388, 'Sangju', 'KOR', 'Kyongsangbuk', 124116),
#  (293, 2388, 'Sangju', 'KOR', 'Kyongsangbuk', 124116),
#  (294, 2406, 'Herakleion', 'GRC', 'Crete', 116178),
#  (295, 2406, 'Herakleion', 'GRC', 'Crete', 116178),
#  (296, 2406, 'Herakleion', 'GRC', 'Crete', 116178),
#  (297, 2406, 'Herakleion', 'GRC', 'Crete', 116178),
#  (298, 2406, 'Herakleion', 'GRC', 'Crete', 116178),
#  (299, 2406, 'Herakleion', 'GRC', 'Crete', 116178),
#  (300, 2440, 'Monrovia', 'LBR', 'Montserrado', 850000),
#  (301, 2440, 'Monrovia', 'LBR', 'Montserrado', 850000),
#  (302, 2440, 'Monrovia', 'LBR', 'Montserrado', 850000),
#  (303, 2440, 'Monrovia', 'LBR', 'Montserrado', 850000),
#  (304, 2440, 'Monrovia', 'LBR', 'Montserrado', 850000),
#  (305, 2440, 'Monrovia', 'LBR', 'Montserrado', 850000),
#  (306, 2462, 'Lilongwe', 'MWI', 'Lilongwe', 435964),
#  (307, 2462, 'Lilongwe', 'MWI', 'Lilongwe', 435964),
#  (308, 2462, 'Lilongwe', 'MWI', 'Lilongwe', 435964),
#  (309, 2462, 'Lilongwe', 'MWI', 'Lilongwe', 435964),
#  (310, 2462, 'Lilongwe', 'MWI', 'Lilongwe', 435964),
#  (311, 2462, 'Lilongwe', 'MWI', 'Lilongwe', 435964),
#  (312, 2505, 'Taza', 'MAR', 'Taza-Al Hoceima-Taou', 92700),
#  (313, 2505, 'Taza', 'MAR', 'Taza-Al Hoceima-Taou', 92700),
#  (314, 2505, 'Taza', 'MAR', 'Taza-Al Hoceima-Taou', 92700),
#  (315, 2505, 'Taza', 'MAR', 'Taza-Al Hoceima-Taou', 92700),
#  (316, 2505, 'Taza', 'MAR', 'Taza-Al Hoceima-Taou', 92700),
#  (317, 2505, 'Taza', 'MAR', 'Taza-Al Hoceima-Taou', 92700),
#  (318, 2555, 'Xalapa', 'MEX', 'Veracruz', 390058),
#  (319, 2555, 'Xalapa', 'MEX', 'Veracruz', 390058),
#  (320, 2555, 'Xalapa', 'MEX', 'Veracruz', 390058),
#  (321, 2555, 'Xalapa', 'MEX', 'Veracruz', 390058),
#  (322, 2555, 'Xalapa', 'MEX', 'Veracruz', 390058),
#  (323, 2555, 'Xalapa', 'MEX', 'Veracruz', 390058),
#  (324, 2602, 'Ocosingo', 'MEX', 'Chiapas', 171495),
#  (325, 2602, 'Ocosingo', 'MEX', 'Chiapas', 171495),
#  (326, 2602, 'Ocosingo', 'MEX', 'Chiapas', 171495),
#  (327, 2602, 'Ocosingo', 'MEX', 'Chiapas', 171495),
#  (328, 2602, 'Ocosingo', 'MEX', 'Chiapas', 171495),
#  (329, 2602, 'Ocosingo', 'MEX', 'Chiapas', 171495),
#  (330, 2609, 'Nogales', 'MEX', 'Sonora', 159103),
#  (331, 2609, 'Nogales', 'MEX', 'Sonora', 159103),
#  (332, 2609, 'Nogales', 'MEX', 'Sonora', 159103),
#  (333, 2609, 'Nogales', 'MEX', 'Sonora', 159103),
#  (334, 2609, 'Nogales', 'MEX', 'Sonora', 159103),
#  (335, 2609, 'Nogales', 'MEX', 'Sonora', 159103),
#  (336, 2670, 'San Pedro Cholula', 'MEX', 'Puebla', 99734),
#  (337, 2670, 'San Pedro Cholula', 'MEX', 'Puebla', 99734),
#  (338, 2670, 'San Pedro Cholula', 'MEX', 'Puebla', 99734),
#  (339, 2670, 'San Pedro Cholula', 'MEX', 'Puebla', 99734),
#  (340, 2670, 'San Pedro Cholula', 'MEX', 'Puebla', 99734),
#  (341, 2670, 'San Pedro Cholula', 'MEX', 'Puebla', 99734),
#  (342, 2689, 'Palikir', 'FSM', 'Pohnpei', 8600),
#  (343, 2689, 'Palikir', 'FSM', 'Pohnpei', 8600),
#  (344, 2689, 'Palikir', 'FSM', 'Pohnpei', 8600),
#  (345, 2689, 'Palikir', 'FSM', 'Pohnpei', 8600),
#  (346, 2689, 'Palikir', 'FSM', 'Pohnpei', 8600),
#  (347, 2689, 'Palikir', 'FSM', 'Pohnpei', 8600),
#  (348, 2706, 'Tete', 'MOZ', 'Tete', 101984),
#  (349, 2706, 'Tete', 'MOZ', 'Tete', 101984),
#  (350, 2706, 'Tete', 'MOZ', 'Tete', 101984),
#  (351, 2706, 'Tete', 'MOZ', 'Tete', 101984),
#  (352, 2706, 'Tete', 'MOZ', 'Tete', 101984),
#  (353, 2706, 'Tete', 'MOZ', 'Tete', 101984),
#  (354, 2716, 'Sittwe (Akyab)', 'MMR', 'Rakhine', 137600),
#  (355, 2716, 'Sittwe (Akyab)', 'MMR', 'Rakhine', 137600),
#  (356, 2716, 'Sittwe (Akyab)', 'MMR', 'Rakhine', 137600),
#  (357, 2716, 'Sittwe (Akyab)', 'MMR', 'Rakhine', 137600),
#  (358, 2716, 'Sittwe (Akyab)', 'MMR', 'Rakhine', 137600),
#  (359, 2716, 'Sittwe (Akyab)', 'MMR', 'Rakhine', 137600),
#  (360, 2922, 'Carolina', 'PRI', 'Carolina', 186076),
#  (361, 2922, 'Carolina', 'PRI', 'Carolina', 186076),
#  (362, 2922, 'Carolina', 'PRI', 'Carolina', 186076),
#  (363, 2922, 'Carolina', 'PRI', 'Carolina', 186076),
#  (364, 2922, 'Carolina', 'PRI', 'Carolina', 186076),
#  (365, 2922, 'Carolina', 'PRI', 'Carolina', 186076),
#  (366, 2967, 'Grudziadz', 'POL', 'Kujawsko-Pomorskie', 102434),
#  (367, 2967, 'Grudziadz', 'POL', 'Kujawsko-Pomorskie', 102434),
#  (368, 2967, 'Grudziadz', 'POL', 'Kujawsko-Pomorskie', 102434),
#  (369, 2967, 'Grudziadz', 'POL', 'Kujawsko-Pomorskie', 102434),
#  (370, 2967, 'Grudziadz', 'POL', 'Kujawsko-Pomorskie', 102434),
#  (371, 2967, 'Grudziadz', 'POL', 'Kujawsko-Pomorskie', 102434),
#  (372, 2972, 'Malabo', 'GNQ', 'Bioko', 40000),
#  (373, 2972, 'Malabo', 'GNQ', 'Bioko', 40000),
#  (374, 2972, 'Malabo', 'GNQ', 'Bioko', 40000),
#  (375, 2972, 'Malabo', 'GNQ', 'Bioko', 40000),
#  (376, 2972, 'Malabo', 'GNQ', 'Bioko', 40000),
#  (377, 2972, 'Malabo', 'GNQ', 'Bioko', 40000),
#  (378, 3073, 'Essen', 'DEU', 'Nordrhein-Westfalen', 599515),
#  (379, 3073, 'Essen', 'DEU', 'Nordrhein-Westfalen', 599515),
#  (380, 3073, 'Essen', 'DEU', 'Nordrhein-Westfalen', 599515),
#  (381, 3073, 'Essen', 'DEU', 'Nordrhein-Westfalen', 599515),
#  (382, 3073, 'Essen', 'DEU', 'Nordrhein-Westfalen', 599515),
#  (383, 3073, 'Essen', 'DEU', 'Nordrhein-Westfalen', 599515),
#  (384, 3169, 'Apia', 'WSM', 'Upolu', 35900),
#  (385, 3169, 'Apia', 'WSM', 'Upolu', 35900),
#  (386, 3169, 'Apia', 'WSM', 'Upolu', 35900),
#  (387, 3169, 'Apia', 'WSM', 'Upolu', 35900),
#  (388, 3169, 'Apia', 'WSM', 'Upolu', 35900),
#  (389, 3169, 'Apia', 'WSM', 'Upolu', 35900),
#  (390, 3198, 'Dakar', 'SEN', 'Cap-Vert', 785071),
#  (391, 3198, 'Dakar', 'SEN', 'Cap-Vert', 785071),
#  (392, 3198, 'Dakar', 'SEN', 'Cap-Vert', 785071),
#  (393, 3198, 'Dakar', 'SEN', 'Cap-Vert', 785071),
#  (394, 3198, 'Dakar', 'SEN', 'Cap-Vert', 785071),
#  (395, 3198, 'Dakar', 'SEN', 'Cap-Vert', 785071),
#  (396, 3253, 'Hama', 'SYR', 'Hama', 343361),
#  (397, 3253, 'Hama', 'SYR', 'Hama', 343361),
#  (398, 3253, 'Hama', 'SYR', 'Hama', 343361),
#  (399, 3253, 'Hama', 'SYR', 'Hama', 343361),
#  (400, 3253, 'Hama', 'SYR', 'Hama', 343361),
#  (401, 3253, 'Hama', 'SYR', 'Hama', 343361),
#  (402, 3288, 'Luchou', 'TWN', 'Taipei', 160516),
#  (403, 3288, 'Luchou', 'TWN', 'Taipei', 160516),
#  (404, 3288, 'Luchou', 'TWN', 'Taipei', 160516),
#  (405, 3288, 'Luchou', 'TWN', 'Taipei', 160516),
#  (406, 3288, 'Luchou', 'TWN', 'Taipei', 160516),
#  (407, 3288, 'Luchou', 'TWN', 'Taipei', 160516),
#  (408, 3309, 'Tanga', 'TZA', 'Tanga', 137400),
#  (409, 3309, 'Tanga', 'TZA', 'Tanga', 137400),
#  (410, 3309, 'Tanga', 'TZA', 'Tanga', 137400),
#  (411, 3309, 'Tanga', 'TZA', 'Tanga', 137400),
#  (412, 3309, 'Tanga', 'TZA', 'Tanga', 137400),
#  (413, 3309, 'Tanga', 'TZA', 'Tanga', 137400),
#  (414, 3353, 'Sousse', 'TUN', 'Sousse', 145900),
#  (415, 3353, 'Sousse', 'TUN', 'Sousse', 145900),
#  (416, 3353, 'Sousse', 'TUN', 'Sousse', 145900),
#  (417, 3353, 'Sousse', 'TUN', 'Sousse', 145900),
#  (418, 3353, 'Sousse', 'TUN', 'Sousse', 145900),
#  (419, 3353, 'Sousse', 'TUN', 'Sousse', 145900),
#  (420, 3377, 'Kahramanmaras', 'TUR', 'Kahramanmaras', 245772),
#  (421, 3377, 'Kahramanmaras', 'TUR', 'Kahramanmaras', 245772),
#  (422, 3377, 'Kahramanmaras', 'TUR', 'Kahramanmaras', 245772),
#  (423, 3377, 'Kahramanmaras', 'TUR', 'Kahramanmaras', 245772),
#  (424, 3377, 'Kahramanmaras', 'TUR', 'Kahramanmaras', 245772),
#  (425, 3377, 'Kahramanmaras', 'TUR', 'Kahramanmaras', 245772),
#  (426, 3430, 'Odesa', 'UKR', 'Odesa', 1011000),
#  (427, 3430, 'Odesa', 'UKR', 'Odesa', 1011000),
#  (428, 3430, 'Odesa', 'UKR', 'Odesa', 1011000),
#  (429, 3430, 'Odesa', 'UKR', 'Odesa', 1011000),
#  (430, 3430, 'Odesa', 'UKR', 'Odesa', 1011000),
#  (431, 3430, 'Odesa', 'UKR', 'Odesa', 1011000),
#  (432, 3581, 'St Petersburg', 'RUS', 'Pietari', 4694000),
#  (433, 3581, 'St Petersburg', 'RUS', 'Pietari', 4694000),
#  (434, 3581, 'St Petersburg', 'RUS', 'Pietari', 4694000),
#  (435, 3581, 'St Petersburg', 'RUS', 'Pietari', 4694000),
#  (436, 3581, 'St Petersburg', 'RUS', 'Pietari', 4694000),
#  (437, 3581, 'St Petersburg', 'RUS', 'Pietari', 4694000),
#  (438, 3770, 'Hanoi', 'VNM', 'Hanoi', 1410000),
#  (439, 3770, 'Hanoi', 'VNM', 'Hanoi', 1410000),
#  (440, 3770, 'Hanoi', 'VNM', 'Hanoi', 1410000),
#  (441, 3770, 'Hanoi', 'VNM', 'Hanoi', 1410000),
#  (442, 3770, 'Hanoi', 'VNM', 'Hanoi', 1410000),
#  (443, 3770, 'Hanoi', 'VNM', 'Hanoi', 1410000),
#  (444, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (445, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (446, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (447, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (448, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (449, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (450, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (451, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (452, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (453, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (454, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (455, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (456, 3965, 'Corona', 'USA', 'California', 124966),
#  (457, 3965, 'Corona', 'USA', 'California', 124966),
#  (458, 3965, 'Corona', 'USA', 'California', 124966),
#  (459, 3965, 'Corona', 'USA', 'California', 124966),
#  (460, 3965, 'Corona', 'USA', 'California', 124966),
#  (461, 3965, 'Corona', 'USA', 'California', 124966),
#  (462, 3973, 'Concord', 'USA', 'California', 121780),
#  (463, 3973, 'Concord', 'USA', 'California', 121780),
#  (464, 3973, 'Concord', 'USA', 'California', 121780),
#  (465, 3973, 'Concord', 'USA', 'California', 121780),
#  (466, 3973, 'Concord', 'USA', 'California', 121780),
#  (467, 3973, 'Concord', 'USA', 'California', 121780),
#  (468, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (469, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (470, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (471, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (472, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (473, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (474, 3982, 'Coral Springs', 'USA', 'Florida', 117549),
#  (475, 3982, 'Coral Springs', 'USA', 'Florida', 117549),
#  (476, 3982, 'Coral Springs', 'USA', 'Florida', 117549),
#  (477, 3982, 'Coral Springs', 'USA', 'Florida', 117549),
#  (478, 3982, 'Coral Springs', 'USA', 'Florida', 117549),
#  (479, 3982, 'Coral Springs', 'USA', 'Florida', 117549),
#  (480, 4054, 'Fairfield', 'USA', 'California', 92256),
#  (481, 4054, 'Fairfield', 'USA', 'California', 92256),
#  (482, 4054, 'Fairfield', 'USA', 'California', 92256),
#  (483, 4054, 'Fairfield', 'USA', 'California', 92256),
#  (484, 4054, 'Fairfield', 'USA', 'California', 92256),
#  (485, 4054, 'Fairfield', 'USA', 'California', 92256),
#  (486, 4058, 'Boulder', 'USA', 'Colorado', 91238),
#  (487, 4058, 'Boulder', 'USA', 'Colorado', 91238),
#  (488, 4058, 'Boulder', 'USA', 'Colorado', 91238),
#  (489, 4058, 'Boulder', 'USA', 'Colorado', 91238),
#  (490, 4058, 'Boulder', 'USA', 'Colorado', 91238),
#  (491, 4058, 'Boulder', 'USA', 'Colorado', 91238),
#  (492, 4061, 'Fall River', 'USA', 'Massachusetts', 90555),
#  (493, 4061, 'Fall River', 'USA', 'Massachusetts', 90555),
#  (494, 4061, 'Fall River', 'USA', 'Massachusetts', 90555),
#  (495, 4061, 'Fall River', 'USA', 'Massachusetts', 90555),
#  (496, 4061, 'Fall River', 'USA', 'Massachusetts', 90555),
#  (497, 4061, 'Fall River', 'USA', 'Massachusetts', 90555)]

# %% [markdown]
# ## Problem 1: Query all columns for all American cities in the CITY table with populations larger than 100000. The CountryCode for America is USA

# %%
# %%sql
#
# SELECT *
# FROM city
# WHERE COUNTRYCODE = 'USA' AND POPULATION > 100000;
# Out:
#  * sqlite:///Problem_set_01.db
# Done.
# [(444, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (445, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (446, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (447, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (448, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (449, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (450, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (451, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (452, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (453, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (454, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (455, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (456, 3965, 'Corona', 'USA', 'California', 124966),
#  (457, 3965, 'Corona', 'USA', 'California', 124966),
#  (458, 3965, 'Corona', 'USA', 'California', 124966),
#  (459, 3965, 'Corona', 'USA', 'California', 124966),
#  (460, 3965, 'Corona', 'USA', 'California', 124966),
#  (461, 3965, 'Corona', 'USA', 'California', 124966),
#  (462, 3973, 'Concord', 'USA', 'California', 121780),
#  (463, 3973, 'Concord', 'USA', 'California', 121780),
#  (464, 3973, 'Concord', 'USA', 'California', 121780),
#  (465, 3973, 'Concord', 'USA', 'California', 121780),
#  (466, 3973, 'Concord', 'USA', 'California', 121780),
#  (467, 3973, 'Concord', 'USA', 'California', 121780),
#  (468, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (469, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (470, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (471, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (472, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (473, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (474, 3982, 'Coral Springs', 'USA', 'Florida', 117549),
#  (475, 3982, 'Coral Springs', 'USA', 'Florida', 117549),
#  (476, 3982, 'Coral Springs', 'USA', 'Florida', 117549),
#  (477, 3982, 'Coral Springs', 'USA', 'Florida', 117549),
#  (478, 3982, 'Coral Springs', 'USA', 'Florida', 117549),
#  (479, 3982, 'Coral Springs', 'USA', 'Florida', 117549)]

# %% [markdown]
# ## Problem 2: Query the NAME field for all American cities in the CITY table with populations larger than 120000. The CountryCode for America is USA

# %%
# %%sql
#
# SELECT *
# FROM city
# WHERE COUNTRYCODE = "USA" AND POPULATION > 120000;
# Out:
#  * sqlite:///Problem_set_01.db
# Done.
# [(444, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (445, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (446, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (447, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (448, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (449, 3815, 'El Paso', 'USA', 'Texas', 563662),
#  (450, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (451, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (452, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (453, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (454, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (455, 3878, 'Scottsdale', 'USA', 'Arizona', 202705),
#  (456, 3965, 'Corona', 'USA', 'California', 124966),
#  (457, 3965, 'Corona', 'USA', 'California', 124966),
#  (458, 3965, 'Corona', 'USA', 'California', 124966),
#  (459, 3965, 'Corona', 'USA', 'California', 124966),
#  (460, 3965, 'Corona', 'USA', 'California', 124966),
#  (461, 3965, 'Corona', 'USA', 'California', 124966),
#  (462, 3973, 'Concord', 'USA', 'California', 121780),
#  (463, 3973, 'Concord', 'USA', 'California', 121780),
#  (464, 3973, 'Concord', 'USA', 'California', 121780),
#  (465, 3973, 'Concord', 'USA', 'California', 121780),
#  (466, 3973, 'Concord', 'USA', 'California', 121780),
#  (467, 3973, 'Concord', 'USA', 'California', 121780),
#  (468, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (469, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (470, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (471, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (472, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758),
#  (473, 3977, 'Cedar Rapids', 'USA', 'Iowa', 120758)]

# %% [markdown]
# ## Problem 3: Query all columns for a city in CITY with the ID 1661

# %%
# %%sql
#
# SELECT *
# FROM city
# WHERE ID = 1661;
# Out:
#  * sqlite:///Problem_set_01.db
# Done.
# [(168, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (169, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (170, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (171, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (172, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (173, 1661, 'Sayama', 'JPN', 'Saitama', 162472)]

# %% [markdown]
# ## Problem 4: Query all attributes of every Japanese city in the CITY table. The COUNTRYCODE for Japan is JPN

# %%
# %%sql
#
# SELECT *
# FROM city
# WHERE COUNTRYCODE = "JPN";
# Out:
#  * sqlite:///Problem_set_01.db
# Done.
# [(156, 1613, 'Neyagawa', 'JPN', 'Osaka', 257315),
#  (157, 1613, 'Neyagawa', 'JPN', 'Osaka', 257315),
#  (158, 1613, 'Neyagawa', 'JPN', 'Osaka', 257315),
#  (159, 1613, 'Neyagawa', 'JPN', 'Osaka', 257315),
#  (160, 1613, 'Neyagawa', 'JPN', 'Osaka', 257315),
#  (161, 1613, 'Neyagawa', 'JPN', 'Osaka', 257315),
#  (162, 1630, 'Ageo', 'JPN', 'Saitama', 209442),
#  (163, 1630, 'Ageo', 'JPN', 'Saitama', 209442),
#  (164, 1630, 'Ageo', 'JPN', 'Saitama', 209442),
#  (165, 1630, 'Ageo', 'JPN', 'Saitama', 209442),
#  (166, 1630, 'Ageo', 'JPN', 'Saitama', 209442),
#  (167, 1630, 'Ageo', 'JPN', 'Saitama', 209442),
#  (168, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (169, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (170, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (171, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (172, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (173, 1661, 'Sayama', 'JPN', 'Saitama', 162472),
#  (174, 1681, 'Omuta', 'JPN', 'Fukuoka', 142889),
#  (175, 1681, 'Omuta', 'JPN', 'Fukuoka', 142889),
#  (176, 1681, 'Omuta', 'JPN', 'Fukuoka', 142889),
#  (177, 1681, 'Omuta', 'JPN', 'Fukuoka', 142889),
#  (178, 1681, 'Omuta', 'JPN', 'Fukuoka', 142889),
#  (179, 1681, 'Omuta', 'JPN', 'Fukuoka', 142889),
#  (180, 1739, 'Tokuyama', 'JPN', 'Yamaguchi', 107078),
#  (181, 1739, 'Tokuyama', 'JPN', 'Yamaguchi', 107078),
#  (182, 1739, 'Tokuyama', 'JPN', 'Yamaguchi', 107078),
#  (183, 1739, 'Tokuyama', 'JPN', 'Yamaguchi', 107078),
#  (184, 1739, 'Tokuyama', 'JPN', 'Yamaguchi', 107078),
#  (185, 1739, 'Tokuyama', 'JPN', 'Yamaguchi', 107078)]

# %% [markdown]
# ## Problem 5: Query the names and populations of all the Japanese cities in the CITY table. The COUNTRYCODE for Japan is JPN.

# %%
# %%sql
#
# SELECT NAME, POPULATION
# FROM city
# WHERE COUNTRYCODE = "JPN";
# Out:
#  * sqlite:///Problem_set_01.db
# Done.
# [(257315,),
#  (257315,),
#  (257315,),
#  (257315,),
#  (257315,),
#  (257315,),
#  (209442,),
#  (209442,),
#  (209442,),
#  (209442,),
#  (209442,),
#  (209442,),
#  (162472,),
#  (162472,),
#  (162472,),
#  (162472,),
#  (162472,),
#  (162472,),
#  (142889,),
#  (142889,),
#  (142889,),
#  (142889,),
#  (142889,),
#  (142889,),
#  (107078,),
#  (107078,),
#  (107078,),
#  (107078,),
#  (107078,),
#  (107078,)]

# %% [markdown]
# ## Problem 6: Query a count of the number of cities in CITY having a Population larger than 100,000.

# %%
# %%sql
#
# SELECT COUNT(DISTINCT(ID)) AS Japan_Population
# FROM city
# WHERE POPULATION > 100000;
# Out:
#  * sqlite:///Problem_set_01.db
# Done.
# [(68,)]

# %% [markdown]
# ## Problem 7: Query the total population of all cities in CITY where District is California.

# %%
# %%sql
#
# SELECT SUM(POPULATION) AS California_Population
# FROM city
# WHERE DISTRICT = "California";
# Out:
#  * sqlite:///Problem_set_01.db
# Done.
# [(2034012,)]

# %% [markdown]
# ## Problem 8: Query the average population of all cities in CITY where District is California

# %%
# %%sql
#
# SELECT AVG(POPULATION) AS Average_Population
# FROM city
# WHERE DISTRICT = "California";
# Out:
#  * sqlite:///Problem_set_01.db
# Done.
# [(113000.66666666667,)]

# %% [markdown]
# ## Problem 9: Query the average population for all cities in CITY, rounded down to the nearest integer

# %%
# %%sql
#
# SELECT ROUND(AVG(POPULATION)) AS Rounded_Avg
# FROM city;
# Out:
#  * sqlite:///Problem_set_01.db
# Done.
# [(454250.0,)]

# %% [markdown]
# ## Problem 10: Query the sum of the populations for all Japanese cities in CITY. The COUNTRYCODE for Japan is JPN.

# %%
# %%sql
#
# SELECT SUM(POPULATION) AS Japan_Population
# FROM city
# WHERE COUNTRYCODE = "JPN";
# Out:
#  * sqlite:///Problem_set_01.db
# Done.
# [(5275176,)]

# %% [markdown]
# ## Problem 11: Query the difference between the maximum and minimum populations in CITY

# %%
# %%sql
#
# SELECT (MAX(POPULATION)-MIN(POPULATION)) AS Difference
# FROM city;
# Out:
#  * sqlite:///Problem_set_01.db
# Done.
# [(4695354,)]
