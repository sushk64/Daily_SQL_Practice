# %% [markdown]
# # Problemset_02_Practice

# %%
#importing all the libraries
import pandas as pd
import sqlite3

# %%
#installing ipython-sql library 
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: sqlparse in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.4.1)
# Requirement already satisfied: six in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: prettytable<1 in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.3.20)
# Requirement already satisfied: ipython>=1.0 in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (7.19.0)
# Requirement already satisfied: pickleshare in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.0.5)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (3.0.8)
# Requirement already satisfied: jedi>=0.10 in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.17.1)
# Requirement already satisfied: backcall in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (50.3.1.post20201107)
# Requirement already satisfied: pygments in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (2.7.2)
# Requirement already satisfied: decorator in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.4.2)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=1.0->ipython-sql) (0.6.0)
# Requirement already satisfied: wcwidth in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/sushantkumbhar/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.7.0)

# %%
df = pd.read_csv(r'/Users/sushantkumbhar/Documents/Stevens Academics/Skills Imporvement/SQL/SQL practice/Day_02_Practice/Data/Dataset_02.csv')

# %%
cnn = sqlite3.connect('Problem_set_02.db')

# %%
df.to_sql('station',cnn)

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///Problem_set_02.db

# %%
# %%sql
# SELECT * FROM station;
# Out:
#  * sqlite:///Problem_set_02.db
# Done.
# [(0, 794, 'Kissee Mills', 'MO', 140, 73),
#  (1, 794, 'Kissee Mills', 'MO', 140, 73),
#  (2, 794, 'Kissee Mills', 'MO', 140, 73),
#  (3, 794, 'Kissee Mills', 'MO', 140, 73),
#  (4, 794, 'Kissee Mills', 'MO', 140, 73),
#  (5, 794, 'Kissee Mills', 'MO', 140, 73),
#  (6, 824, 'Loma Mar', 'CA', 49, 131),
#  (7, 824, 'Loma Mar', 'CA', 49, 131),
#  (8, 824, 'Loma Mar', 'CA', 49, 131),
#  (9, 824, 'Loma Mar', 'CA', 49, 131),
#  (10, 824, 'Loma Mar', 'CA', 49, 131),
#  (11, 824, 'Loma Mar', 'CA', 49, 131),
#  (12, 603, 'Sandy Hook', 'CT', 72, 148),
#  (13, 603, 'Sandy Hook', 'CT', 72, 148),
#  (14, 603, 'Sandy Hook', 'CT', 72, 148),
#  (15, 603, 'Sandy Hook', 'CT', 72, 148),
#  (16, 603, 'Sandy Hook', 'CT', 72, 148),
#  (17, 603, 'Sandy Hook', 'CT', 72, 148),
#  (18, 478, 'Tipton', 'IN', 34, 98),
#  (19, 478, 'Tipton', 'IN', 34, 98),
#  (20, 478, 'Tipton', 'IN', 34, 98),
#  (21, 478, 'Tipton', 'IN', 34, 98),
#  (22, 478, 'Tipton', 'IN', 34, 98),
#  (23, 478, 'Tipton', 'IN', 34, 98),
#  (24, 619, 'Arlington', 'CO', 75, 93),
#  (25, 619, 'Arlington', 'CO', 75, 93),
#  (26, 619, 'Arlington', 'CO', 75, 93),
#  (27, 619, 'Arlington', 'CO', 75, 93),
#  (28, 619, 'Arlington', 'CO', 75, 93),
#  (29, 619, 'Arlington', 'CO', 75, 93),
#  (30, 711, 'Turner', 'AR', 50, 101),
#  (31, 711, 'Turner', 'AR', 50, 101),
#  (32, 711, 'Turner', 'AR', 50, 101),
#  (33, 711, 'Turner', 'AR', 50, 101),
#  (34, 711, 'Turner', 'AR', 50, 101),
#  (35, 711, 'Turner', 'AR', 50, 101),
#  (36, 839, 'Slidell', 'LA', 85, 152),
#  (37, 839, 'Slidell', 'LA', 85, 152),
#  (38, 839, 'Slidell', 'LA', 85, 152),
#  (39, 839, 'Slidell', 'LA', 85, 152),
#  (40, 839, 'Slidell', 'LA', 85, 152),
#  (41, 839, 'Slidell', 'LA', 85, 152),
#  (42, 411, 'Negreet', 'LA', 99, 105),
#  (43, 411, 'Negreet', 'LA', 99, 105),
#  (44, 411, 'Negreet', 'LA', 99, 105),
#  (45, 411, 'Negreet', 'LA', 99, 105),
#  (46, 411, 'Negreet', 'LA', 99, 105),
#  (47, 411, 'Negreet', 'LA', 99, 105),
#  (48, 588, 'Glencoe', 'KY', 46, 136),
#  (49, 588, 'Glencoe', 'KY', 46, 136),
#  (50, 588, 'Glencoe', 'KY', 46, 136),
#  (51, 588, 'Glencoe', 'KY', 46, 136),
#  (52, 588, 'Glencoe', 'KY', 46, 136),
#  (53, 588, 'Glencoe', 'KY', 46, 136),
#  (54, 665, 'Chelsea', 'IA', 99, 60),
#  (55, 665, 'Chelsea', 'IA', 99, 60),
#  (56, 665, 'Chelsea', 'IA', 99, 60),
#  (57, 665, 'Chelsea', 'IA', 99, 60),
#  (58, 665, 'Chelsea', 'IA', 99, 60),
#  (59, 665, 'Chelsea', 'IA', 99, 60),
#  (60, 342, 'Chignik Lagoon', 'AK', 103, 153),
#  (61, 342, 'Chignik Lagoon', 'AK', 103, 153),
#  (62, 342, 'Chignik Lagoon', 'AK', 103, 153),
#  (63, 342, 'Chignik Lagoon', 'AK', 103, 153),
#  (64, 342, 'Chignik Lagoon', 'AK', 103, 153),
#  (65, 342, 'Chignik Lagoon', 'AK', 103, 153),
#  (66, 733, 'Pelahatchie', 'MS', 39, 28),
#  (67, 733, 'Pelahatchie', 'MS', 39, 28),
#  (68, 733, 'Pelahatchie', 'MS', 39, 28),
#  (69, 733, 'Pelahatchie', 'MS', 39, 28),
#  (70, 733, 'Pelahatchie', 'MS', 39, 28),
#  (71, 733, 'Pelahatchie', 'MS', 39, 28),
#  (72, 441, 'Hanna City', 'IL', 51, 137),
#  (73, 441, 'Hanna City', 'IL', 51, 137),
#  (74, 441, 'Hanna City', 'IL', 51, 137),
#  (75, 441, 'Hanna City', 'IL', 51, 137),
#  (76, 441, 'Hanna City', 'IL', 51, 137),
#  (77, 441, 'Hanna City', 'IL', 51, 137),
#  (78, 811, 'Dorrance', 'KS', 102, 122),
#  (79, 811, 'Dorrance', 'KS', 102, 122),
#  (80, 811, 'Dorrance', 'KS', 102, 122),
#  (81, 811, 'Dorrance', 'KS', 102, 122),
#  (82, 811, 'Dorrance', 'KS', 102, 122),
#  (83, 811, 'Dorrance', 'KS', 102, 122),
#  (84, 698, 'Albany', 'CA', 50, 80),
#  (85, 698, 'Albany', 'CA', 50, 80),
#  (86, 698, 'Albany', 'CA', 50, 80),
#  (87, 698, 'Albany', 'CA', 50, 80),
#  (88, 698, 'Albany', 'CA', 50, 80),
#  (89, 698, 'Albany', 'CA', 50, 80),
#  (90, 325, 'Monument', 'KS', 71, 142),
#  (91, 325, 'Monument', 'KS', 71, 142),
#  (92, 325, 'Monument', 'KS', 71, 142),
#  (93, 325, 'Monument', 'KS', 71, 142),
#  (94, 325, 'Monument', 'KS', 71, 142),
#  (95, 325, 'Monument', 'KS', 71, 142),
#  (96, 414, 'Manchester', 'MD', 74, 37),
#  (97, 414, 'Manchester', 'MD', 74, 37),
#  (98, 414, 'Manchester', 'MD', 74, 37),
#  (99, 414, 'Manchester', 'MD', 74, 37),
#  (100, 414, 'Manchester', 'MD', 74, 37),
#  (101, 414, 'Manchester', 'MD', 74, 37),
#  (102, 113, 'Prescott', 'IA', 40, 66),
#  (103, 113, 'Prescott', 'IA', 40, 66),
#  (104, 113, 'Prescott', 'IA', 40, 66),
#  (105, 113, 'Prescott', 'IA', 40, 66),
#  (106, 113, 'Prescott', 'IA', 40, 66),
#  (107, 113, 'Prescott', 'IA', 40, 66),
#  (108, 971, 'Graettinger', 'IA', 95, 150),
#  (109, 971, 'Graettinger', 'IA', 95, 150),
#  (110, 971, 'Graettinger', 'IA', 95, 150),
#  (111, 971, 'Graettinger', 'IA', 95, 150),
#  (112, 971, 'Graettinger', 'IA', 95, 150),
#  (113, 971, 'Graettinger', 'IA', 95, 150),
#  (114, 266, 'Cahone', 'CO', 116, 127),
#  (115, 266, 'Cahone', 'CO', 116, 127),
#  (116, 266, 'Cahone', 'CO', 116, 127),
#  (117, 266, 'Cahone', 'CO', 116, 127),
#  (118, 266, 'Cahone', 'CO', 116, 127),
#  (119, 266, 'Cahone', 'CO', 116, 127),
#  (120, 617, 'Sturgis', 'MS', 36, 126),
#  (121, 617, 'Sturgis', 'MS', 36, 126),
#  (122, 617, 'Sturgis', 'MS', 36, 126),
#  (123, 617, 'Sturgis', 'MS', 36, 126),
#  (124, 617, 'Sturgis', 'MS', 36, 126),
#  (125, 617, 'Sturgis', 'MS', 36, 126),
#  (126, 495, 'Upperco', 'MD', 114, 30),
#  (127, 495, 'Upperco', 'MD', 114, 30),
#  (128, 495, 'Upperco', 'MD', 114, 30),
#  (129, 495, 'Upperco', 'MD', 114, 30),
#  (130, 495, 'Upperco', 'MD', 114, 30),
#  (131, 495, 'Upperco', 'MD', 114, 30),
#  (132, 473, 'Highwood', 'IL', 27, 151),
#  (133, 473, 'Highwood', 'IL', 27, 151),
#  (134, 473, 'Highwood', 'IL', 27, 151),
#  (135, 473, 'Highwood', 'IL', 27, 151),
#  (136, 473, 'Highwood', 'IL', 27, 151),
#  (137, 473, 'Highwood', 'IL', 27, 151),
#  (138, 959, 'Waipahu', 'HI', 106, 34),
#  (139, 959, 'Waipahu', 'HI', 106, 34),
#  (140, 959, 'Waipahu', 'HI', 106, 34),
#  (141, 959, 'Waipahu', 'HI', 106, 34),
#  (142, 959, 'Waipahu', 'HI', 106, 34),
#  (143, 959, 'Waipahu', 'HI', 106, 34),
#  (144, 438, 'Bowdon', 'GA', 89, 78),
#  (145, 438, 'Bowdon', 'GA', 89, 78),
#  (146, 438, 'Bowdon', 'GA', 89, 78),
#  (147, 438, 'Bowdon', 'GA', 89, 78),
#  (148, 438, 'Bowdon', 'GA', 89, 78),
#  (149, 438, 'Bowdon', 'GA', 89, 78),
#  (150, 571, 'Tyler', 'MN', 133, 59),
#  (151, 571, 'Tyler', 'MN', 133, 59),
#  (152, 571, 'Tyler', 'MN', 133, 59),
#  (153, 571, 'Tyler', 'MN', 133, 59),
#  (154, 571, 'Tyler', 'MN', 133, 59),
#  (155, 571, 'Tyler', 'MN', 133, 59),
#  (156, 92, 'Watkins', 'CO', 83, 97),
#  (157, 92, 'Watkins', 'CO', 83, 97),
#  (158, 92, 'Watkins', 'CO', 83, 97),
#  (159, 92, 'Watkins', 'CO', 83, 97),
#  (160, 92, 'Watkins', 'CO', 83, 97),
#  (161, 92, 'Watkins', 'CO', 83, 97),
#  (162, 399, 'Republic', 'MI', 75, 130),
#  (163, 399, 'Republic', 'MI', 75, 130),
#  (164, 399, 'Republic', 'MI', 75, 130),
#  (165, 399, 'Republic', 'MI', 75, 130),
#  (166, 399, 'Republic', 'MI', 75, 130),
#  (167, 399, 'Republic', 'MI', 75, 130),
#  (168, 426, 'Millville', 'CA', 33, 146),
#  (169, 426, 'Millville', 'CA', 33, 146),
#  (170, 426, 'Millville', 'CA', 33, 146),
#  (171, 426, 'Millville', 'CA', 33, 146),
#  (172, 426, 'Millville', 'CA', 33, 146),
#  (173, 426, 'Millville', 'CA', 33, 146),
#  (174, 844, 'Aguanga', 'CA', 80, 66),
#  (175, 844, 'Aguanga', 'CA', 80, 66),
#  (176, 844, 'Aguanga', 'CA', 80, 66),
#  (177, 844, 'Aguanga', 'CA', 80, 66),
#  (178, 844, 'Aguanga', 'CA', 80, 66),
#  (179, 844, 'Aguanga', 'CA', 80, 66),
#  (180, 321, 'Bowdon Junction', 'GA', 86, 34),
#  (181, 321, 'Bowdon Junction', 'GA', 86, 34),
#  (182, 321, 'Bowdon Junction', 'GA', 86, 34),
#  (183, 321, 'Bowdon Junction', 'GA', 86, 34),
#  (184, 321, 'Bowdon Junction', 'GA', 86, 34),
#  (185, 321, 'Bowdon Junction', 'GA', 86, 34),
#  (186, 606, 'Morenci', 'AZ', 105, 110),
#  (187, 606, 'Morenci', 'AZ', 105, 110),
#  (188, 606, 'Morenci', 'AZ', 105, 110),
#  (189, 606, 'Morenci', 'AZ', 105, 110),
#  (190, 606, 'Morenci', 'AZ', 105, 110),
#  (191, 606, 'Morenci', 'AZ', 105, 110),
#  (192, 957, 'South El Monte', 'CA', 74, 80),
#  (193, 957, 'South El Monte', 'CA', 74, 80),
#  (194, 957, 'South El Monte', 'CA', 74, 80),
#  (195, 957, 'South El Monte', 'CA', 74, 80),
#  (196, 957, 'South El Monte', 'CA', 74, 80),
#  (197, 957, 'South El Monte', 'CA', 74, 80),
#  (198, 833, 'Hoskinston', 'KY', 66, 66),
#  (199, 833, 'Hoskinston', 'KY', 66, 66),
#  (200, 833, 'Hoskinston', 'KY', 66, 66),
#  (201, 833, 'Hoskinston', 'KY', 66, 66),
#  (202, 833, 'Hoskinston', 'KY', 66, 66),
#  (203, 833, 'Hoskinston', 'KY', 66, 66),
#  (204, 843, 'Talbert', 'KY', 40, 59),
#  (205, 843, 'Talbert', 'KY', 40, 59),
#  (206, 843, 'Talbert', 'KY', 40, 59),
#  (207, 843, 'Talbert', 'KY', 40, 59),
#  (208, 843, 'Talbert', 'KY', 40, 59),
#  (209, 843, 'Talbert', 'KY', 40, 59),
#  (210, 166, 'Mccomb', 'MS', 74, 43),
#  (211, 166, 'Mccomb', 'MS', 74, 43),
#  (212, 166, 'Mccomb', 'MS', 74, 43),
#  (213, 166, 'Mccomb', 'MS', 74, 43),
#  (214, 166, 'Mccomb', 'MS', 74, 43),
#  (215, 166, 'Mccomb', 'MS', 74, 43),
#  (216, 339, 'Kirk', 'CO', 141, 136),
#  (217, 339, 'Kirk', 'CO', 141, 136),
#  (218, 339, 'Kirk', 'CO', 141, 136),
#  (219, 339, 'Kirk', 'CO', 141, 136),
#  (220, 339, 'Kirk', 'CO', 141, 136),
#  (221, 339, 'Kirk', 'CO', 141, 136),
#  (222, 909, 'Carlock', 'IL', 117, 85),
#  (223, 909, 'Carlock', 'IL', 117, 85),
#  (224, 909, 'Carlock', 'IL', 117, 85),
#  (225, 909, 'Carlock', 'IL', 117, 85),
#  (226, 909, 'Carlock', 'IL', 117, 85),
#  (227, 909, 'Carlock', 'IL', 117, 85),
#  (228, 829, 'Seward', 'IL', 72, 90),
#  (229, 829, 'Seward', 'IL', 72, 90),
#  (230, 829, 'Seward', 'IL', 72, 90),
#  (231, 829, 'Seward', 'IL', 72, 90),
#  (232, 829, 'Seward', 'IL', 72, 90),
#  (233, 829, 'Seward', 'IL', 72, 90),
#  (234, 766, 'Gustine', 'CA', 111, 141),
#  (235, 766, 'Gustine', 'CA', 111, 141),
#  (236, 766, 'Gustine', 'CA', 111, 141),
#  (237, 766, 'Gustine', 'CA', 111, 141),
#  (238, 766, 'Gustine', 'CA', 111, 141),
#  (239, 766, 'Gustine', 'CA', 111, 141),
#  (240, 392, 'Delano', 'CA', 126, 92),
#  (241, 392, 'Delano', 'CA', 126, 92),
#  (242, 392, 'Delano', 'CA', 126, 92),
#  (243, 392, 'Delano', 'CA', 126, 92),
#  (244, 392, 'Delano', 'CA', 126, 92),
#  (245, 392, 'Delano', 'CA', 126, 92),
#  (246, 555, 'Westphalia', 'MI', 33, 144),
#  (247, 555, 'Westphalia', 'MI', 33, 144),
#  (248, 555, 'Westphalia', 'MI', 33, 144),
#  (249, 555, 'Westphalia', 'MI', 33, 144),
#  (250, 555, 'Westphalia', 'MI', 33, 144),
#  (251, 555, 'Westphalia', 'MI', 33, 144),
#  (252, 33, 'Saint Elmo', 'AL', 27, 51),
#  (253, 33, 'Saint Elmo', 'AL', 27, 51),
#  (254, 33, 'Saint Elmo', 'AL', 27, 51),
#  (255, 33, 'Saint Elmo', 'AL', 27, 51),
#  (256, 33, 'Saint Elmo', 'AL', 27, 51),
#  (257, 33, 'Saint Elmo', 'AL', 27, 51),
#  (258, 728, 'Roy', 'MT', 41, 52),
#  (259, 728, 'Roy', 'MT', 41, 52),
#  (260, 728, 'Roy', 'MT', 41, 52),
#  (261, 728, 'Roy', 'MT', 41, 52),
#  (262, 728, 'Roy', 'MT', 41, 52),
#  (263, 728, 'Roy', 'MT', 41, 52),
#  (264, 656, 'Pattonsburg', 'MO', 138, 32),
#  (265, 656, 'Pattonsburg', 'MO', 138, 32),
#  (266, 656, 'Pattonsburg', 'MO', 138, 32),
#  (267, 656, 'Pattonsburg', 'MO', 138, 32),
#  (268, 656, 'Pattonsburg', 'MO', 138, 32),
#  (269, 656, 'Pattonsburg', 'MO', 138, 32),
#  (270, 394, 'Centertown', 'MO', 134, 93),
#  (271, 394, 'Centertown', 'MO', 134, 93),
#  (272, 394, 'Centertown', 'MO', 134, 93),
#  (273, 394, 'Centertown', 'MO', 134, 93),
#  (274, 394, 'Centertown', 'MO', 134, 93),
#  (275, 394, 'Centertown', 'MO', 134, 93),
#  (276, 366, 'Norvell', 'MI', 125, 94),
#  (277, 366, 'Norvell', 'MI', 125, 94),
#  (278, 366, 'Norvell', 'MI', 125, 94),
#  (279, 366, 'Norvell', 'MI', 125, 94),
#  (280, 366, 'Norvell', 'MI', 125, 94),
#  (281, 366, 'Norvell', 'MI', 125, 94),
#  (282, 96, 'Raymondville', 'MO', 71, 148),
#  (283, 96, 'Raymondville', 'MO', 71, 148),
#  (284, 96, 'Raymondville', 'MO', 71, 148),
#  (285, 96, 'Raymondville', 'MO', 71, 148),
#  (286, 96, 'Raymondville', 'MO', 71, 148),
#  (287, 96, 'Raymondville', 'MO', 71, 148),
#  (288, 867, 'Beaver Island', 'MI', 82, 165),
#  (289, 867, 'Beaver Island', 'MI', 82, 165),
#  (290, 867, 'Beaver Island', 'MI', 82, 165),
#  (291, 867, 'Beaver Island', 'MI', 82, 165),
#  (292, 867, 'Beaver Island', 'MI', 82, 165),
#  (293, 867, 'Beaver Island', 'MI', 82, 165),
#  (294, 977, 'Odin', 'IL', 53, 116),
#  (295, 977, 'Odin', 'IL', 53, 116),
#  (296, 977, 'Odin', 'IL', 53, 116),
#  (297, 977, 'Odin', 'IL', 53, 116),
#  (298, 977, 'Odin', 'IL', 53, 116),
#  (299, 977, 'Odin', 'IL', 53, 116),
#  (300, 741, 'Jemison', 'AL', 62, 26),
#  (301, 741, 'Jemison', 'AL', 62, 26),
#  (302, 741, 'Jemison', 'AL', 62, 26),
#  (303, 741, 'Jemison', 'AL', 62, 26),
#  (304, 741, 'Jemison', 'AL', 62, 26),
#  (305, 741, 'Jemison', 'AL', 62, 26),
#  (306, 436, 'West Hills', 'CA', 68, 73),
#  (307, 436, 'West Hills', 'CA', 68, 73),
#  (308, 436, 'West Hills', 'CA', 68, 73),
#  (309, 436, 'West Hills', 'CA', 68, 73),
#  (310, 436, 'West Hills', 'CA', 68, 73),
#  (311, 436, 'West Hills', 'CA', 68, 73),
#  (312, 323, 'Barrigada', 'GU', 61, 148),
#  (313, 323, 'Barrigada', 'GU', 61, 148),
#  (314, 323, 'Barrigada', 'GU', 61, 148),
#  (315, 323, 'Barrigada', 'GU', 61, 148),
#  (316, 323, 'Barrigada', 'GU', 61, 148),
#  (317, 323, 'Barrigada', 'GU', 61, 148),
#  (318, 3, 'Hesperia', 'CA', 106, 71),
#  (319, 3, 'Hesperia', 'CA', 106, 71),
#  (320, 3, 'Hesperia', 'CA', 106, 71),
#  (321, 3, 'Hesperia', 'CA', 106, 71),
#  (322, 3, 'Hesperia', 'CA', 106, 71),
#  (323, 3, 'Hesperia', 'CA', 106, 71),
#  (324, 814, 'Wickliffe', 'KY', 80, 46),
#  (325, 814, 'Wickliffe', 'KY', 80, 46),
#  (326, 814, 'Wickliffe', 'KY', 80, 46),
#  (327, 814, 'Wickliffe', 'KY', 80, 46),
#  (328, 814, 'Wickliffe', 'KY', 80, 46),
#  (329, 814, 'Wickliffe', 'KY', 80, 46),
#  (330, 375, 'Culdesac', 'ID', 48, 78),
#  (331, 375, 'Culdesac', 'ID', 48, 78),
#  (332, 375, 'Culdesac', 'ID', 48, 78),
#  (333, 375, 'Culdesac', 'ID', 48, 78),
#  (334, 375, 'Culdesac', 'ID', 48, 78),
#  (335, 375, 'Culdesac', 'ID', 48, 78),
#  (336, 467, 'Roselawn', 'IN', 88, 52),
#  (337, 467, 'Roselawn', 'IN', 88, 52),
#  (338, 467, 'Roselawn', 'IN', 88, 52),
#  (339, 467, 'Roselawn', 'IN', 88, 52),
#  (340, 467, 'Roselawn', 'IN', 88, 52),
#  (341, 467, 'Roselawn', 'IN', 88, 52),
#  (342, 604, 'Forest Lakes', 'AZ', 145, 114),
#  (343, 604, 'Forest Lakes', 'AZ', 145, 114),
#  (344, 604, 'Forest Lakes', 'AZ', 145, 114),
#  (345, 604, 'Forest Lakes', 'AZ', 145, 114),
#  (346, 604, 'Forest Lakes', 'AZ', 145, 114),
#  (347, 604, 'Forest Lakes', 'AZ', 145, 114),
#  (348, 551, 'San Simeon', 'CA', 38, 28),
#  (349, 551, 'San Simeon', 'CA', 38, 28),
#  (350, 551, 'San Simeon', 'CA', 38, 28),
#  (351, 551, 'San Simeon', 'CA', 38, 28),
#  (352, 551, 'San Simeon', 'CA', 38, 28),
#  (353, 551, 'San Simeon', 'CA', 38, 28),
#  (354, 706, 'Little Rock', 'AR', 122, 121),
#  (355, 706, 'Little Rock', 'AR', 122, 121),
#  (356, 706, 'Little Rock', 'AR', 122, 121),
#  (357, 706, 'Little Rock', 'AR', 122, 121),
#  (358, 706, 'Little Rock', 'AR', 122, 121),
#  (359, 706, 'Little Rock', 'AR', 122, 121),
#  (360, 647, 'Portland', 'AR', 84, 45),
#  (361, 647, 'Portland', 'AR', 84, 45),
#  (362, 647, 'Portland', 'AR', 84, 45),
#  (363, 647, 'Portland', 'AR', 84, 45),
#  (364, 647, 'Portland', 'AR', 84, 45),
#  (365, 647, 'Portland', 'AR', 84, 45),
#  (366, 25, 'New Century', 'KS', 135, 79),
#  (367, 25, 'New Century', 'KS', 135, 79),
#  (368, 25, 'New Century', 'KS', 135, 79),
#  (369, 25, 'New Century', 'KS', 135, 79),
#  (370, 25, 'New Century', 'KS', 135, 79),
#  (371, 25, 'New Century', 'KS', 135, 79),
#  (372, 250, 'Hampden', 'MA', 76, 26),
#  (373, 250, 'Hampden', 'MA', 76, 26),
#  (374, 250, 'Hampden', 'MA', 76, 26),
#  (375, 250, 'Hampden', 'MA', 76, 26),
#  (376, 250, 'Hampden', 'MA', 76, 26),
#  (377, 250, 'Hampden', 'MA', 76, 26),
#  (378, 124, 'Pine City', 'MN', 119, 129),
#  (379, 124, 'Pine City', 'MN', 119, 129),
#  (380, 124, 'Pine City', 'MN', 119, 129),
#  (381, 124, 'Pine City', 'MN', 119, 129),
#  (382, 124, 'Pine City', 'MN', 119, 129),
#  (383, 124, 'Pine City', 'MN', 119, 129),
#  (384, 547, 'Sandborn', 'IN', 56, 94),
#  (385, 547, 'Sandborn', 'IN', 56, 94),
#  (386, 547, 'Sandborn', 'IN', 56, 94),
#  (387, 547, 'Sandborn', 'IN', 56, 94),
#  (388, 547, 'Sandborn', 'IN', 56, 94),
#  (389, 547, 'Sandborn', 'IN', 56, 94),
#  (390, 701, 'Seaton', 'IL', 128, 78),
#  (391, 701, 'Seaton', 'IL', 128, 78),
#  (392, 701, 'Seaton', 'IL', 128, 78),
#  (393, 701, 'Seaton', 'IL', 128, 78),
#  (394, 701, 'Seaton', 'IL', 128, 78),
#  (395, 701, 'Seaton', 'IL', 128, 78),
#  (396, 197, 'Milledgeville', 'IL', 91, 113),
#  (397, 197, 'Milledgeville', 'IL', 91, 113),
#  (398, 197, 'Milledgeville', 'IL', 91, 113),
#  (399, 197, 'Milledgeville', 'IL', 91, 113),
#  (400, 197, 'Milledgeville', 'IL', 91, 113),
#  (401, 197, 'Milledgeville', 'IL', 91, 113),
#  (402, 613, 'East China', 'MI', 109, 42),
#  (403, 613, 'East China', 'MI', 109, 42),
#  (404, 613, 'East China', 'MI', 109, 42),
#  (405, 613, 'East China', 'MI', 109, 42),
#  (406, 613, 'East China', 'MI', 109, 42),
#  (407, 613, 'East China', 'MI', 109, 42),
#  (408, 630, 'Prince Frederick', 'MD', 105, 58),
#  (409, 630, 'Prince Frederick', 'MD', 105, 58),
#  (410, 630, 'Prince Frederick', 'MD', 105, 58),
#  (411, 630, 'Prince Frederick', 'MD', 105, 58),
#  (412, 630, 'Prince Frederick', 'MD', 105, 58),
#  (413, 630, 'Prince Frederick', 'MD', 105, 58),
#  (414, 767, 'Pomona Park', 'FL', 101, 163),
#  (415, 767, 'Pomona Park', 'FL', 101, 163),
#  (416, 767, 'Pomona Park', 'FL', 101, 163),
#  (417, 767, 'Pomona Park', 'FL', 101, 163),
#  (418, 767, 'Pomona Park', 'FL', 101, 163),
#  (419, 767, 'Pomona Park', 'FL', 101, 163),
#  (420, 679, 'Gretna', 'LA', 75, 143),
#  (421, 679, 'Gretna', 'LA', 75, 143),
#  (422, 679, 'Gretna', 'LA', 75, 143),
#  (423, 679, 'Gretna', 'LA', 75, 143),
#  (424, 679, 'Gretna', 'LA', 75, 143),
#  (425, 679, 'Gretna', 'LA', 75, 143),
#  (426, 896, 'Yazoo City', 'MS', 95, 85),
#  (427, 896, 'Yazoo City', 'MS', 95, 85),
#  (428, 896, 'Yazoo City', 'MS', 95, 85),
#  (429, 896, 'Yazoo City', 'MS', 95, 85),
#  (430, 896, 'Yazoo City', 'MS', 95, 85),
#  (431, 896, 'Yazoo City', 'MS', 95, 85),
#  (432, 403, 'Zionsville', 'IN', 58, 36),
#  (433, 403, 'Zionsville', 'IN', 58, 36),
#  (434, 403, 'Zionsville', 'IN', 58, 36),
#  (435, 403, 'Zionsville', 'IN', 58, 36),
#  (436, 403, 'Zionsville', 'IN', 58, 36),
#  (437, 403, 'Zionsville', 'IN', 58, 36),
#  (438, 519, 'Rio Oso', 'CA', 29, 106),
#  (439, 519, 'Rio Oso', 'CA', 29, 106),
#  (440, 519, 'Rio Oso', 'CA', 29, 106),
#  (441, 519, 'Rio Oso', 'CA', 29, 106),
#  (442, 519, 'Rio Oso', 'CA', 29, 106),
#  (443, 519, 'Rio Oso', 'CA', 29, 106),
#  (444, 482, 'Jolon', 'CA', 67, 53),
#  (445, 482, 'Jolon', 'CA', 67, 53),
#  (446, 482, 'Jolon', 'CA', 67, 53),
#  (447, 482, 'Jolon', 'CA', 67, 53),
#  (448, 482, 'Jolon', 'CA', 67, 53),
#  (449, 482, 'Jolon', 'CA', 67, 53),
#  (450, 252, 'Childs', 'MD', 93, 104),
#  (451, 252, 'Childs', 'MD', 93, 104),
#  (452, 252, 'Childs', 'MD', 93, 104),
#  (453, 252, 'Childs', 'MD', 93, 104),
#  (454, 252, 'Childs', 'MD', 93, 104),
#  (455, 252, 'Childs', 'MD', 93, 104),
#  (456, 600, 'Shreveport', 'LA', 136, 39),
#  (457, 600, 'Shreveport', 'LA', 136, 39),
#  (458, 600, 'Shreveport', 'LA', 136, 39),
#  (459, 600, 'Shreveport', 'LA', 136, 39),
#  (460, 600, 'Shreveport', 'LA', 136, 39),
#  (461, 600, 'Shreveport', 'LA', 136, 39),
#  (462, 14, 'Forest', 'MS', 120, 50),
#  (463, 14, 'Forest', 'MS', 120, 50),
#  (464, 14, 'Forest', 'MS', 120, 50),
#  (465, 14, 'Forest', 'MS', 120, 50),
#  (466, 14, 'Forest', 'MS', 120, 50),
#  (467, 14, 'Forest', 'MS', 120, 50),
#  (468, 260, 'Sizerock', 'KY', 116, 113),
#  (469, 260, 'Sizerock', 'KY', 116, 113),
#  (470, 260, 'Sizerock', 'KY', 116, 113),
#  (471, 260, 'Sizerock', 'KY', 116, 113),
#  (472, 260, 'Sizerock', 'KY', 116, 113),
#  (473, 260, 'Sizerock', 'KY', 116, 113),
#  (474, 65, 'Buffalo Creek', 'CO', 48, 148),
#  (475, 65, 'Buffalo Creek', 'CO', 48, 148),
#  (476, 65, 'Buffalo Creek', 'CO', 48, 148),
#  (477, 65, 'Buffalo Creek', 'CO', 48, 148),
#  (478, 65, 'Buffalo Creek', 'CO', 48, 148),
#  (479, 65, 'Buffalo Creek', 'CO', 48, 148),
#  (480, 753, 'Algonac', 'MI', 119, 80),
#  (481, 753, 'Algonac', 'MI', 119, 80),
#  (482, 753, 'Algonac', 'MI', 119, 80),
#  (483, 753, 'Algonac', 'MI', 119, 80),
#  (484, 753, 'Algonac', 'MI', 119, 80),
#  (485, 753, 'Algonac', 'MI', 119, 80),
#  (486, 174, 'Onaway', 'MI', 109, 56),
#  (487, 174, 'Onaway', 'MI', 109, 56),
#  (488, 174, 'Onaway', 'MI', 109, 56),
#  (489, 174, 'Onaway', 'MI', 109, 56),
#  (490, 174, 'Onaway', 'MI', 109, 56),
#  (491, 174, 'Onaway', 'MI', 109, 56),
#  (492, 263, 'Irvington', 'IL', 97, 68),
#  (493, 263, 'Irvington', 'IL', 97, 68),
#  (494, 263, 'Irvington', 'IL', 97, 68),
#  (495, 263, 'Irvington', 'IL', 97, 68),
#  (496, 263, 'Irvington', 'IL', 97, 68),
#  (497, 263, 'Irvington', 'IL', 97, 68),
#  (498, 253, 'Winsted', 'MN', 69, 73),
#  (499, 253, 'Winsted', 'MN', 69, 73),
#  (500, 253, 'Winsted', 'MN', 69, 73),
#  (501, 253, 'Winsted', 'MN', 69, 73),
#  (502, 253, 'Winsted', 'MN', 69, 73),
#  (503, 253, 'Winsted', 'MN', 69, 73),
#  (504, 557, 'Woodbury', 'GA', 103, 93),
#  (505, 557, 'Woodbury', 'GA', 103, 93),
#  (506, 557, 'Woodbury', 'GA', 103, 93),
#  (507, 557, 'Woodbury', 'GA', 103, 93),
#  (508, 557, 'Woodbury', 'GA', 103, 93),
#  (509, 557, 'Woodbury', 'GA', 103, 93),
#  (510, 897, 'Samantha', 'AL', 75, 36),
#  (511, 897, 'Samantha', 'AL', 75, 36),
#  (512, 897, 'Samantha', 'AL', 75, 36),
#  (513, 897, 'Samantha', 'AL', 75, 36),
#  (514, 897, 'Samantha', 'AL', 75, 36),
#  (515, 897, 'Samantha', 'AL', 75, 36),
#  (516, 98, 'Hackleburg', 'AL', 120, 121),
#  (517, 98, 'Hackleburg', 'AL', 120, 121),
#  (518, 98, 'Hackleburg', 'AL', 120, 121),
#  (519, 98, 'Hackleburg', 'AL', 120, 121),
#  (520, 98, 'Hackleburg', 'AL', 120, 121),
#  (521, 98, 'Hackleburg', 'AL', 120, 121),
#  (522, 423, 'Soldier', 'KS', 77, 153),
#  (523, 423, 'Soldier', 'KS', 77, 153),
#  (524, 423, 'Soldier', 'KS', 77, 153),
#  (525, 423, 'Soldier', 'KS', 77, 153),
#  (526, 423, 'Soldier', 'KS', 77, 153),
#  (527, 423, 'Soldier', 'KS', 77, 153),
#  (528, 361, 'Arrowsmith', 'IL', 28, 109),
#  (529, 361, 'Arrowsmith', 'IL', 28, 109),
#  (530, 361, 'Arrowsmith', 'IL', 28, 109),
#  (531, 361, 'Arrowsmith', 'IL', 28, 109),
#  (532, 361, 'Arrowsmith', 'IL', 28, 109),
#  (533, 361, 'Arrowsmith', 'IL', 28, 109),
#  (534, 409, 'Columbus', 'GA', 67, 47),
#  (535, 409, 'Columbus', 'GA', 67, 47),
#  (536, 409, 'Columbus', 'GA', 67, 47),
#  (537, 409, 'Columbus', 'GA', 67, 47),
#  (538, 409, 'Columbus', 'GA', 67, 47),
#  (539, 409, 'Columbus', 'GA', 67, 47),
#  (540, 312, 'Bentonville', 'AR', 37, 78),
#  (541, 312, 'Bentonville', 'AR', 37, 78),
#  (542, 312, 'Bentonville', 'AR', 37, 78),
#  (543, 312, 'Bentonville', 'AR', 37, 78),
#  (544, 312, 'Bentonville', 'AR', 37, 78),
#  (545, 312, 'Bentonville', 'AR', 37, 78),
#  (546, 854, 'Kirkland', 'AZ', 86, 58),
#  (547, 854, 'Kirkland', 'AZ', 86, 58),
#  (548, 854, 'Kirkland', 'AZ', 86, 58),
#  (549, 854, 'Kirkland', 'AZ', 86, 58),
#  (550, 854, 'Kirkland', 'AZ', 86, 58),
#  (551, 854, 'Kirkland', 'AZ', 86, 58),
#  (552, 160, 'Grosse Pointe', 'MI', 102, 91),
#  (553, 160, 'Grosse Pointe', 'MI', 102, 91),
#  (554, 160, 'Grosse Pointe', 'MI', 102, 91),
#  (555, 160, 'Grosse Pointe', 'MI', 102, 91),
#  (556, 160, 'Grosse Pointe', 'MI', 102, 91),
#  (557, 160, 'Grosse Pointe', 'MI', 102, 91),
#  (558, 735, 'Wilton', 'ME', 57, 157),
#  (559, 735, 'Wilton', 'ME', 57, 157),
#  (560, 735, 'Wilton', 'ME', 57, 157),
#  (561, 735, 'Wilton', 'ME', 57, 157),
#  (562, 735, 'Wilton', 'ME', 57, 157),
#  (563, 735, 'Wilton', 'ME', 57, 157),
#  (564, 608, 'Busby', 'MT', 104, 30),
#  (565, 608, 'Busby', 'MT', 104, 30),
#  (566, 608, 'Busby', 'MT', 104, 30),
#  (567, 608, 'Busby', 'MT', 104, 30),
#  (568, 608, 'Busby', 'MT', 104, 30),
#  (569, 608, 'Busby', 'MT', 104, 30),
#  (570, 122, 'Robertsdale', 'AL', 98, 85),
#  (571, 122, 'Robertsdale', 'AL', 98, 85),
#  (572, 122, 'Robertsdale', 'AL', 98, 85),
#  (573, 122, 'Robertsdale', 'AL', 98, 85),
#  (574, 122, 'Robertsdale', 'AL', 98, 85),
#  (575, 122, 'Robertsdale', 'AL', 98, 85),
#  (576, 93, 'Dale', 'IN', 70, 34),
#  (577, 93, 'Dale', 'IN', 70, 34),
#  (578, 93, 'Dale', 'IN', 70, 34),
#  (579, 93, 'Dale', 'IN', 70, 34),
#  (580, 93, 'Dale', 'IN', 70, 34),
#  (581, 93, 'Dale', 'IN', 70, 34),
#  (582, 67, 'Reeds', 'MO', 31, 43),
#  (583, 67, 'Reeds', 'MO', 31, 43),
#  (584, 67, 'Reeds', 'MO', 31, 43),
#  (585, 67, 'Reeds', 'MO', 31, 43),
#  (586, 67, 'Reeds', 'MO', 31, 43),
#  (587, 67, 'Reeds', 'MO', 31, 43),
#  (588, 906, 'Hayfork', 'CA', 35, 117),
#  (589, 906, 'Hayfork', 'CA', 35, 117),
#  (590, 906, 'Hayfork', 'CA', 35, 117),
#  (591, 906, 'Hayfork', 'CA', 35, 117),
#  (592, 906, 'Hayfork', 'CA', 35, 117),
#  (593, 906, 'Hayfork', 'CA', 35, 117),
#  (594, 34, 'Mcbrides', 'MI', 74, 36),
#  (595, 34, 'Mcbrides', 'MI', 74, 36),
#  (596, 34, 'Mcbrides', 'MI', 74, 36),
#  (597, 34, 'Mcbrides', 'MI', 74, 36),
#  (598, 34, 'Mcbrides', 'MI', 74, 36),
#  (599, 34, 'Mcbrides', 'MI', 74, 36),
#  (600, 921, 'Lee Center', 'IL', 96, 77),
#  (601, 921, 'Lee Center', 'IL', 96, 77),
#  (602, 921, 'Lee Center', 'IL', 96, 77),
#  (603, 921, 'Lee Center', 'IL', 96, 77),
#  (604, 921, 'Lee Center', 'IL', 96, 77),
#  (605, 921, 'Lee Center', 'IL', 96, 77),
#  (606, 401, 'Tennessee', 'IL', 55, 156),
#  (607, 401, 'Tennessee', 'IL', 55, 156),
#  (608, 401, 'Tennessee', 'IL', 55, 156),
#  (609, 401, 'Tennessee', 'IL', 55, 156),
#  (610, 401, 'Tennessee', 'IL', 55, 156),
#  (611, 401, 'Tennessee', 'IL', 55, 156),
#  (612, 536, 'Henderson', 'IA', 78, 78),
#  (613, 536, 'Henderson', 'IA', 78, 78),
#  (614, 536, 'Henderson', 'IA', 78, 78),
#  (615, 536, 'Henderson', 'IA', 78, 78),
#  (616, 536, 'Henderson', 'IA', 78, 78),
#  (617, 536, 'Henderson', 'IA', 78, 78),
#  (618, 953, 'Udall', 'KS', 113, 60),
#  (619, 953, 'Udall', 'KS', 113, 60),
#  (620, 953, 'Udall', 'KS', 113, 60),
#  (621, 953, 'Udall', 'KS', 113, 60),
#  (622, 953, 'Udall', 'KS', 113, 60),
#  (623, 953, 'Udall', 'KS', 113, 60),
#  (624, 370, 'Palm Desert', 'CA', 107, 146),
#  (625, 370, 'Palm Desert', 'CA', 107, 146),
#  (626, 370, 'Palm Desert', 'CA', 107, 146),
#  (627, 370, 'Palm Desert', 'CA', 107, 146),
#  (628, 370, 'Palm Desert', 'CA', 107, 146),
#  (629, 370, 'Palm Desert', 'CA', 107, 146),
#  (630, 614, 'Benedict', 'KS', 138, 96),
#  (631, 614, 'Benedict', 'KS', 138, 96),
#  (632, 614, 'Benedict', 'KS', 138, 96),
#  (633, 614, 'Benedict', 'KS', 138, 96),
#  (634, 614, 'Benedict', 'KS', 138, 96),
#  (635, 614, 'Benedict', 'KS', 138, 96),
#  (636, 998, 'Oakfield', 'ME', 48, 132),
#  (637, 998, 'Oakfield', 'ME', 48, 132),
#  (638, 998, 'Oakfield', 'ME', 48, 132),
#  (639, 998, 'Oakfield', 'ME', 48, 132),
#  (640, 998, 'Oakfield', 'ME', 48, 132),
#  (641, 998, 'Oakfield', 'ME', 48, 132),
#  (642, 805, 'Tamms', 'IL', 60, 75),
#  (643, 805, 'Tamms', 'IL', 60, 75),
#  (644, 805, 'Tamms', 'IL', 60, 75),
#  (645, 805, 'Tamms', 'IL', 60, 75),
#  (646, 805, 'Tamms', 'IL', 60, 75),
#  (647, 805, 'Tamms', 'IL', 60, 75),
#  (648, 235, 'Haubstadt', 'IN', 28, 32),
#  (649, 235, 'Haubstadt', 'IN', 28, 32),
#  (650, 235, 'Haubstadt', 'IN', 28, 32),
#  (651, 235, 'Haubstadt', 'IN', 28, 32),
#  (652, 235, 'Haubstadt', 'IN', 28, 32),
#  (653, 235, 'Haubstadt', 'IN', 28, 32),
#  (654, 820, 'Chokio', 'MN', 81, 134),
#  (655, 820, 'Chokio', 'MN', 81, 134),
#  (656, 820, 'Chokio', 'MN', 81, 134),
#  (657, 820, 'Chokio', 'MN', 81, 134),
#  (658, 820, 'Chokio', 'MN', 81, 134),
#  (659, 820, 'Chokio', 'MN', 81, 134),
#  (660, 650, 'Clancy', 'MT', 46, 164),
#  (661, 650, 'Clancy', 'MT', 46, 164),
#  (662, 650, 'Clancy', 'MT', 46, 164),
#  (663, 650, 'Clancy', 'MT', 46, 164),
#  (664, 650, 'Clancy', 'MT', 46, 164),
#  (665, 650, 'Clancy', 'MT', 46, 164),
#  (666, 791, 'Scotts Valley', 'CA', 120, 91),
#  (667, 791, 'Scotts Valley', 'CA', 120, 91),
#  (668, 791, 'Scotts Valley', 'CA', 120, 91),
#  (669, 791, 'Scotts Valley', 'CA', 120, 91),
#  (670, 791, 'Scotts Valley', 'CA', 120, 91),
#  (671, 791, 'Scotts Valley', 'CA', 120, 91),
#  (672, 324, 'Norwood', 'MN', 144, 35),
#  (673, 324, 'Norwood', 'MN', 144, 35),
#  (674, 324, 'Norwood', 'MN', 144, 35),
#  (675, 324, 'Norwood', 'MN', 144, 35),
#  (676, 324, 'Norwood', 'MN', 144, 35),
#  (677, 324, 'Norwood', 'MN', 144, 35),
#  (678, 442, 'Elkton', 'MD', 103, 157),
#  (679, 442, 'Elkton', 'MD', 103, 157),
#  (680, 442, 'Elkton', 'MD', 103, 157),
#  (681, 442, 'Elkton', 'MD', 103, 157),
#  (682, 442, 'Elkton', 'MD', 103, 157),
#  (683, 442, 'Elkton', 'MD', 103, 157),
#  (684, 633, 'Bertha', 'MN', 40, 105),
#  (685, 633, 'Bertha', 'MN', 40, 105),
#  (686, 633, 'Bertha', 'MN', 40, 105),
#  (687, 633, 'Bertha', 'MN', 40, 105),
#  (688, 633, 'Bertha', 'MN', 40, 105),
#  (689, 633, 'Bertha', 'MN', 40, 105),
#  (690, 109, 'Bridgeport', 'MI', 51, 80),
#  (691, 109, 'Bridgeport', 'MI', 51, 80),
#  (692, 109, 'Bridgeport', 'MI', 51, 80),
#  (693, 109, 'Bridgeport', 'MI', 51, 80),
#  (694, 109, 'Bridgeport', 'MI', 51, 80),
#  (695, 109, 'Bridgeport', 'MI', 51, 80),
#  (696, 780, 'Cherry', 'IL', 68, 47),
#  (697, 780, 'Cherry', 'IL', 68, 47),
#  (698, 780, 'Cherry', 'IL', 68, 47),
#  (699, 780, 'Cherry', 'IL', 68, 47),
#  (700, 780, 'Cherry', 'IL', 68, 47),
#  (701, 780, 'Cherry', 'IL', 68, 47),
#  (702, 492, 'Regina', 'KY', 132, 90),
#  (703, 492, 'Regina', 'KY', 132, 90),
#  (704, 492, 'Regina', 'KY', 132, 90),
#  (705, 492, 'Regina', 'KY', 132, 90),
#  (706, 492, 'Regina', 'KY', 132, 90),
#  (707, 492, 'Regina', 'KY', 132, 90),
#  (708, 965, 'Griffin', 'GA', 39, 152),
#  (709, 965, 'Griffin', 'GA', 39, 152),
#  (710, 965, 'Griffin', 'GA', 39, 152),
#  (711, 965, 'Griffin', 'GA', 39, 152),
#  (712, 965, 'Griffin', 'GA', 39, 152),
#  (713, 965, 'Griffin', 'GA', 39, 152),
#  (714, 778, 'Pine Bluff', 'AR', 60, 146),
#  (715, 778, 'Pine Bluff', 'AR', 60, 146),
#  (716, 778, 'Pine Bluff', 'AR', 60, 146),
#  (717, 778, 'Pine Bluff', 'AR', 60, 146),
#  (718, 778, 'Pine Bluff', 'AR', 60, 146),
#  (719, 778, 'Pine Bluff', 'AR', 60, 146),
#  (720, 337, 'Mascotte', 'FL', 121, 146),
#  (721, 337, 'Mascotte', 'FL', 121, 146),
#  (722, 337, 'Mascotte', 'FL', 121, 146),
#  (723, 337, 'Mascotte', 'FL', 121, 146),
#  (724, 337, 'Mascotte', 'FL', 121, 146),
#  (725, 337, 'Mascotte', 'FL', 121, 146),
#  (726, 259, 'Baldwin', 'MD', 82, 40),
#  (727, 259, 'Baldwin', 'MD', 82, 40),
#  (728, 259, 'Baldwin', 'MD', 82, 40),
#  (729, 259, 'Baldwin', 'MD', 82, 40),
#  (730, 259, 'Baldwin', 'MD', 82, 40),
#  (731, 259, 'Baldwin', 'MD', 82, 40),
#  (732, 955, 'Netawaka', 'KS', 109, 120),
#  (733, 955, 'Netawaka', 'KS', 109, 120),
#  (734, 955, 'Netawaka', 'KS', 109, 120),
#  (735, 955, 'Netawaka', 'KS', 109, 120),
#  (736, 955, 'Netawaka', 'KS', 109, 120),
#  (737, 955, 'Netawaka', 'KS', 109, 120),
#  (738, 752, 'East Irvine', 'CA', 106, 115),
#  (739, 752, 'East Irvine', 'CA', 106, 115),
#  (740, 752, 'East Irvine', 'CA', 106, 115),
#  (741, 752, 'East Irvine', 'CA', 106, 115),
#  (742, 752, 'East Irvine', 'CA', 106, 115),
#  (743, 752, 'East Irvine', 'CA', 106, 115),
#  (744, 886, 'Pony', 'MT', 99, 163),
#  (745, 886, 'Pony', 'MT', 99, 163),
#  (746, 886, 'Pony', 'MT', 99, 163),
#  (747, 886, 'Pony', 'MT', 99, 163),
#  (748, 886, 'Pony', 'MT', 99, 163),
#  (749, 886, 'Pony', 'MT', 99, 163),
#  (750, 200, 'Franklin', 'LA', 82, 32),
#  (751, 200, 'Franklin', 'LA', 82, 32),
#  (752, 200, 'Franklin', 'LA', 82, 32),
#  (753, 200, 'Franklin', 'LA', 82, 32),
#  (754, 200, 'Franklin', 'LA', 82, 32),
#  (755, 200, 'Franklin', 'LA', 82, 32),
#  (756, 384, 'Amo', 'IN', 104, 159),
#  (757, 384, 'Amo', 'IN', 104, 159),
#  (758, 384, 'Amo', 'IN', 104, 159),
#  (759, 384, 'Amo', 'IN', 104, 159),
#  (760, 384, 'Amo', 'IN', 104, 159),
#  (761, 384, 'Amo', 'IN', 104, 159),
#  (762, 518, 'Vulcan', 'MO', 109, 92),
#  (763, 518, 'Vulcan', 'MO', 109, 92),
#  (764, 518, 'Vulcan', 'MO', 109, 92),
#  (765, 518, 'Vulcan', 'MO', 109, 92),
#  (766, 518, 'Vulcan', 'MO', 109, 92),
#  (767, 518, 'Vulcan', 'MO', 109, 92),
#  (768, 188, 'Prairie Du Rocher', 'IL', 76, 71),
#  (769, 188, 'Prairie Du Rocher', 'IL', 76, 71),
#  (770, 188, 'Prairie Du Rocher', 'IL', 76, 71),
#  (771, 188, 'Prairie Du Rocher', 'IL', 76, 71),
#  (772, 188, 'Prairie Du Rocher', 'IL', 76, 71),
#  (773, 188, 'Prairie Du Rocher', 'IL', 76, 71),
#  (774, 161, 'Alanson', 'MI', 91, 72),
#  (775, 161, 'Alanson', 'MI', 91, 72),
#  (776, 161, 'Alanson', 'MI', 91, 72),
#  (777, 161, 'Alanson', 'MI', 91, 72),
#  (778, 161, 'Alanson', 'MI', 91, 72),
#  (779, 161, 'Alanson', 'MI', 91, 72),
#  (780, 486, 'Delta', 'LA', 137, 50),
#  (781, 486, 'Delta', 'LA', 137, 50),
#  (782, 486, 'Delta', 'LA', 137, 50),
#  (783, 486, 'Delta', 'LA', 137, 50),
#  (784, 486, 'Delta', 'LA', 137, 50),
#  (785, 486, 'Delta', 'LA', 137, 50),
#  (786, 406, 'Carver', 'MN', 46, 122),
#  (787, 406, 'Carver', 'MN', 46, 122),
#  (788, 406, 'Carver', 'MN', 46, 122),
#  (789, 406, 'Carver', 'MN', 46, 122),
#  (790, 406, 'Carver', 'MN', 46, 122),
#  (791, 406, 'Carver', 'MN', 46, 122),
#  (792, 940, 'Paron', 'AR', 59, 104),
#  (793, 940, 'Paron', 'AR', 59, 104),
#  (794, 940, 'Paron', 'AR', 59, 104),
#  (795, 940, 'Paron', 'AR', 59, 104),
#  (796, 940, 'Paron', 'AR', 59, 104),
#  (797, 940, 'Paron', 'AR', 59, 104),
#  (798, 237, 'Winchester', 'ID', 38, 80),
#  (799, 237, 'Winchester', 'ID', 38, 80),
#  (800, 237, 'Winchester', 'ID', 38, 80),
#  (801, 237, 'Winchester', 'ID', 38, 80),
#  (802, 237, 'Winchester', 'ID', 38, 80),
#  (803, 237, 'Winchester', 'ID', 38, 80),
#  (804, 465, 'Jerome', 'AZ', 122, 34),
#  (805, 465, 'Jerome', 'AZ', 122, 34),
#  (806, 465, 'Jerome', 'AZ', 122, 34),
#  (807, 465, 'Jerome', 'AZ', 122, 34),
#  (808, 465, 'Jerome', 'AZ', 122, 34),
#  (809, 465, 'Jerome', 'AZ', 122, 34),
#  (810, 591, 'Baton Rouge', 'LA', 130, 72),
#  (811, 591, 'Baton Rouge', 'LA', 130, 72),
#  (812, 591, 'Baton Rouge', 'LA', 130, 72),
#  (813, 591, 'Baton Rouge', 'LA', 130, 72),
#  (814, 591, 'Baton Rouge', 'LA', 130, 72),
#  (815, 591, 'Baton Rouge', 'LA', 130, 72),
#  (816, 570, 'Greenview', 'CA', 81, 58),
#  (817, 570, 'Greenview', 'CA', 81, 58),
#  (818, 570, 'Greenview', 'CA', 81, 58),
#  (819, 570, 'Greenview', 'CA', 81, 58),
#  (820, 570, 'Greenview', 'CA', 81, 58),
#  (821, 570, 'Greenview', 'CA', 81, 58),
#  (822, 429, 'Lucerne Valley', 'CA', 36, 48),
#  (823, 429, 'Lucerne Valley', 'CA', 36, 48),
#  (824, 429, 'Lucerne Valley', 'CA', 36, 48),
#  (825, 429, 'Lucerne Valley', 'CA', 36, 48),
#  (826, 429, 'Lucerne Valley', 'CA', 36, 48),
#  (827, 429, 'Lucerne Valley', 'CA', 36, 48),
#  (828, 278, 'Cromwell', 'MN', 129, 54),
#  (829, 278, 'Cromwell', 'MN', 129, 54),
#  (830, 278, 'Cromwell', 'MN', 129, 54),
#  (831, 278, 'Cromwell', 'MN', 129, 54),
#  (832, 278, 'Cromwell', 'MN', 129, 54),
#  (833, 278, 'Cromwell', 'MN', 129, 54),
#  (834, 927, 'Quinter', 'KS', 60, 25),
#  (835, 927, 'Quinter', 'KS', 60, 25),
#  (836, 927, 'Quinter', 'KS', 60, 25),
#  (837, 927, 'Quinter', 'KS', 60, 25),
#  (838, 927, 'Quinter', 'KS', 60, 25),
#  (839, 927, 'Quinter', 'KS', 60, 25),
#  (840, 59, 'Whitewater', 'MO', 83, 71),
#  (841, 59, 'Whitewater', 'MO', 83, 71),
#  (842, 59, 'Whitewater', 'MO', 83, 71),
#  (843, 59, 'Whitewater', 'MO', 83, 71),
#  (844, 59, 'Whitewater', 'MO', 83, 71),
#  (845, 59, 'Whitewater', 'MO', 83, 71),
#  (846, 218, 'Round Pond', 'ME', 127, 124),
#  (847, 218, 'Round Pond', 'ME', 127, 124),
#  (848, 218, 'Round Pond', 'ME', 127, 124),
#  (849, 218, 'Round Pond', 'ME', 127, 124),
#  (850, 218, 'Round Pond', 'ME', 127, 124),
#  (851, 218, 'Round Pond', 'ME', 127, 124),
#  (852, 291, 'Clarkdale', 'AZ', 58, 74),
#  (853, 291, 'Clarkdale', 'AZ', 58, 74),
#  (854, 291, 'Clarkdale', 'AZ', 58, 74),
#  (855, 291, 'Clarkdale', 'AZ', 58, 74),
#  (856, 291, 'Clarkdale', 'AZ', 58, 74),
#  (857, 291, 'Clarkdale', 'AZ', 58, 74),
#  (858, 668, 'Rockton', 'IL', 116, 87),
#  (859, 668, 'Rockton', 'IL', 116, 87),
#  (860, 668, 'Rockton', 'IL', 116, 87),
#  (861, 668, 'Rockton', 'IL', 116, 87),
#  (862, 668, 'Rockton', 'IL', 116, 87),
#  (863, 668, 'Rockton', 'IL', 116, 87),
#  (864, 682, 'Pheba', 'MS', 91, 127),
#  (865, 682, 'Pheba', 'MS', 91, 127),
#  (866, 682, 'Pheba', 'MS', 91, 127),
#  (867, 682, 'Pheba', 'MS', 91, 127),
#  (868, 682, 'Pheba', 'MS', 91, 127),
#  (869, 682, 'Pheba', 'MS', 91, 127),
#  (870, 775, 'Eleele', 'HI', 81, 153),
#  (871, 775, 'Eleele', 'HI', 81, 153),
#  (872, 775, 'Eleele', 'HI', 81, 153),
#  (873, 775, 'Eleele', 'HI', 81, 153),
#  (874, 775, 'Eleele', 'HI', 81, 153),
#  (875, 775, 'Eleele', 'HI', 81, 153),
#  (876, 527, 'Auburn', 'IA', 95, 137),
#  (877, 527, 'Auburn', 'IA', 95, 137),
#  (878, 527, 'Auburn', 'IA', 95, 137),
#  (879, 527, 'Auburn', 'IA', 95, 137),
#  (880, 527, 'Auburn', 'IA', 95, 137),
#  (881, 527, 'Auburn', 'IA', 95, 137),
#  (882, 108, 'North Berwick', 'ME', 71, 27),
#  (883, 108, 'North Berwick', 'ME', 71, 27),
#  (884, 108, 'North Berwick', 'ME', 71, 27),
#  (885, 108, 'North Berwick', 'ME', 71, 27),
#  (886, 108, 'North Berwick', 'ME', 71, 27),
#  (887, 108, 'North Berwick', 'ME', 71, 27),
#  (888, 190, 'Oconee', 'GA', 93, 119),
#  (889, 190, 'Oconee', 'GA', 93, 119),
#  (890, 190, 'Oconee', 'GA', 93, 119),
#  (891, 190, 'Oconee', 'GA', 93, 119),
#  (892, 190, 'Oconee', 'GA', 93, 119),
#  (893, 190, 'Oconee', 'GA', 93, 119),
#  (894, 232, 'Grandville', 'MI', 39, 70),
#  (895, 232, 'Grandville', 'MI', 39, 70),
#  (896, 232, 'Grandville', 'MI', 39, 70),
#  (897, 232, 'Grandville', 'MI', 39, 70),
#  (898, 232, 'Grandville', 'MI', 39, 70),
#  (899, 232, 'Grandville', 'MI', 39, 70),
#  (900, 405, 'Susanville', 'CA', 128, 80),
#  (901, 405, 'Susanville', 'CA', 128, 80),
#  (902, 405, 'Susanville', 'CA', 128, 80),
#  (903, 405, 'Susanville', 'CA', 128, 80),
#  (904, 405, 'Susanville', 'CA', 128, 80),
#  (905, 405, 'Susanville', 'CA', 128, 80),
#  (906, 273, 'Rosie', 'AR', 73, 162),
#  (907, 273, 'Rosie', 'AR', 73, 162),
#  (908, 273, 'Rosie', 'AR', 73, 162),
#  (909, 273, 'Rosie', 'AR', 73, 162),
#  (910, 273, 'Rosie', 'AR', 73, 162),
#  (911, 273, 'Rosie', 'AR', 73, 162),
#  (912, 813, 'Verona', 'MO', 110, 153),
#  (913, 813, 'Verona', 'MO', 110, 153),
#  (914, 813, 'Verona', 'MO', 110, 153),
#  (915, 813, 'Verona', 'MO', 110, 153),
#  (916, 813, 'Verona', 'MO', 110, 153),
#  (917, 813, 'Verona', 'MO', 110, 153),
#  (918, 444, 'Richland', 'GA', 105, 113),
#  (919, 444, 'Richland', 'GA', 105, 113),
#  (920, 444, 'Richland', 'GA', 105, 113),
#  (921, 444, 'Richland', 'GA', 105, 113),
#  (922, 444, 'Richland', 'GA', 105, 113),
#  (923, 444, 'Richland', 'GA', 105, 113),
#  (924, 899, 'Fremont', 'MI', 54, 151),
#  (925, 899, 'Fremont', 'MI', 54, 151),
#  (926, 899, 'Fremont', 'MI', 54, 151),
#  (927, 899, 'Fremont', 'MI', 54, 151),
#  (928, 899, 'Fremont', 'MI', 54, 151),
#  (929, 899, 'Fremont', 'MI', 54, 151),
#  (930, 738, 'Philipsburg', 'MT', 96, 72),
#  (931, 738, 'Philipsburg', 'MT', 96, 72),
#  (932, 738, 'Philipsburg', 'MT', 96, 72),
#  (933, 738, 'Philipsburg', 'MT', 96, 72),
#  (934, 738, 'Philipsburg', 'MT', 96, 72),
#  (935, 738, 'Philipsburg', 'MT', 96, 72),
#  (936, 215, 'Kensett', 'IA', 56, 140),
#  (937, 215, 'Kensett', 'IA', 56, 140),
#  (938, 215, 'Kensett', 'IA', 56, 140),
#  (939, 215, 'Kensett', 'IA', 56, 140),
#  (940, 215, 'Kensett', 'IA', 56, 140),
#  (941, 215, 'Kensett', 'IA', 56, 140),
#  (942, 743, 'De Tour Village', 'MI', 25, 25),
#  (943, 743, 'De Tour Village', 'MI', 25, 25),
#  (944, 743, 'De Tour Village', 'MI', 25, 25),
#  (945, 743, 'De Tour Village', 'MI', 25, 25),
#  (946, 743, 'De Tour Village', 'MI', 25, 25),
#  (947, 743, 'De Tour Village', 'MI', 25, 25),
#  (948, 377, 'Koleen', 'IN', 138, 111),
#  (949, 377, 'Koleen', 'IN', 138, 111),
#  (950, 377, 'Koleen', 'IN', 138, 111),
#  (951, 377, 'Koleen', 'IN', 138, 111),
#  (952, 377, 'Koleen', 'IN', 138, 111),
#  (953, 377, 'Koleen', 'IN', 138, 111),
#  (954, 727, 'Winslow', 'IL', 113, 39),
#  (955, 727, 'Winslow', 'IL', 113, 39),
#  (956, 727, 'Winslow', 'IL', 113, 39),
#  (957, 727, 'Winslow', 'IL', 113, 39),
#  (958, 727, 'Winslow', 'IL', 113, 39),
#  (959, 727, 'Winslow', 'IL', 113, 39),
#  (960, 363, 'Reasnor', 'IA', 42, 163),
#  (961, 363, 'Reasnor', 'IA', 42, 163),
#  (962, 363, 'Reasnor', 'IA', 42, 163),
#  (963, 363, 'Reasnor', 'IA', 42, 163),
#  (964, 363, 'Reasnor', 'IA', 42, 163),
#  (965, 363, 'Reasnor', 'IA', 42, 163),
#  (966, 117, 'West Grove', 'IA', 127, 99),
#  (967, 117, 'West Grove', 'IA', 127, 99),
#  (968, 117, 'West Grove', 'IA', 127, 99),
#  (969, 117, 'West Grove', 'IA', 127, 99),
#  (970, 117, 'West Grove', 'IA', 127, 99),
#  (971, 117, 'West Grove', 'IA', 127, 99),
#  (972, 420, 'Frankfort Heights', 'IL', 72, 30),
#  (973, 420, 'Frankfort Heights', 'IL', 72, 30),
#  (974, 420, 'Frankfort Heights', 'IL', 72, 30),
#  (975, 420, 'Frankfort Heights', 'IL', 72, 30),
#  (976, 420, 'Frankfort Heights', 'IL', 72, 30),
#  (977, 420, 'Frankfort Heights', 'IL', 72, 30),
#  (978, 888, 'Bono', 'AR', 133, 150),
#  (979, 888, 'Bono', 'AR', 133, 150),
#  (980, 888, 'Bono', 'AR', 133, 150),
#  (981, 888, 'Bono', 'AR', 133, 150),
#  (982, 888, 'Bono', 'AR', 133, 150),
#  (983, 888, 'Bono', 'AR', 133, 150),
#  (984, 784, 'Biggsville', 'IL', 86, 139),
#  (985, 784, 'Biggsville', 'IL', 86, 139),
#  (986, 784, 'Biggsville', 'IL', 86, 139),
#  (987, 784, 'Biggsville', 'IL', 86, 139),
#  (988, 784, 'Biggsville', 'IL', 86, 139),
#  (989, 784, 'Biggsville', 'IL', 86, 139),
#  (990, 413, 'Linthicum Heights', 'MD', 128, 68),
#  (991, 413, 'Linthicum Heights', 'MD', 128, 68),
#  (992, 413, 'Linthicum Heights', 'MD', 128, 68),
#  (993, 413, 'Linthicum Heights', 'MD', 128, 68),
#  (994, 413, 'Linthicum Heights', 'MD', 128, 68),
#  (995, 413, 'Linthicum Heights', 'MD', 128, 68),
#  (996, 695, 'Amazonia', 'MO', 46, 148),
#  (997, 695, 'Amazonia', 'MO', 46, 148),
#  (998, 695, 'Amazonia', 'MO', 46, 148),
#  (999, 695, 'Amazonia', 'MO', 46, 148),
#  ...]

# %% [markdown]
# ## Problem 01: Query a list of CITY and STATE from the STATION table.

# %%
# %%sql
#
# SELECT CITY, STATE
# FROM station;
# Out:
#  * sqlite:///Problem_set_02.db
# Done.
# [('Kissee Mills', 'MO'),
#  ('Kissee Mills', 'MO'),
#  ('Kissee Mills', 'MO'),
#  ('Kissee Mills', 'MO'),
#  ('Kissee Mills', 'MO'),
#  ('Kissee Mills', 'MO'),
#  ('Loma Mar', 'CA'),
#  ('Loma Mar', 'CA'),
#  ('Loma Mar', 'CA'),
#  ('Loma Mar', 'CA'),
#  ('Loma Mar', 'CA'),
#  ('Loma Mar', 'CA'),
#  ('Sandy Hook', 'CT'),
#  ('Sandy Hook', 'CT'),
#  ('Sandy Hook', 'CT'),
#  ('Sandy Hook', 'CT'),
#  ('Sandy Hook', 'CT'),
#  ('Sandy Hook', 'CT'),
#  ('Tipton', 'IN'),
#  ('Tipton', 'IN'),
#  ('Tipton', 'IN'),
#  ('Tipton', 'IN'),
#  ('Tipton', 'IN'),
#  ('Tipton', 'IN'),
#  ('Arlington', 'CO'),
#  ('Arlington', 'CO'),
#  ('Arlington', 'CO'),
#  ('Arlington', 'CO'),
#  ('Arlington', 'CO'),
#  ('Arlington', 'CO'),
#  ('Turner', 'AR'),
#  ('Turner', 'AR'),
#  ('Turner', 'AR'),
#  ('Turner', 'AR'),
#  ('Turner', 'AR'),
#  ('Turner', 'AR'),
#  ('Slidell', 'LA'),
#  ('Slidell', 'LA'),
#  ('Slidell', 'LA'),
#  ('Slidell', 'LA'),
#  ('Slidell', 'LA'),
#  ('Slidell', 'LA'),
#  ('Negreet', 'LA'),
#  ('Negreet', 'LA'),
#  ('Negreet', 'LA'),
#  ('Negreet', 'LA'),
#  ('Negreet', 'LA'),
#  ('Negreet', 'LA'),
#  ('Glencoe', 'KY'),
#  ('Glencoe', 'KY'),
#  ('Glencoe', 'KY'),
#  ('Glencoe', 'KY'),
#  ('Glencoe', 'KY'),
#  ('Glencoe', 'KY'),
#  ('Chelsea', 'IA'),
#  ('Chelsea', 'IA'),
#  ('Chelsea', 'IA'),
#  ('Chelsea', 'IA'),
#  ('Chelsea', 'IA'),
#  ('Chelsea', 'IA'),
#  ('Chignik Lagoon', 'AK'),
#  ('Chignik Lagoon', 'AK'),
#  ('Chignik Lagoon', 'AK'),
#  ('Chignik Lagoon', 'AK'),
#  ('Chignik Lagoon', 'AK'),
#  ('Chignik Lagoon', 'AK'),
#  ('Pelahatchie', 'MS'),
#  ('Pelahatchie', 'MS'),
#  ('Pelahatchie', 'MS'),
#  ('Pelahatchie', 'MS'),
#  ('Pelahatchie', 'MS'),
#  ('Pelahatchie', 'MS'),
#  ('Hanna City', 'IL'),
#  ('Hanna City', 'IL'),
#  ('Hanna City', 'IL'),
#  ('Hanna City', 'IL'),
#  ('Hanna City', 'IL'),
#  ('Hanna City', 'IL'),
#  ('Dorrance', 'KS'),
#  ('Dorrance', 'KS'),
#  ('Dorrance', 'KS'),
#  ('Dorrance', 'KS'),
#  ('Dorrance', 'KS'),
#  ('Dorrance', 'KS'),
#  ('Albany', 'CA'),
#  ('Albany', 'CA'),
#  ('Albany', 'CA'),
#  ('Albany', 'CA'),
#  ('Albany', 'CA'),
#  ('Albany', 'CA'),
#  ('Monument', 'KS'),
#  ('Monument', 'KS'),
#  ('Monument', 'KS'),
#  ('Monument', 'KS'),
#  ('Monument', 'KS'),
#  ('Monument', 'KS'),
#  ('Manchester', 'MD'),
#  ('Manchester', 'MD'),
#  ('Manchester', 'MD'),
#  ('Manchester', 'MD'),
#  ('Manchester', 'MD'),
#  ('Manchester', 'MD'),
#  ('Prescott', 'IA'),
#  ('Prescott', 'IA'),
#  ('Prescott', 'IA'),
#  ('Prescott', 'IA'),
#  ('Prescott', 'IA'),
#  ('Prescott', 'IA'),
#  ('Graettinger', 'IA'),
#  ('Graettinger', 'IA'),
#  ('Graettinger', 'IA'),
#  ('Graettinger', 'IA'),
#  ('Graettinger', 'IA'),
#  ('Graettinger', 'IA'),
#  ('Cahone', 'CO'),
#  ('Cahone', 'CO'),
#  ('Cahone', 'CO'),
#  ('Cahone', 'CO'),
#  ('Cahone', 'CO'),
#  ('Cahone', 'CO'),
#  ('Sturgis', 'MS'),
#  ('Sturgis', 'MS'),
#  ('Sturgis', 'MS'),
#  ('Sturgis', 'MS'),
#  ('Sturgis', 'MS'),
#  ('Sturgis', 'MS'),
#  ('Upperco', 'MD'),
#  ('Upperco', 'MD'),
#  ('Upperco', 'MD'),
#  ('Upperco', 'MD'),
#  ('Upperco', 'MD'),
#  ('Upperco', 'MD'),
#  ('Highwood', 'IL'),
#  ('Highwood', 'IL'),
#  ('Highwood', 'IL'),
#  ('Highwood', 'IL'),
#  ('Highwood', 'IL'),
#  ('Highwood', 'IL'),
#  ('Waipahu', 'HI'),
#  ('Waipahu', 'HI'),
#  ('Waipahu', 'HI'),
#  ('Waipahu', 'HI'),
#  ('Waipahu', 'HI'),
#  ('Waipahu', 'HI'),
#  ('Bowdon', 'GA'),
#  ('Bowdon', 'GA'),
#  ('Bowdon', 'GA'),
#  ('Bowdon', 'GA'),
#  ('Bowdon', 'GA'),
#  ('Bowdon', 'GA'),
#  ('Tyler', 'MN'),
#  ('Tyler', 'MN'),
#  ('Tyler', 'MN'),
#  ('Tyler', 'MN'),
#  ('Tyler', 'MN'),
#  ('Tyler', 'MN'),
#  ('Watkins', 'CO'),
#  ('Watkins', 'CO'),
#  ('Watkins', 'CO'),
#  ('Watkins', 'CO'),
#  ('Watkins', 'CO'),
#  ('Watkins', 'CO'),
#  ('Republic', 'MI'),
#  ('Republic', 'MI'),
#  ('Republic', 'MI'),
#  ('Republic', 'MI'),
#  ('Republic', 'MI'),
#  ('Republic', 'MI'),
#  ('Millville', 'CA'),
#  ('Millville', 'CA'),
#  ('Millville', 'CA'),
#  ('Millville', 'CA'),
#  ('Millville', 'CA'),
#  ('Millville', 'CA'),
#  ('Aguanga', 'CA'),
#  ('Aguanga', 'CA'),
#  ('Aguanga', 'CA'),
#  ('Aguanga', 'CA'),
#  ('Aguanga', 'CA'),
#  ('Aguanga', 'CA'),
#  ('Bowdon Junction', 'GA'),
#  ('Bowdon Junction', 'GA'),
#  ('Bowdon Junction', 'GA'),
#  ('Bowdon Junction', 'GA'),
#  ('Bowdon Junction', 'GA'),
#  ('Bowdon Junction', 'GA'),
#  ('Morenci', 'AZ'),
#  ('Morenci', 'AZ'),
#  ('Morenci', 'AZ'),
#  ('Morenci', 'AZ'),
#  ('Morenci', 'AZ'),
#  ('Morenci', 'AZ'),
#  ('South El Monte', 'CA'),
#  ('South El Monte', 'CA'),
#  ('South El Monte', 'CA'),
#  ('South El Monte', 'CA'),
#  ('South El Monte', 'CA'),
#  ('South El Monte', 'CA'),
#  ('Hoskinston', 'KY'),
#  ('Hoskinston', 'KY'),
#  ('Hoskinston', 'KY'),
#  ('Hoskinston', 'KY'),
#  ('Hoskinston', 'KY'),
#  ('Hoskinston', 'KY'),
#  ('Talbert', 'KY'),
#  ('Talbert', 'KY'),
#  ('Talbert', 'KY'),
#  ('Talbert', 'KY'),
#  ('Talbert', 'KY'),
#  ('Talbert', 'KY'),
#  ('Mccomb', 'MS'),
#  ('Mccomb', 'MS'),
#  ('Mccomb', 'MS'),
#  ('Mccomb', 'MS'),
#  ('Mccomb', 'MS'),
#  ('Mccomb', 'MS'),
#  ('Kirk', 'CO'),
#  ('Kirk', 'CO'),
#  ('Kirk', 'CO'),
#  ('Kirk', 'CO'),
#  ('Kirk', 'CO'),
#  ('Kirk', 'CO'),
#  ('Carlock', 'IL'),
#  ('Carlock', 'IL'),
#  ('Carlock', 'IL'),
#  ('Carlock', 'IL'),
#  ('Carlock', 'IL'),
#  ('Carlock', 'IL'),
#  ('Seward', 'IL'),
#  ('Seward', 'IL'),
#  ('Seward', 'IL'),
#  ('Seward', 'IL'),
#  ('Seward', 'IL'),
#  ('Seward', 'IL'),
#  ('Gustine', 'CA'),
#  ('Gustine', 'CA'),
#  ('Gustine', 'CA'),
#  ('Gustine', 'CA'),
#  ('Gustine', 'CA'),
#  ('Gustine', 'CA'),
#  ('Delano', 'CA'),
#  ('Delano', 'CA'),
#  ('Delano', 'CA'),
#  ('Delano', 'CA'),
#  ('Delano', 'CA'),
#  ('Delano', 'CA'),
#  ('Westphalia', 'MI'),
#  ('Westphalia', 'MI'),
#  ('Westphalia', 'MI'),
#  ('Westphalia', 'MI'),
#  ('Westphalia', 'MI'),
#  ('Westphalia', 'MI'),
#  ('Saint Elmo', 'AL'),
#  ('Saint Elmo', 'AL'),
#  ('Saint Elmo', 'AL'),
#  ('Saint Elmo', 'AL'),
#  ('Saint Elmo', 'AL'),
#  ('Saint Elmo', 'AL'),
#  ('Roy', 'MT'),
#  ('Roy', 'MT'),
#  ('Roy', 'MT'),
#  ('Roy', 'MT'),
#  ('Roy', 'MT'),
#  ('Roy', 'MT'),
#  ('Pattonsburg', 'MO'),
#  ('Pattonsburg', 'MO'),
#  ('Pattonsburg', 'MO'),
#  ('Pattonsburg', 'MO'),
#  ('Pattonsburg', 'MO'),
#  ('Pattonsburg', 'MO'),
#  ('Centertown', 'MO'),
#  ('Centertown', 'MO'),
#  ('Centertown', 'MO'),
#  ('Centertown', 'MO'),
#  ('Centertown', 'MO'),
#  ('Centertown', 'MO'),
#  ('Norvell', 'MI'),
#  ('Norvell', 'MI'),
#  ('Norvell', 'MI'),
#  ('Norvell', 'MI'),
#  ('Norvell', 'MI'),
#  ('Norvell', 'MI'),
#  ('Raymondville', 'MO'),
#  ('Raymondville', 'MO'),
#  ('Raymondville', 'MO'),
#  ('Raymondville', 'MO'),
#  ('Raymondville', 'MO'),
#  ('Raymondville', 'MO'),
#  ('Beaver Island', 'MI'),
#  ('Beaver Island', 'MI'),
#  ('Beaver Island', 'MI'),
#  ('Beaver Island', 'MI'),
#  ('Beaver Island', 'MI'),
#  ('Beaver Island', 'MI'),
#  ('Odin', 'IL'),
#  ('Odin', 'IL'),
#  ('Odin', 'IL'),
#  ('Odin', 'IL'),
#  ('Odin', 'IL'),
#  ('Odin', 'IL'),
#  ('Jemison', 'AL'),
#  ('Jemison', 'AL'),
#  ('Jemison', 'AL'),
#  ('Jemison', 'AL'),
#  ('Jemison', 'AL'),
#  ('Jemison', 'AL'),
#  ('West Hills', 'CA'),
#  ('West Hills', 'CA'),
#  ('West Hills', 'CA'),
#  ('West Hills', 'CA'),
#  ('West Hills', 'CA'),
#  ('West Hills', 'CA'),
#  ('Barrigada', 'GU'),
#  ('Barrigada', 'GU'),
#  ('Barrigada', 'GU'),
#  ('Barrigada', 'GU'),
#  ('Barrigada', 'GU'),
#  ('Barrigada', 'GU'),
#  ('Hesperia', 'CA'),
#  ('Hesperia', 'CA'),
#  ('Hesperia', 'CA'),
#  ('Hesperia', 'CA'),
#  ('Hesperia', 'CA'),
#  ('Hesperia', 'CA'),
#  ('Wickliffe', 'KY'),
#  ('Wickliffe', 'KY'),
#  ('Wickliffe', 'KY'),
#  ('Wickliffe', 'KY'),
#  ('Wickliffe', 'KY'),
#  ('Wickliffe', 'KY'),
#  ('Culdesac', 'ID'),
#  ('Culdesac', 'ID'),
#  ('Culdesac', 'ID'),
#  ('Culdesac', 'ID'),
#  ('Culdesac', 'ID'),
#  ('Culdesac', 'ID'),
#  ('Roselawn', 'IN'),
#  ('Roselawn', 'IN'),
#  ('Roselawn', 'IN'),
#  ('Roselawn', 'IN'),
#  ('Roselawn', 'IN'),
#  ('Roselawn', 'IN'),
#  ('Forest Lakes', 'AZ'),
#  ('Forest Lakes', 'AZ'),
#  ('Forest Lakes', 'AZ'),
#  ('Forest Lakes', 'AZ'),
#  ('Forest Lakes', 'AZ'),
#  ('Forest Lakes', 'AZ'),
#  ('San Simeon', 'CA'),
#  ('San Simeon', 'CA'),
#  ('San Simeon', 'CA'),
#  ('San Simeon', 'CA'),
#  ('San Simeon', 'CA'),
#  ('San Simeon', 'CA'),
#  ('Little Rock', 'AR'),
#  ('Little Rock', 'AR'),
#  ('Little Rock', 'AR'),
#  ('Little Rock', 'AR'),
#  ('Little Rock', 'AR'),
#  ('Little Rock', 'AR'),
#  ('Portland', 'AR'),
#  ('Portland', 'AR'),
#  ('Portland', 'AR'),
#  ('Portland', 'AR'),
#  ('Portland', 'AR'),
#  ('Portland', 'AR'),
#  ('New Century', 'KS'),
#  ('New Century', 'KS'),
#  ('New Century', 'KS'),
#  ('New Century', 'KS'),
#  ('New Century', 'KS'),
#  ('New Century', 'KS'),
#  ('Hampden', 'MA'),
#  ('Hampden', 'MA'),
#  ('Hampden', 'MA'),
#  ('Hampden', 'MA'),
#  ('Hampden', 'MA'),
#  ('Hampden', 'MA'),
#  ('Pine City', 'MN'),
#  ('Pine City', 'MN'),
#  ('Pine City', 'MN'),
#  ('Pine City', 'MN'),
#  ('Pine City', 'MN'),
#  ('Pine City', 'MN'),
#  ('Sandborn', 'IN'),
#  ('Sandborn', 'IN'),
#  ('Sandborn', 'IN'),
#  ('Sandborn', 'IN'),
#  ('Sandborn', 'IN'),
#  ('Sandborn', 'IN'),
#  ('Seaton', 'IL'),
#  ('Seaton', 'IL'),
#  ('Seaton', 'IL'),
#  ('Seaton', 'IL'),
#  ('Seaton', 'IL'),
#  ('Seaton', 'IL'),
#  ('Milledgeville', 'IL'),
#  ('Milledgeville', 'IL'),
#  ('Milledgeville', 'IL'),
#  ('Milledgeville', 'IL'),
#  ('Milledgeville', 'IL'),
#  ('Milledgeville', 'IL'),
#  ('East China', 'MI'),
#  ('East China', 'MI'),
#  ('East China', 'MI'),
#  ('East China', 'MI'),
#  ('East China', 'MI'),
#  ('East China', 'MI'),
#  ('Prince Frederick', 'MD'),
#  ('Prince Frederick', 'MD'),
#  ('Prince Frederick', 'MD'),
#  ('Prince Frederick', 'MD'),
#  ('Prince Frederick', 'MD'),
#  ('Prince Frederick', 'MD'),
#  ('Pomona Park', 'FL'),
#  ('Pomona Park', 'FL'),
#  ('Pomona Park', 'FL'),
#  ('Pomona Park', 'FL'),
#  ('Pomona Park', 'FL'),
#  ('Pomona Park', 'FL'),
#  ('Gretna', 'LA'),
#  ('Gretna', 'LA'),
#  ('Gretna', 'LA'),
#  ('Gretna', 'LA'),
#  ('Gretna', 'LA'),
#  ('Gretna', 'LA'),
#  ('Yazoo City', 'MS'),
#  ('Yazoo City', 'MS'),
#  ('Yazoo City', 'MS'),
#  ('Yazoo City', 'MS'),
#  ('Yazoo City', 'MS'),
#  ('Yazoo City', 'MS'),
#  ('Zionsville', 'IN'),
#  ('Zionsville', 'IN'),
#  ('Zionsville', 'IN'),
#  ('Zionsville', 'IN'),
#  ('Zionsville', 'IN'),
#  ('Zionsville', 'IN'),
#  ('Rio Oso', 'CA'),
#  ('Rio Oso', 'CA'),
#  ('Rio Oso', 'CA'),
#  ('Rio Oso', 'CA'),
#  ('Rio Oso', 'CA'),
#  ('Rio Oso', 'CA'),
#  ('Jolon', 'CA'),
#  ('Jolon', 'CA'),
#  ('Jolon', 'CA'),
#  ('Jolon', 'CA'),
#  ('Jolon', 'CA'),
#  ('Jolon', 'CA'),
#  ('Childs', 'MD'),
#  ('Childs', 'MD'),
#  ('Childs', 'MD'),
#  ('Childs', 'MD'),
#  ('Childs', 'MD'),
#  ('Childs', 'MD'),
#  ('Shreveport', 'LA'),
#  ('Shreveport', 'LA'),
#  ('Shreveport', 'LA'),
#  ('Shreveport', 'LA'),
#  ('Shreveport', 'LA'),
#  ('Shreveport', 'LA'),
#  ('Forest', 'MS'),
#  ('Forest', 'MS'),
#  ('Forest', 'MS'),
#  ('Forest', 'MS'),
#  ('Forest', 'MS'),
#  ('Forest', 'MS'),
#  ('Sizerock', 'KY'),
#  ('Sizerock', 'KY'),
#  ('Sizerock', 'KY'),
#  ('Sizerock', 'KY'),
#  ('Sizerock', 'KY'),
#  ('Sizerock', 'KY'),
#  ('Buffalo Creek', 'CO'),
#  ('Buffalo Creek', 'CO'),
#  ('Buffalo Creek', 'CO'),
#  ('Buffalo Creek', 'CO'),
#  ('Buffalo Creek', 'CO'),
#  ('Buffalo Creek', 'CO'),
#  ('Algonac', 'MI'),
#  ('Algonac', 'MI'),
#  ('Algonac', 'MI'),
#  ('Algonac', 'MI'),
#  ('Algonac', 'MI'),
#  ('Algonac', 'MI'),
#  ('Onaway', 'MI'),
#  ('Onaway', 'MI'),
#  ('Onaway', 'MI'),
#  ('Onaway', 'MI'),
#  ('Onaway', 'MI'),
#  ('Onaway', 'MI'),
#  ('Irvington', 'IL'),
#  ('Irvington', 'IL'),
#  ('Irvington', 'IL'),
#  ('Irvington', 'IL'),
#  ('Irvington', 'IL'),
#  ('Irvington', 'IL'),
#  ('Winsted', 'MN'),
#  ('Winsted', 'MN'),
#  ('Winsted', 'MN'),
#  ('Winsted', 'MN'),
#  ('Winsted', 'MN'),
#  ('Winsted', 'MN'),
#  ('Woodbury', 'GA'),
#  ('Woodbury', 'GA'),
#  ('Woodbury', 'GA'),
#  ('Woodbury', 'GA'),
#  ('Woodbury', 'GA'),
#  ('Woodbury', 'GA'),
#  ('Samantha', 'AL'),
#  ('Samantha', 'AL'),
#  ('Samantha', 'AL'),
#  ('Samantha', 'AL'),
#  ('Samantha', 'AL'),
#  ('Samantha', 'AL'),
#  ('Hackleburg', 'AL'),
#  ('Hackleburg', 'AL'),
#  ('Hackleburg', 'AL'),
#  ('Hackleburg', 'AL'),
#  ('Hackleburg', 'AL'),
#  ('Hackleburg', 'AL'),
#  ('Soldier', 'KS'),
#  ('Soldier', 'KS'),
#  ('Soldier', 'KS'),
#  ('Soldier', 'KS'),
#  ('Soldier', 'KS'),
#  ('Soldier', 'KS'),
#  ('Arrowsmith', 'IL'),
#  ('Arrowsmith', 'IL'),
#  ('Arrowsmith', 'IL'),
#  ('Arrowsmith', 'IL'),
#  ('Arrowsmith', 'IL'),
#  ('Arrowsmith', 'IL'),
#  ('Columbus', 'GA'),
#  ('Columbus', 'GA'),
#  ('Columbus', 'GA'),
#  ('Columbus', 'GA'),
#  ('Columbus', 'GA'),
#  ('Columbus', 'GA'),
#  ('Bentonville', 'AR'),
#  ('Bentonville', 'AR'),
#  ('Bentonville', 'AR'),
#  ('Bentonville', 'AR'),
#  ('Bentonville', 'AR'),
#  ('Bentonville', 'AR'),
#  ('Kirkland', 'AZ'),
#  ('Kirkland', 'AZ'),
#  ('Kirkland', 'AZ'),
#  ('Kirkland', 'AZ'),
#  ('Kirkland', 'AZ'),
#  ('Kirkland', 'AZ'),
#  ('Grosse Pointe', 'MI'),
#  ('Grosse Pointe', 'MI'),
#  ('Grosse Pointe', 'MI'),
#  ('Grosse Pointe', 'MI'),
#  ('Grosse Pointe', 'MI'),
#  ('Grosse Pointe', 'MI'),
#  ('Wilton', 'ME'),
#  ('Wilton', 'ME'),
#  ('Wilton', 'ME'),
#  ('Wilton', 'ME'),
#  ('Wilton', 'ME'),
#  ('Wilton', 'ME'),
#  ('Busby', 'MT'),
#  ('Busby', 'MT'),
#  ('Busby', 'MT'),
#  ('Busby', 'MT'),
#  ('Busby', 'MT'),
#  ('Busby', 'MT'),
#  ('Robertsdale', 'AL'),
#  ('Robertsdale', 'AL'),
#  ('Robertsdale', 'AL'),
#  ('Robertsdale', 'AL'),
#  ('Robertsdale', 'AL'),
#  ('Robertsdale', 'AL'),
#  ('Dale', 'IN'),
#  ('Dale', 'IN'),
#  ('Dale', 'IN'),
#  ('Dale', 'IN'),
#  ('Dale', 'IN'),
#  ('Dale', 'IN'),
#  ('Reeds', 'MO'),
#  ('Reeds', 'MO'),
#  ('Reeds', 'MO'),
#  ('Reeds', 'MO'),
#  ('Reeds', 'MO'),
#  ('Reeds', 'MO'),
#  ('Hayfork', 'CA'),
#  ('Hayfork', 'CA'),
#  ('Hayfork', 'CA'),
#  ('Hayfork', 'CA'),
#  ('Hayfork', 'CA'),
#  ('Hayfork', 'CA'),
#  ('Mcbrides', 'MI'),
#  ('Mcbrides', 'MI'),
#  ('Mcbrides', 'MI'),
#  ('Mcbrides', 'MI'),
#  ('Mcbrides', 'MI'),
#  ('Mcbrides', 'MI'),
#  ('Lee Center', 'IL'),
#  ('Lee Center', 'IL'),
#  ('Lee Center', 'IL'),
#  ('Lee Center', 'IL'),
#  ('Lee Center', 'IL'),
#  ('Lee Center', 'IL'),
#  ('Tennessee', 'IL'),
#  ('Tennessee', 'IL'),
#  ('Tennessee', 'IL'),
#  ('Tennessee', 'IL'),
#  ('Tennessee', 'IL'),
#  ('Tennessee', 'IL'),
#  ('Henderson', 'IA'),
#  ('Henderson', 'IA'),
#  ('Henderson', 'IA'),
#  ('Henderson', 'IA'),
#  ('Henderson', 'IA'),
#  ('Henderson', 'IA'),
#  ('Udall', 'KS'),
#  ('Udall', 'KS'),
#  ('Udall', 'KS'),
#  ('Udall', 'KS'),
#  ('Udall', 'KS'),
#  ('Udall', 'KS'),
#  ('Palm Desert', 'CA'),
#  ('Palm Desert', 'CA'),
#  ('Palm Desert', 'CA'),
#  ('Palm Desert', 'CA'),
#  ('Palm Desert', 'CA'),
#  ('Palm Desert', 'CA'),
#  ('Benedict', 'KS'),
#  ('Benedict', 'KS'),
#  ('Benedict', 'KS'),
#  ('Benedict', 'KS'),
#  ('Benedict', 'KS'),
#  ('Benedict', 'KS'),
#  ('Oakfield', 'ME'),
#  ('Oakfield', 'ME'),
#  ('Oakfield', 'ME'),
#  ('Oakfield', 'ME'),
#  ('Oakfield', 'ME'),
#  ('Oakfield', 'ME'),
#  ('Tamms', 'IL'),
#  ('Tamms', 'IL'),
#  ('Tamms', 'IL'),
#  ('Tamms', 'IL'),
#  ('Tamms', 'IL'),
#  ('Tamms', 'IL'),
#  ('Haubstadt', 'IN'),
#  ('Haubstadt', 'IN'),
#  ('Haubstadt', 'IN'),
#  ('Haubstadt', 'IN'),
#  ('Haubstadt', 'IN'),
#  ('Haubstadt', 'IN'),
#  ('Chokio', 'MN'),
#  ('Chokio', 'MN'),
#  ('Chokio', 'MN'),
#  ('Chokio', 'MN'),
#  ('Chokio', 'MN'),
#  ('Chokio', 'MN'),
#  ('Clancy', 'MT'),
#  ('Clancy', 'MT'),
#  ('Clancy', 'MT'),
#  ('Clancy', 'MT'),
#  ('Clancy', 'MT'),
#  ('Clancy', 'MT'),
#  ('Scotts Valley', 'CA'),
#  ('Scotts Valley', 'CA'),
#  ('Scotts Valley', 'CA'),
#  ('Scotts Valley', 'CA'),
#  ('Scotts Valley', 'CA'),
#  ('Scotts Valley', 'CA'),
#  ('Norwood', 'MN'),
#  ('Norwood', 'MN'),
#  ('Norwood', 'MN'),
#  ('Norwood', 'MN'),
#  ('Norwood', 'MN'),
#  ('Norwood', 'MN'),
#  ('Elkton', 'MD'),
#  ('Elkton', 'MD'),
#  ('Elkton', 'MD'),
#  ('Elkton', 'MD'),
#  ('Elkton', 'MD'),
#  ('Elkton', 'MD'),
#  ('Bertha', 'MN'),
#  ('Bertha', 'MN'),
#  ('Bertha', 'MN'),
#  ('Bertha', 'MN'),
#  ('Bertha', 'MN'),
#  ('Bertha', 'MN'),
#  ('Bridgeport', 'MI'),
#  ('Bridgeport', 'MI'),
#  ('Bridgeport', 'MI'),
#  ('Bridgeport', 'MI'),
#  ('Bridgeport', 'MI'),
#  ('Bridgeport', 'MI'),
#  ('Cherry', 'IL'),
#  ('Cherry', 'IL'),
#  ('Cherry', 'IL'),
#  ('Cherry', 'IL'),
#  ('Cherry', 'IL'),
#  ('Cherry', 'IL'),
#  ('Regina', 'KY'),
#  ('Regina', 'KY'),
#  ('Regina', 'KY'),
#  ('Regina', 'KY'),
#  ('Regina', 'KY'),
#  ('Regina', 'KY'),
#  ('Griffin', 'GA'),
#  ('Griffin', 'GA'),
#  ('Griffin', 'GA'),
#  ('Griffin', 'GA'),
#  ('Griffin', 'GA'),
#  ('Griffin', 'GA'),
#  ('Pine Bluff', 'AR'),
#  ('Pine Bluff', 'AR'),
#  ('Pine Bluff', 'AR'),
#  ('Pine Bluff', 'AR'),
#  ('Pine Bluff', 'AR'),
#  ('Pine Bluff', 'AR'),
#  ('Mascotte', 'FL'),
#  ('Mascotte', 'FL'),
#  ('Mascotte', 'FL'),
#  ('Mascotte', 'FL'),
#  ('Mascotte', 'FL'),
#  ('Mascotte', 'FL'),
#  ('Baldwin', 'MD'),
#  ('Baldwin', 'MD'),
#  ('Baldwin', 'MD'),
#  ('Baldwin', 'MD'),
#  ('Baldwin', 'MD'),
#  ('Baldwin', 'MD'),
#  ('Netawaka', 'KS'),
#  ('Netawaka', 'KS'),
#  ('Netawaka', 'KS'),
#  ('Netawaka', 'KS'),
#  ('Netawaka', 'KS'),
#  ('Netawaka', 'KS'),
#  ('East Irvine', 'CA'),
#  ('East Irvine', 'CA'),
#  ('East Irvine', 'CA'),
#  ('East Irvine', 'CA'),
#  ('East Irvine', 'CA'),
#  ('East Irvine', 'CA'),
#  ('Pony', 'MT'),
#  ('Pony', 'MT'),
#  ('Pony', 'MT'),
#  ('Pony', 'MT'),
#  ('Pony', 'MT'),
#  ('Pony', 'MT'),
#  ('Franklin', 'LA'),
#  ('Franklin', 'LA'),
#  ('Franklin', 'LA'),
#  ('Franklin', 'LA'),
#  ('Franklin', 'LA'),
#  ('Franklin', 'LA'),
#  ('Amo', 'IN'),
#  ('Amo', 'IN'),
#  ('Amo', 'IN'),
#  ('Amo', 'IN'),
#  ('Amo', 'IN'),
#  ('Amo', 'IN'),
#  ('Vulcan', 'MO'),
#  ('Vulcan', 'MO'),
#  ('Vulcan', 'MO'),
#  ('Vulcan', 'MO'),
#  ('Vulcan', 'MO'),
#  ('Vulcan', 'MO'),
#  ('Prairie Du Rocher', 'IL'),
#  ('Prairie Du Rocher', 'IL'),
#  ('Prairie Du Rocher', 'IL'),
#  ('Prairie Du Rocher', 'IL'),
#  ('Prairie Du Rocher', 'IL'),
#  ('Prairie Du Rocher', 'IL'),
#  ('Alanson', 'MI'),
#  ('Alanson', 'MI'),
#  ('Alanson', 'MI'),
#  ('Alanson', 'MI'),
#  ('Alanson', 'MI'),
#  ('Alanson', 'MI'),
#  ('Delta', 'LA'),
#  ('Delta', 'LA'),
#  ('Delta', 'LA'),
#  ('Delta', 'LA'),
#  ('Delta', 'LA'),
#  ('Delta', 'LA'),
#  ('Carver', 'MN'),
#  ('Carver', 'MN'),
#  ('Carver', 'MN'),
#  ('Carver', 'MN'),
#  ('Carver', 'MN'),
#  ('Carver', 'MN'),
#  ('Paron', 'AR'),
#  ('Paron', 'AR'),
#  ('Paron', 'AR'),
#  ('Paron', 'AR'),
#  ('Paron', 'AR'),
#  ('Paron', 'AR'),
#  ('Winchester', 'ID'),
#  ('Winchester', 'ID'),
#  ('Winchester', 'ID'),
#  ('Winchester', 'ID'),
#  ('Winchester', 'ID'),
#  ('Winchester', 'ID'),
#  ('Jerome', 'AZ'),
#  ('Jerome', 'AZ'),
#  ('Jerome', 'AZ'),
#  ('Jerome', 'AZ'),
#  ('Jerome', 'AZ'),
#  ('Jerome', 'AZ'),
#  ('Baton Rouge', 'LA'),
#  ('Baton Rouge', 'LA'),
#  ('Baton Rouge', 'LA'),
#  ('Baton Rouge', 'LA'),
#  ('Baton Rouge', 'LA'),
#  ('Baton Rouge', 'LA'),
#  ('Greenview', 'CA'),
#  ('Greenview', 'CA'),
#  ('Greenview', 'CA'),
#  ('Greenview', 'CA'),
#  ('Greenview', 'CA'),
#  ('Greenview', 'CA'),
#  ('Lucerne Valley', 'CA'),
#  ('Lucerne Valley', 'CA'),
#  ('Lucerne Valley', 'CA'),
#  ('Lucerne Valley', 'CA'),
#  ('Lucerne Valley', 'CA'),
#  ('Lucerne Valley', 'CA'),
#  ('Cromwell', 'MN'),
#  ('Cromwell', 'MN'),
#  ('Cromwell', 'MN'),
#  ('Cromwell', 'MN'),
#  ('Cromwell', 'MN'),
#  ('Cromwell', 'MN'),
#  ('Quinter', 'KS'),
#  ('Quinter', 'KS'),
#  ('Quinter', 'KS'),
#  ('Quinter', 'KS'),
#  ('Quinter', 'KS'),
#  ('Quinter', 'KS'),
#  ('Whitewater', 'MO'),
#  ('Whitewater', 'MO'),
#  ('Whitewater', 'MO'),
#  ('Whitewater', 'MO'),
#  ('Whitewater', 'MO'),
#  ('Whitewater', 'MO'),
#  ('Round Pond', 'ME'),
#  ('Round Pond', 'ME'),
#  ('Round Pond', 'ME'),
#  ('Round Pond', 'ME'),
#  ('Round Pond', 'ME'),
#  ('Round Pond', 'ME'),
#  ('Clarkdale', 'AZ'),
#  ('Clarkdale', 'AZ'),
#  ('Clarkdale', 'AZ'),
#  ('Clarkdale', 'AZ'),
#  ('Clarkdale', 'AZ'),
#  ('Clarkdale', 'AZ'),
#  ('Rockton', 'IL'),
#  ('Rockton', 'IL'),
#  ('Rockton', 'IL'),
#  ('Rockton', 'IL'),
#  ('Rockton', 'IL'),
#  ('Rockton', 'IL'),
#  ('Pheba', 'MS'),
#  ('Pheba', 'MS'),
#  ('Pheba', 'MS'),
#  ('Pheba', 'MS'),
#  ('Pheba', 'MS'),
#  ('Pheba', 'MS'),
#  ('Eleele', 'HI'),
#  ('Eleele', 'HI'),
#  ('Eleele', 'HI'),
#  ('Eleele', 'HI'),
#  ('Eleele', 'HI'),
#  ('Eleele', 'HI'),
#  ('Auburn', 'IA'),
#  ('Auburn', 'IA'),
#  ('Auburn', 'IA'),
#  ('Auburn', 'IA'),
#  ('Auburn', 'IA'),
#  ('Auburn', 'IA'),
#  ('North Berwick', 'ME'),
#  ('North Berwick', 'ME'),
#  ('North Berwick', 'ME'),
#  ('North Berwick', 'ME'),
#  ('North Berwick', 'ME'),
#  ('North Berwick', 'ME'),
#  ('Oconee', 'GA'),
#  ('Oconee', 'GA'),
#  ('Oconee', 'GA'),
#  ('Oconee', 'GA'),
#  ('Oconee', 'GA'),
#  ('Oconee', 'GA'),
#  ('Grandville', 'MI'),
#  ('Grandville', 'MI'),
#  ('Grandville', 'MI'),
#  ('Grandville', 'MI'),
#  ('Grandville', 'MI'),
#  ('Grandville', 'MI'),
#  ('Susanville', 'CA'),
#  ('Susanville', 'CA'),
#  ('Susanville', 'CA'),
#  ('Susanville', 'CA'),
#  ('Susanville', 'CA'),
#  ('Susanville', 'CA'),
#  ('Rosie', 'AR'),
#  ('Rosie', 'AR'),
#  ('Rosie', 'AR'),
#  ('Rosie', 'AR'),
#  ('Rosie', 'AR'),
#  ('Rosie', 'AR'),
#  ('Verona', 'MO'),
#  ('Verona', 'MO'),
#  ('Verona', 'MO'),
#  ('Verona', 'MO'),
#  ('Verona', 'MO'),
#  ('Verona', 'MO'),
#  ('Richland', 'GA'),
#  ('Richland', 'GA'),
#  ('Richland', 'GA'),
#  ('Richland', 'GA'),
#  ('Richland', 'GA'),
#  ('Richland', 'GA'),
#  ('Fremont', 'MI'),
#  ('Fremont', 'MI'),
#  ('Fremont', 'MI'),
#  ('Fremont', 'MI'),
#  ('Fremont', 'MI'),
#  ('Fremont', 'MI'),
#  ('Philipsburg', 'MT'),
#  ('Philipsburg', 'MT'),
#  ('Philipsburg', 'MT'),
#  ('Philipsburg', 'MT'),
#  ('Philipsburg', 'MT'),
#  ('Philipsburg', 'MT'),
#  ('Kensett', 'IA'),
#  ('Kensett', 'IA'),
#  ('Kensett', 'IA'),
#  ('Kensett', 'IA'),
#  ('Kensett', 'IA'),
#  ('Kensett', 'IA'),
#  ('De Tour Village', 'MI'),
#  ('De Tour Village', 'MI'),
#  ('De Tour Village', 'MI'),
#  ('De Tour Village', 'MI'),
#  ('De Tour Village', 'MI'),
#  ('De Tour Village', 'MI'),
#  ('Koleen', 'IN'),
#  ('Koleen', 'IN'),
#  ('Koleen', 'IN'),
#  ('Koleen', 'IN'),
#  ('Koleen', 'IN'),
#  ('Koleen', 'IN'),
#  ('Winslow', 'IL'),
#  ('Winslow', 'IL'),
#  ('Winslow', 'IL'),
#  ('Winslow', 'IL'),
#  ('Winslow', 'IL'),
#  ('Winslow', 'IL'),
#  ('Reasnor', 'IA'),
#  ('Reasnor', 'IA'),
#  ('Reasnor', 'IA'),
#  ('Reasnor', 'IA'),
#  ('Reasnor', 'IA'),
#  ('Reasnor', 'IA'),
#  ('West Grove', 'IA'),
#  ('West Grove', 'IA'),
#  ('West Grove', 'IA'),
#  ('West Grove', 'IA'),
#  ('West Grove', 'IA'),
#  ('West Grove', 'IA'),
#  ('Frankfort Heights', 'IL'),
#  ('Frankfort Heights', 'IL'),
#  ('Frankfort Heights', 'IL'),
#  ('Frankfort Heights', 'IL'),
#  ('Frankfort Heights', 'IL'),
#  ('Frankfort Heights', 'IL'),
#  ('Bono', 'AR'),
#  ('Bono', 'AR'),
#  ('Bono', 'AR'),
#  ('Bono', 'AR'),
#  ('Bono', 'AR'),
#  ('Bono', 'AR'),
#  ('Biggsville', 'IL'),
#  ('Biggsville', 'IL'),
#  ('Biggsville', 'IL'),
#  ('Biggsville', 'IL'),
#  ('Biggsville', 'IL'),
#  ('Biggsville', 'IL'),
#  ('Linthicum Heights', 'MD'),
#  ('Linthicum Heights', 'MD'),
#  ('Linthicum Heights', 'MD'),
#  ('Linthicum Heights', 'MD'),
#  ('Linthicum Heights', 'MD'),
#  ('Linthicum Heights', 'MD'),
#  ('Amazonia', 'MO'),
#  ('Amazonia', 'MO'),
#  ('Amazonia', 'MO'),
#  ('Amazonia', 'MO'),
#  ...]

# %% [markdown]
# ## Problem 02: Query a list of CITY names from STATION for cities that have an even ID number. Print the results in any order, but exclude duplicates from the answer.

# %%
# %%sql
#
# SELECT DISTINCT(CITY)
# FROM station
# WHERE ID%2=0
# ORDER BY CITY;
# Out:
#  * sqlite:///Problem_set_02.db
# Done.
# [('Aguanga',),
#  ('Alba',),
#  ('Albany',),
#  ('Amo',),
#  ('Andersonville',),
#  ('Archie',),
#  ('Athens',),
#  ('Atlantic Mine',),
#  ('Bainbridge',),
#  ('Baker',),
#  ('Bayville',),
#  ('Beaufort',),
#  ('Bellevue',),
#  ('Benedict',),
#  ('Bennington',),
#  ('Bentonville',),
#  ('Biggsville',),
#  ('Bison',),
#  ('Bono',),
#  ('Bowdon',),
#  ('Bridgton',),
#  ('Brownsdale',),
#  ('Brownstown',),
#  ('Busby',),
#  ('Cahone',),
#  ('Calhoun',),
#  ('Cannonsburg',),
#  ('Carver',),
#  ('Centertown',),
#  ('Cherry',),
#  ('Cheswold',),
#  ('Chignik Lagoon',),
#  ('Childs',),
#  ('Chilhowee',),
#  ('Chokio',),
#  ('Church Creek',),
#  ('Clancy',),
#  ('Climax',),
#  ('Clovis',),
#  ('Clutier',),
#  ('Cobalt',),
#  ('Compton',),
#  ('Crane Lake',),
#  ('Cromwell',),
#  ('Crouseville',),
#  ('Curdsville',),
#  ('Daleville',),
#  ('Decatur',),
#  ('Deep River',),
#  ('Delano',),
#  ('Delray Beach',),
#  ('Delta',),
#  ('Dryden',),
#  ('Dumont',),
#  ('Dundee',),
#  ('East Haddam',),
#  ('East Irvine',),
#  ('Eastlake',),
#  ('Elkton',),
#  ('Elm Grove',),
#  ('Ermine',),
#  ('Eros',),
#  ('Eufaula',),
#  ('Eustis',),
#  ('Everton',),
#  ('Farmington',),
#  ('Firebrick',),
#  ('Forest',),
#  ('Forest Lakes',),
#  ('Frankfort Heights',),
#  ('Franklin',),
#  ('Gales Ferry',),
#  ('Garden City',),
#  ('Garland',),
#  ('Glen Carbon',),
#  ('Glencoe',),
#  ('Grand Terrace',),
#  ('Grandville',),
#  ('Grapevine',),
#  ('Grayslake',),
#  ('Greens Fork',),
#  ('Greenview',),
#  ('Grosse Pointe',),
#  ('Gustine',),
#  ('Hackleburg',),
#  ('Hampden',),
#  ('Hanscom Afb',),
#  ('Harmony',),
#  ('Hayfork',),
#  ('Hayneville',),
#  ('Henderson',),
#  ('Heyburn',),
#  ('Holbrook',),
#  ('Hope',),
#  ('Howard Lake',),
#  ('Jolon',),
#  ('Julian',),
#  ('Kanorado',),
#  ('Kenner',),
#  ('Keyes',),
#  ('Kirkland',),
#  ('Kirksville',),
#  ('Kismet',),
#  ('Kissee Mills',),
#  ('Larkspur',),
#  ('Leavenworth',),
#  ('Ledyard',),
#  ('Lismore',),
#  ('Little Rock',),
#  ('Loma Mar',),
#  ('Lottie',),
#  ('Ludington',),
#  ('Ludlow',),
#  ('Lupton',),
#  ('Lynnville',),
#  ('Macy',),
#  ('Magnolia',),
#  ('Manchester',),
#  ('Many',),
#  ('Marine On Saint Croix',),
#  ('Marion Junction',),
#  ('Mc Henry',),
#  ('Mcbrides',),
#  ('Mccomb',),
#  ('Melber',),
#  ('Mesick',),
#  ('Millville',),
#  ('Mineral Point',),
#  ('Monroe',),
#  ('Montgomery City',),
#  ('Montrose',),
#  ('Morenci',),
#  ('Mosca',),
#  ('Mullan',),
#  ('Napoleon',),
#  ('Neon',),
#  ('New Ross',),
#  ('Newton Center',),
#  ('Norphlet',),
#  ('Norris',),
#  ('North Berwick',),
#  ('North Monmouth',),
#  ('Norvell',),
#  ('Norwood',),
#  ('Oakfield',),
#  ('Oconee',),
#  ('Onaway',),
#  ('Orange Park',),
#  ('Osage City',),
#  ('Ottertail',),
#  ('Palatka',),
#  ('Palm Desert',),
#  ('Paron',),
#  ('Pattonsburg',),
#  ('Peachtree City',),
#  ('Pheba',),
#  ('Philipsburg',),
#  ('Pico Rivera',),
#  ('Pine Bluff',),
#  ('Pine City',),
#  ('Pleasant Grove',),
#  ('Pony',),
#  ('Prairie Du Rocher',),
#  ('Prince Frederick',),
#  ('Randall',),
#  ('Rantoul',),
#  ('Raymondville',),
#  ('Regina',),
#  ('Richland',),
#  ('Robertsdale',),
#  ('Rocheport',),
#  ('Rockton',),
#  ('Rogers',),
#  ('Round Pond',),
#  ('Roy',),
#  ('Rumsey',),
#  ('Rydal',),
#  ('Saint Paul',),
#  ('Saint Petersburg',),
#  ('Salem',),
#  ('Schleswig',),
#  ('Seward',),
#  ('Sherrill',),
#  ('Shreveport',),
#  ('Siler',),
#  ('Sizerock',),
#  ('Skanee',),
#  ('South Britain',),
#  ('South Haven',),
#  ('Southport',),
#  ('Sturdivant',),
#  ('Tarzana',),
#  ('Tipton',),
#  ('Turners Falls',),
#  ('Ukiah',),
#  ('Vulcan',),
#  ('Walnut',),
#  ('Watkins',),
#  ('West Baden Springs',),
#  ('West Hills',),
#  ('White Horse Beach',),
#  ('Wickliffe',),
#  ('Winter Park',),
#  ('Yazoo City',),
#  ('Yellow Pine',),
#  ('Yuma',),
#  ('Zachary',)]

# %% [markdown]
# ## Problem 03: Find the difference between the total number of CITY entries in the table and the number of distinct CITY entries in the table

# %%
# %%sql
#
# SELECT COUNT(CITY) - COUNT(DISTINCT(CITY)) AS Difference
# FROM station;
# Out:
#  * sqlite:///Problem_set_02.db
# Done.
# [(2211,)]

# %% [markdown]
# ## Problem 04: Query the two cities in STATION with the shortest and longest CITY names, as well as their respective lengths (i.e.: number of characters in the name). If there is more than one smallest or largest city, choose the one that comes first when ordered alphabetically.

# %%
# %%sql
#
# SELECT CITY, MIN(LENGTH(CITY)) AS Shortest_and_Longest
# FROM station
# UNION ALL
# SELECT CITY, MAX(LENGTH(CITY)) Shortest_Longest
# FROM station
# ORDER BY Shortest_Longest
# LIMIT 2;
# Out:
#  * sqlite:///Problem_set_02.db
# Done.
# [('Roy', 3), ('Marine On Saint Croix', 21)]

# %% [markdown]
# ## Problem 05: Query the list of CITY names starting with vowels (i.e., a, e, i, o, or u) from STATION. Your result cannot contain duplicates

# %%
# %%sql
#
# SELECT DISTINCT(city)
# FROM station
# WHERE LOWER(CITY) LIKE 'a%' or LOWER(CITY) LIKE 'e%' or LOWER(CITY) LIKE 'i%' or LOWER(CITY) LIKE 'o%'or LOWER(CITY) LIKE 'u%';
# Out:
#  * sqlite:///Problem_set_02.db
# Done.
# [('Arlington',),
#  ('Albany',),
#  ('Upperco',),
#  ('Aguanga',),
#  ('Odin',),
#  ('East China',),
#  ('Algonac',),
#  ('Onaway',),
#  ('Irvington',),
#  ('Arrowsmith',),
#  ('Udall',),
#  ('Oakfield',),
#  ('Elkton',),
#  ('East Irvine',),
#  ('Amo',),
#  ('Alanson',),
#  ('Eleele',),
#  ('Auburn',),
#  ('Oconee',),
#  ('Amazonia',),
#  ('Aliso Viejo',),
#  ('Andersonville',),
#  ('Eros',),
#  ('Arkadelphia',),
#  ('Eriline',),
#  ('Edgewater',),
#  ('East Haddam',),
#  ('Eastlake',),
#  ('Addison',),
#  ('Everton',),
#  ('Eustis',),
#  ('Arispe',),
#  ('Union Star',),
#  ('Ottertail',),
#  ('Ermine',),
#  ('Albion',),
#  ('Athens',),
#  ('Eufaula',),
#  ('Osage City',),
#  ('Andover',),
#  ('Osborne',),
#  ('Elm Grove',),
#  ('Atlantic Mine',),
#  ('Oshtemo',),
#  ('Archie',),
#  ('Olmitz',),
#  ('Allerton',),
#  ('Equality',),
#  ('Alpine',),
#  ('Ojai',),
#  ('Orange Park',),
#  ('Urbana',),
#  ('Ukiah',),
#  ('Alba',),
#  ('Esmond',),
#  ('Eureka Springs',)]

# %% [markdown]
# ## Problem 06: Query the list of CITY names ending with vowels (a, e, i, o, u) from STATION. Your result cannot contain duplicates

# %%
# %%sql
#
# SELECT DISTINCT(city)
# FROM station
# WHERE LOWER(CITY) LIKE '%a' or LOWER(CITY) LIKE '%e' or LOWER(CITY) LIKE '%i' or LOWER(CITY) LIKE '%o'or LOWER(CITY) LIKE '%u';
# Out:
#  * sqlite:///Problem_set_02.db
# Done.
# [('Glencoe',),
#  ('Chelsea',),
#  ('Pelahatchie',),
#  ('Dorrance',),
#  ('Cahone',),
#  ('Upperco',),
#  ('Waipahu',),
#  ('Millville',),
#  ('Aguanga',),
#  ('Morenci',),
#  ('South El Monte',),
#  ('Gustine',),
#  ('Delano',),
#  ('Westphalia',),
#  ('Saint Elmo',),
#  ('Raymondville',),
#  ('Barrigada',),
#  ('Hesperia',),
#  ('Wickliffe',),
#  ('Milledgeville',),
#  ('East China',),
#  ('Gretna',),
#  ('Zionsville',),
#  ('Rio Oso',),
#  ('Samantha',),
#  ('Bentonville',),
#  ('Grosse Pointe',),
#  ('Robertsdale',),
#  ('Dale',),
#  ('Tennessee',),
#  ('Chokio',),
#  ('Bertha',),
#  ('Regina',),
#  ('Mascotte',),
#  ('Netawaka',),
#  ('East Irvine',),
#  ('Amo',),
#  ('Delta',),
#  ('Jerome',),
#  ('Baton Rouge',),
#  ('Clarkdale',),
#  ('Pheba',),
#  ('Eleele',),
#  ('Oconee',),
#  ('Grandville',),
#  ('Susanville',),
#  ('Rosie',),
#  ('Verona',),
#  ('De Tour Village',),
#  ('West Grove',),
#  ('Bono',),
#  ('Biggsville',),
#  ('Amazonia',),
#  ('Marysville',),
#  ('Cape Girardeau',),
#  ('Crane Lake',),
#  ('Grayslake',),
#  ('Bellevue',),
#  ('Lynnville',),
#  ('Hope',),
#  ('Aliso Viejo',),
#  ('Gowrie',),
#  ('Andersonville',),
#  ('Crouseville',),
#  ('Arkadelphia',),
#  ('Eriline',),
#  ('Howard Lake',),
#  ('Hagatna',),
#  ('Eastlake',),
#  ('Corriganville',),
#  ('Tarzana',),
#  ('Grapevine',),
#  ('Kanorado',),
#  ('Curdsville',),
#  ('Notasulga',),
#  ('Pleasant Grove',),
#  ('Skanee',),
#  ('Springerville',),
#  ('Yellow Pine',),
#  ('Ravenna',),
#  ('Brownsdale',),
#  ('Hayesville',),
#  ('Greenville',),
#  ('Yellville',),
#  ('Weldona',),
#  ('Cascade',),
#  ('Bayville',),
#  ('Arispe',),
#  ('Baileyville',),
#  ('Lakeville',),
#  ('Pico Rivera',),
#  ('Pawnee',),
#  ('Bainbridge',),
#  ('Dupo',),
#  ('Montrose',),
#  ('Ermine',),
#  ('Casco',),
#  ('Madisonville',),
#  ('Lismore',),
#  ('Eufaula',),
#  ('Wildie',),
#  ('Mosca',),
#  ('Lottie',),
#  ('Daleville',),
#  ('Cuba',),
#  ('Renville',),
#  ('Kirksville',),
#  ('Lydia',),
#  ('Monona',),
#  ('Lakota',),
#  ('Grand Terrace',),
#  ('Fort Meade',),
#  ('Hayneville',),
#  ('Losantville',),
#  ('Caseville',),
#  ('Pomona',),
#  ('Hopkinsville',),
#  ('Dixie',),
#  ('Hillside',),
#  ('Osborne',),
#  ('Elm Grove',),
#  ('Atlantic Mine',),
#  ('Honolulu',),
#  ('Oshtemo',),
#  ('Monroe',),
#  ('Archie',),
#  ('Alpine',),
#  ('Ojai',),
#  ('Urbana',),
#  ('Palatka',),
#  ('Yuma',),
#  ('Alba',),
#  ('Waresboro',),
#  ('Magnolia',),
#  ('Dundee',),
#  ('Chilhowee',)]

# %% [markdown]
# ## Problem 07: Query the list of CITY names from STATION which have vowels (i.e., a, e, i, o, and u) as both their first and last characters. Your result cannot contain duplicates.

# %%
# %%sql
#
# SELECT DISTINCT(city)
# FROM station
# WHERE (LOWER(CITY) LIKE 'a%' or LOWER(CITY) LIKE 'e%' or LOWER(CITY) LIKE 'i%' or LOWER(CITY) LIKE 'o%'or LOWER(CITY) LIKE 'u%')
# and
# (LOWER(CITY) LIKE '%a' or LOWER(CITY) LIKE '%e' or LOWER(CITY) LIKE '%i' or LOWER(CITY) LIKE '%o'or LOWER(CITY) LIKE '%u');
# Out:
#  * sqlite:///Problem_set_02.db
# Done.
# [('Upperco',),
#  ('Aguanga',),
#  ('East China',),
#  ('East Irvine',),
#  ('Amo',),
#  ('Eleele',),
#  ('Oconee',),
#  ('Amazonia',),
#  ('Aliso Viejo',),
#  ('Andersonville',),
#  ('Arkadelphia',),
#  ('Eriline',),
#  ('Eastlake',),
#  ('Arispe',),
#  ('Ermine',),
#  ('Eufaula',),
#  ('Osborne',),
#  ('Elm Grove',),
#  ('Atlantic Mine',),
#  ('Oshtemo',),
#  ('Archie',),
#  ('Alpine',),
#  ('Ojai',),
#  ('Urbana',),
#  ('Alba',)]

# %% [markdown]
# ## Problem 08: Query the list of CITY names from STATION that do not start with vowels. Your result cannot contain duplicates.

# %%
# %%sql
#
# SELECT DISTINCT(city)
# FROM station
# WHERE LOWER(CITY) NOT LIKE 'a%' or LOWER(CITY) LIKE 'e%' or LOWER(CITY) LIKE 'i%' or LOWER(CITY) LIKE 'o%'or LOWER(CITY) LIKE 'u%';
# Out:
#  * sqlite:///Problem_set_02.db
# Done.
# [('Kissee Mills',),
#  ('Loma Mar',),
#  ('Sandy Hook',),
#  ('Tipton',),
#  ('Turner',),
#  ('Slidell',),
#  ('Negreet',),
#  ('Glencoe',),
#  ('Chelsea',),
#  ('Chignik Lagoon',),
#  ('Pelahatchie',),
#  ('Hanna City',),
#  ('Dorrance',),
#  ('Monument',),
#  ('Manchester',),
#  ('Prescott',),
#  ('Graettinger',),
#  ('Cahone',),
#  ('Sturgis',),
#  ('Upperco',),
#  ('Highwood',),
#  ('Waipahu',),
#  ('Bowdon',),
#  ('Tyler',),
#  ('Watkins',),
#  ('Republic',),
#  ('Millville',),
#  ('Bowdon Junction',),
#  ('Morenci',),
#  ('South El Monte',),
#  ('Hoskinston',),
#  ('Talbert',),
#  ('Mccomb',),
#  ('Kirk',),
#  ('Carlock',),
#  ('Seward',),
#  ('Gustine',),
#  ('Delano',),
#  ('Westphalia',),
#  ('Saint Elmo',),
#  ('Roy',),
#  ('Pattonsburg',),
#  ('Centertown',),
#  ('Norvell',),
#  ('Raymondville',),
#  ('Beaver Island',),
#  ('Odin',),
#  ('Jemison',),
#  ('West Hills',),
#  ('Barrigada',),
#  ('Hesperia',),
#  ('Wickliffe',),
#  ('Culdesac',),
#  ('Roselawn',),
#  ('Forest Lakes',),
#  ('San Simeon',),
#  ('Little Rock',),
#  ('Portland',),
#  ('New Century',),
#  ('Hampden',),
#  ('Pine City',),
#  ('Sandborn',),
#  ('Seaton',),
#  ('Milledgeville',),
#  ('East China',),
#  ('Prince Frederick',),
#  ('Pomona Park',),
#  ('Gretna',),
#  ('Yazoo City',),
#  ('Zionsville',),
#  ('Rio Oso',),
#  ('Jolon',),
#  ('Childs',),
#  ('Shreveport',),
#  ('Forest',),
#  ('Sizerock',),
#  ('Buffalo Creek',),
#  ('Onaway',),
#  ('Irvington',),
#  ('Winsted',),
#  ('Woodbury',),
#  ('Samantha',),
#  ('Hackleburg',),
#  ('Soldier',),
#  ('Columbus',),
#  ('Bentonville',),
#  ('Kirkland',),
#  ('Grosse Pointe',),
#  ('Wilton',),
#  ('Busby',),
#  ('Robertsdale',),
#  ('Dale',),
#  ('Reeds',),
#  ('Hayfork',),
#  ('Mcbrides',),
#  ('Lee Center',),
#  ('Tennessee',),
#  ('Henderson',),
#  ('Udall',),
#  ('Palm Desert',),
#  ('Benedict',),
#  ('Oakfield',),
#  ('Tamms',),
#  ('Haubstadt',),
#  ('Chokio',),
#  ('Clancy',),
#  ('Scotts Valley',),
#  ('Norwood',),
#  ('Elkton',),
#  ('Bertha',),
#  ('Bridgeport',),
#  ('Cherry',),
#  ('Regina',),
#  ('Griffin',),
#  ('Pine Bluff',),
#  ('Mascotte',),
#  ('Baldwin',),
#  ('Netawaka',),
#  ('East Irvine',),
#  ('Pony',),
#  ('Franklin',),
#  ('Vulcan',),
#  ('Prairie Du Rocher',),
#  ('Delta',),
#  ('Carver',),
#  ('Paron',),
#  ('Winchester',),
#  ('Jerome',),
#  ('Baton Rouge',),
#  ('Greenview',),
#  ('Lucerne Valley',),
#  ('Cromwell',),
#  ('Quinter',),
#  ('Whitewater',),
#  ('Round Pond',),
#  ('Clarkdale',),
#  ('Rockton',),
#  ('Pheba',),
#  ('Eleele',),
#  ('North Berwick',),
#  ('Oconee',),
#  ('Grandville',),
#  ('Susanville',),
#  ('Rosie',),
#  ('Verona',),
#  ('Richland',),
#  ('Fremont',),
#  ('Philipsburg',),
#  ('Kensett',),
#  ('De Tour Village',),
#  ('Koleen',),
#  ('Winslow',),
#  ('Reasnor',),
#  ('West Grove',),
#  ('Frankfort Heights',),
#  ('Bono',),
#  ('Biggsville',),
#  ('Linthicum Heights',),
#  ('Marysville',),
#  ('Cape Girardeau',),
#  ('Pengilly',),
#  ('Newton Center',),
#  ('Crane Lake',),
#  ('Newbury',),
#  ('Kismet',),
#  ('Canton',),
#  ('Clipper Mills',),
#  ('Grayslake',),
#  ('Pierre Part',),
#  ('Bison',),
#  ('Bellevue',),
#  ('Ridgway',),
#  ('South Britain',),
#  ('Rydal',),
#  ('Lynnville',),
#  ('Deerfield',),
#  ('Montreal',),
#  ('Hope',),
#  ('Gowrie',),
#  ('Knob Lick',),
#  ('Crouseville',),
#  ('Cranks',),
#  ('Rives Junction',),
#  ('Ledyard',),
#  ('Norway',),
#  ('Eros',),
#  ('Rantoul',),
#  ('Richmond Hill',),
#  ('Fredericktown',),
#  ('Glen Carbon',),
#  ('Fredericksburg',),
#  ('Mc Henry',),
#  ('Eriline',),
#  ('Wellington',),
#  ('Hoffman Estates',),
#  ('Howard Lake',),
#  ('Edgewater',),
#  ('Ducor',),
#  ('Salem',),
#  ('Sturdivant',),
#  ('Hagatna',),
#  ('East Haddam',),
#  ('Eastlake',),
#  ('Larkspur',),
#  ('Patriot',),
#  ('Corriganville',),
#  ('Carlos',),
#  ('Tarzana',),
#  ('Grapevine',),
#  ('Kanorado',),
#  ('Climax',),
#  ('Curdsville',),
#  ('Southport',),
#  ('Compton',),
#  ('Notasulga',),
#  ('Rumsey',),
#  ('Rogers',),
#  ('Pleasant Grove',),
#  ('Everton',),
#  ('Skanee',),
#  ('Springerville',),
#  ('Libertytown',),
#  ('Church Creek',),
#  ('Yellow Pine',),
#  ('Dumont',),
#  ('Gales Ferry',),
#  ('Ravenna',),
#  ('Williams',),
#  ('Decatur',),
#  ('Holbrook',),
#  ('Sherrill',),
#  ('Brownsdale',),
#  ('Linden',),
#  ('Sedgwick',),
#  ('Fort Atkinson',),
#  ('Peachtree City',),
#  ('Rocheport',),
#  ('West Somerset',),
#  ('Clovis',),
#  ('Heyburn',),
#  ('Peabody',),
#  ('Marion Junction',),
#  ('Randall',),
#  ('Hayesville',),
#  ('Jordan',),
#  ('White Horse Beach',),
#  ('Greenville',),
#  ('Macy',),
#  ('Flowood',),
#  ('Deep River',),
#  ('Napoleon',),
#  ('Leavenworth',),
#  ('Coldwater',),
#  ('Weldon',),
#  ('Yellville',),
#  ('Turners Falls',),
#  ('Delray Beach',),
#  ('Eustis',),
#  ('Mineral Point',),
#  ('Weldona',),
#  ('Midpines',),
#  ('Cascade',),
#  ('Tefft',),
#  ('Showell',),
#  ('Bayville',),
#  ('Brighton',),
#  ('Grimes',),
#  ('Nubieber',),
#  ('North Monmouth',),
#  ('Harmony',),
#  ('Beaufort',),
#  ('Union Star',),
#  ('Humeston',),
#  ('Baileyville',),
#  ('Lakeville',),
#  ('Firebrick',),
#  ('Pico Rivera',),
#  ('Ludington',),
#  ('Channing',),
#  ('West Baden Springs',),
#  ('Pawnee',),
#  ('Melber',),
#  ('Bainbridge',),
#  ('Sanders',),
#  ('Ottertail',),
#  ('Dupo',),
#  ('Montrose',),
#  ('Schleswig',),
#  ('Harbor Springs',),
#  ('Richmond',),
#  ('Ermine',),
#  ('Siler',),
#  ('Reeves',),
#  ('Clifton',),
#  ('Casco',),
#  ('Crescent City',),
#  ('Madisonville',),
#  ('Lismore',),
#  ('Eufaula',),
#  ('Panther Burn',),
#  ('Hanscom Afb',),
#  ('Wildie',),
#  ('Mosca',),
#  ('Bennington',),
#  ('Lottie',),
#  ('Garland',),
#  ('Clutier',),
#  ('Lupton',),
#  ('Northfield',),
#  ('Daleville',),
#  ('Osage City',),
#  ('Cuba',),
#  ('Norris',),
#  ('Clopton',),
#  ('Renville',),
#  ('Saint Paul',),
#  ('Kirksville',),
#  ('Kingsland',),
#  ('Fairview',),
#  ('Lydia',),
#  ('Bridgton',),
#  ('Brownstown',),
#  ('Monona',),
#  ('Hartland',),
#  ('Lakota',),
#  ('Grand Terrace',),
#  ('Mesick',),
#  ('Dryden',),
#  ('Beverly',),
#  ('Marine On Saint Croix',),
#  ('Pocahontas',),
#  ('Fort Meade',),
#  ('Hayneville',),
#  ('Yoder',),
#  ('Gatewood',),
#  ('Madden',),
#  ('Losantville',),
#  ('Cheswold',),
#  ('Caseville',),
#  ('Pomona',),
#  ('Hopkinsville',),
#  ('Jack',),
#  ('Dixie',),
#  ('Hillside',),
#  ('Hawarden',),
#  ('Cannonsburg',),
#  ('Osborne',),
#  ('Elm Grove',),
#  ('North Branford',),
#  ('New Liberty',),
#  ('Woodstock Valley',),
#  ('Farmington',),
#  ('Honolulu',),
#  ('Pfeifer',),
#  ('Oshtemo',),
#  ('Gridley',),
#  ('Fulton',),
#  ('Winter Park',),
#  ('Monroe',),
#  ('Del Mar',),
#  ('Greens Fork',),
#  ('Garden City',),
#  ('Blue River',),
#  ('New Ross',),
#  ('Brilliant',),
#  ('Olmitz',),
#  ('Norphlet',),
#  ('Mechanic Falls',),
#  ('North Middletown',),
#  ('Keyes',),
#  ('Equality',),
#  ('Neon',),
#  ('Calhoun',),
#  ('Mullan',),
#  ('Coalgood',),
#  ('Walnut',),
#  ('Saint Petersburg',),
#  ('Ojai',),
#  ('Julian',),
#  ('Veedersburg',),
#  ('Orange Park',),
#  ('Payson',),
#  ('Windom',),
#  ('Urbana',),
#  ('Ludlow',),
#  ('Lindsay',),
#  ('Palatka',),
#  ('Bristol',),
#  ('Ukiah',),
#  ('Yuma',),
#  ('Zachary',),
#  ('Esmond',),
#  ('Waresboro',),
#  ('Hills',),
#  ('Montgomery City',),
#  ('Delavan',),
#  ('Magnolia',),
#  ('Byron',),
#  ('Dundee',),
#  ('Eureka Springs',),
#  ('Baker',),
#  ('Hyde Park',),
#  ('Groveoak',),
#  ('Kenner',),
#  ('Many',),
#  ('Berryton',),
#  ('Chilhowee',),
#  ('Newark',),
#  ('Cowgill',),
#  ('Novinger',),
#  ('Goodman',),
#  ('Cobalt',),
#  ('South Haven',)]

# %% [markdown]
# ## Problem 09: Query the list of CITY names from STATION that do not end with vowels. Your result cannot contain duplicates.

# %%
# %%sql
#
# SELECT DISTINCT(city)
# FROM station
# WHERE LOWER(CITY) NOT LIKE '%a' or LOWER(CITY) LIKE '%e' or LOWER(CITY) LIKE '%i' or LOWER(CITY) LIKE '%o'or LOWER(CITY) LIKE '%u';
# Out:
#  * sqlite:///Problem_set_02.db
# Done.
# [('Kissee Mills',),
#  ('Loma Mar',),
#  ('Sandy Hook',),
#  ('Tipton',),
#  ('Arlington',),
#  ('Turner',),
#  ('Slidell',),
#  ('Negreet',),
#  ('Glencoe',),
#  ('Chignik Lagoon',),
#  ('Pelahatchie',),
#  ('Hanna City',),
#  ('Dorrance',),
#  ('Albany',),
#  ('Monument',),
#  ('Manchester',),
#  ('Prescott',),
#  ('Graettinger',),
#  ('Cahone',),
#  ('Sturgis',),
#  ('Upperco',),
#  ('Highwood',),
#  ('Waipahu',),
#  ('Bowdon',),
#  ('Tyler',),
#  ('Watkins',),
#  ('Republic',),
#  ('Millville',),
#  ('Bowdon Junction',),
#  ('Morenci',),
#  ('South El Monte',),
#  ('Hoskinston',),
#  ('Talbert',),
#  ('Mccomb',),
#  ('Kirk',),
#  ('Carlock',),
#  ('Seward',),
#  ('Gustine',),
#  ('Delano',),
#  ('Saint Elmo',),
#  ('Roy',),
#  ('Pattonsburg',),
#  ('Centertown',),
#  ('Norvell',),
#  ('Raymondville',),
#  ('Beaver Island',),
#  ('Odin',),
#  ('Jemison',),
#  ('West Hills',),
#  ('Wickliffe',),
#  ('Culdesac',),
#  ('Roselawn',),
#  ('Forest Lakes',),
#  ('San Simeon',),
#  ('Little Rock',),
#  ('Portland',),
#  ('New Century',),
#  ('Hampden',),
#  ('Pine City',),
#  ('Sandborn',),
#  ('Seaton',),
#  ('Milledgeville',),
#  ('Prince Frederick',),
#  ('Pomona Park',),
#  ('Yazoo City',),
#  ('Zionsville',),
#  ('Rio Oso',),
#  ('Jolon',),
#  ('Childs',),
#  ('Shreveport',),
#  ('Forest',),
#  ('Sizerock',),
#  ('Buffalo Creek',),
#  ('Algonac',),
#  ('Onaway',),
#  ('Irvington',),
#  ('Winsted',),
#  ('Woodbury',),
#  ('Hackleburg',),
#  ('Soldier',),
#  ('Arrowsmith',),
#  ('Columbus',),
#  ('Bentonville',),
#  ('Kirkland',),
#  ('Grosse Pointe',),
#  ('Wilton',),
#  ('Busby',),
#  ('Robertsdale',),
#  ('Dale',),
#  ('Reeds',),
#  ('Hayfork',),
#  ('Mcbrides',),
#  ('Lee Center',),
#  ('Tennessee',),
#  ('Henderson',),
#  ('Udall',),
#  ('Palm Desert',),
#  ('Benedict',),
#  ('Oakfield',),
#  ('Tamms',),
#  ('Haubstadt',),
#  ('Chokio',),
#  ('Clancy',),
#  ('Scotts Valley',),
#  ('Norwood',),
#  ('Elkton',),
#  ('Bridgeport',),
#  ('Cherry',),
#  ('Griffin',),
#  ('Pine Bluff',),
#  ('Mascotte',),
#  ('Baldwin',),
#  ('East Irvine',),
#  ('Pony',),
#  ('Franklin',),
#  ('Amo',),
#  ('Vulcan',),
#  ('Prairie Du Rocher',),
#  ('Alanson',),
#  ('Carver',),
#  ('Paron',),
#  ('Winchester',),
#  ('Jerome',),
#  ('Baton Rouge',),
#  ('Greenview',),
#  ('Lucerne Valley',),
#  ('Cromwell',),
#  ('Quinter',),
#  ('Whitewater',),
#  ('Round Pond',),
#  ('Clarkdale',),
#  ('Rockton',),
#  ('Eleele',),
#  ('Auburn',),
#  ('North Berwick',),
#  ('Oconee',),
#  ('Grandville',),
#  ('Susanville',),
#  ('Rosie',),
#  ('Richland',),
#  ('Fremont',),
#  ('Philipsburg',),
#  ('Kensett',),
#  ('De Tour Village',),
#  ('Koleen',),
#  ('Winslow',),
#  ('Reasnor',),
#  ('West Grove',),
#  ('Frankfort Heights',),
#  ('Bono',),
#  ('Biggsville',),
#  ('Linthicum Heights',),
#  ('Marysville',),
#  ('Cape Girardeau',),
#  ('Pengilly',),
#  ('Newton Center',),
#  ('Crane Lake',),
#  ('Newbury',),
#  ('Kismet',),
#  ('Canton',),
#  ('Clipper Mills',),
#  ('Grayslake',),
#  ('Pierre Part',),
#  ('Bison',),
#  ('Bellevue',),
#  ('Ridgway',),
#  ('South Britain',),
#  ('Rydal',),
#  ('Lynnville',),
#  ('Deerfield',),
#  ('Montreal',),
#  ('Hope',),
#  ('Aliso Viejo',),
#  ('Gowrie',),
#  ('Andersonville',),
#  ('Knob Lick',),
#  ('Crouseville',),
#  ('Cranks',),
#  ('Rives Junction',),
#  ('Ledyard',),
#  ('Norway',),
#  ('Eros',),
#  ('Rantoul',),
#  ('Richmond Hill',),
#  ('Fredericktown',),
#  ('Glen Carbon',),
#  ('Fredericksburg',),
#  ('Mc Henry',),
#  ('Eriline',),
#  ('Wellington',),
#  ('Hoffman Estates',),
#  ('Howard Lake',),
#  ('Edgewater',),
#  ('Ducor',),
#  ('Salem',),
#  ('Sturdivant',),
#  ('East Haddam',),
#  ('Eastlake',),
#  ('Larkspur',),
#  ('Patriot',),
#  ('Corriganville',),
#  ('Carlos',),
#  ('Addison',),
#  ('Grapevine',),
#  ('Kanorado',),
#  ('Climax',),
#  ('Curdsville',),
#  ('Southport',),
#  ('Compton',),
#  ('Rumsey',),
#  ('Rogers',),
#  ('Pleasant Grove',),
#  ('Everton',),
#  ('Skanee',),
#  ('Springerville',),
#  ('Libertytown',),
#  ('Church Creek',),
#  ('Yellow Pine',),
#  ('Dumont',),
#  ('Gales Ferry',),
#  ('Williams',),
#  ('Decatur',),
#  ('Holbrook',),
#  ('Sherrill',),
#  ('Brownsdale',),
#  ('Linden',),
#  ('Sedgwick',),
#  ('Fort Atkinson',),
#  ('Peachtree City',),
#  ('Rocheport',),
#  ('West Somerset',),
#  ('Clovis',),
#  ('Heyburn',),
#  ('Peabody',),
#  ('Marion Junction',),
#  ('Randall',),
#  ('Hayesville',),
#  ('Jordan',),
#  ('White Horse Beach',),
#  ('Greenville',),
#  ('Macy',),
#  ('Flowood',),
#  ('Deep River',),
#  ('Napoleon',),
#  ('Leavenworth',),
#  ('Coldwater',),
#  ('Weldon',),
#  ('Yellville',),
#  ('Turners Falls',),
#  ('Delray Beach',),
#  ('Eustis',),
#  ('Mineral Point',),
#  ('Midpines',),
#  ('Cascade',),
#  ('Tefft',),
#  ('Showell',),
#  ('Bayville',),
#  ('Brighton',),
#  ('Grimes',),
#  ('Nubieber',),
#  ('North Monmouth',),
#  ('Harmony',),
#  ('Beaufort',),
#  ('Arispe',),
#  ('Union Star',),
#  ('Humeston',),
#  ('Baileyville',),
#  ('Lakeville',),
#  ('Firebrick',),
#  ('Ludington',),
#  ('Channing',),
#  ('West Baden Springs',),
#  ('Pawnee',),
#  ('Melber',),
#  ('Bainbridge',),
#  ('Sanders',),
#  ('Ottertail',),
#  ('Dupo',),
#  ('Montrose',),
#  ('Schleswig',),
#  ('Harbor Springs',),
#  ('Richmond',),
#  ('Ermine',),
#  ('Siler',),
#  ('Reeves',),
#  ('Clifton',),
#  ('Casco',),
#  ('Crescent City',),
#  ('Madisonville',),
#  ('Albion',),
#  ('Lismore',),
#  ('Athens',),
#  ('Panther Burn',),
#  ('Hanscom Afb',),
#  ('Wildie',),
#  ('Bennington',),
#  ('Lottie',),
#  ('Garland',),
#  ('Clutier',),
#  ('Lupton',),
#  ('Northfield',),
#  ('Daleville',),
#  ('Osage City',),
#  ('Norris',),
#  ('Clopton',),
#  ('Renville',),
#  ('Saint Paul',),
#  ('Kirksville',),
#  ('Kingsland',),
#  ('Fairview',),
#  ('Bridgton',),
#  ('Brownstown',),
#  ('Hartland',),
#  ('Andover',),
#  ('Grand Terrace',),
#  ('Mesick',),
#  ('Dryden',),
#  ('Beverly',),
#  ('Marine On Saint Croix',),
#  ('Pocahontas',),
#  ('Fort Meade',),
#  ('Hayneville',),
#  ('Yoder',),
#  ('Gatewood',),
#  ('Madden',),
#  ('Losantville',),
#  ('Cheswold',),
#  ('Caseville',),
#  ('Hopkinsville',),
#  ('Jack',),
#  ('Dixie',),
#  ('Hillside',),
#  ('Hawarden',),
#  ('Cannonsburg',),
#  ('Osborne',),
#  ('Elm Grove',),
#  ('Atlantic Mine',),
#  ('North Branford',),
#  ('New Liberty',),
#  ('Woodstock Valley',),
#  ('Farmington',),
#  ('Honolulu',),
#  ('Pfeifer',),
#  ('Oshtemo',),
#  ('Gridley',),
#  ('Fulton',),
#  ('Winter Park',),
#  ('Monroe',),
#  ('Del Mar',),
#  ('Greens Fork',),
#  ('Garden City',),
#  ('Blue River',),
#  ('New Ross',),
#  ('Brilliant',),
#  ('Archie',),
#  ('Olmitz',),
#  ('Allerton',),
#  ('Norphlet',),
#  ('Mechanic Falls',),
#  ('North Middletown',),
#  ('Keyes',),
#  ('Equality',),
#  ('Neon',),
#  ('Calhoun',),
#  ('Alpine',),
#  ('Mullan',),
#  ('Coalgood',),
#  ('Walnut',),
#  ('Saint Petersburg',),
#  ('Ojai',),
#  ('Julian',),
#  ('Veedersburg',),
#  ('Orange Park',),
#  ('Payson',),
#  ('Windom',),
#  ('Ludlow',),
#  ('Lindsay',),
#  ('Bristol',),
#  ('Ukiah',),
#  ('Zachary',),
#  ('Esmond',),
#  ('Waresboro',),
#  ('Hills',),
#  ('Montgomery City',),
#  ('Delavan',),
#  ('Byron',),
#  ('Dundee',),
#  ('Eureka Springs',),
#  ('Baker',),
#  ('Hyde Park',),
#  ('Groveoak',),
#  ('Kenner',),
#  ('Many',),
#  ('Berryton',),
#  ('Chilhowee',),
#  ('Newark',),
#  ('Cowgill',),
#  ('Novinger',),
#  ('Goodman',),
#  ('Cobalt',),
#  ('South Haven',)]

# %% [markdown]
# ## Problem 10: Query the list of CITY names from STATION that either do not start with vowels or do not end with vowels. Your result cannot contain duplicates.

# %%
# %%sql
#
# SELECT DISTINCT(city)
# FROM station
# WHERE (LOWER(CITY) NOT LIKE 'a%' or LOWER(CITY) LIKE 'e%' or LOWER(CITY) LIKE 'i%' or LOWER(CITY) LIKE 'o%'or LOWER(CITY) LIKE 'u%')
# OR (LOWER(CITY) NOT LIKE '%a' or LOWER(CITY) LIKE '%e' or LOWER(CITY) LIKE '%i' or LOWER(CITY) LIKE '%o'or LOWER(CITY) LIKE '%u');
# Out:
#  * sqlite:///Problem_set_02.db
# Done.
# [('Kissee Mills',),
#  ('Loma Mar',),
#  ('Sandy Hook',),
#  ('Tipton',),
#  ('Arlington',),
#  ('Turner',),
#  ('Slidell',),
#  ('Negreet',),
#  ('Glencoe',),
#  ('Chelsea',),
#  ('Chignik Lagoon',),
#  ('Pelahatchie',),
#  ('Hanna City',),
#  ('Dorrance',),
#  ('Albany',),
#  ('Monument',),
#  ('Manchester',),
#  ('Prescott',),
#  ('Graettinger',),
#  ('Cahone',),
#  ('Sturgis',),
#  ('Upperco',),
#  ('Highwood',),
#  ('Waipahu',),
#  ('Bowdon',),
#  ('Tyler',),
#  ('Watkins',),
#  ('Republic',),
#  ('Millville',),
#  ('Bowdon Junction',),
#  ('Morenci',),
#  ('South El Monte',),
#  ('Hoskinston',),
#  ('Talbert',),
#  ('Mccomb',),
#  ('Kirk',),
#  ('Carlock',),
#  ('Seward',),
#  ('Gustine',),
#  ('Delano',),
#  ('Westphalia',),
#  ('Saint Elmo',),
#  ('Roy',),
#  ('Pattonsburg',),
#  ('Centertown',),
#  ('Norvell',),
#  ('Raymondville',),
#  ('Beaver Island',),
#  ('Odin',),
#  ('Jemison',),
#  ('West Hills',),
#  ('Barrigada',),
#  ('Hesperia',),
#  ('Wickliffe',),
#  ('Culdesac',),
#  ('Roselawn',),
#  ('Forest Lakes',),
#  ('San Simeon',),
#  ('Little Rock',),
#  ('Portland',),
#  ('New Century',),
#  ('Hampden',),
#  ('Pine City',),
#  ('Sandborn',),
#  ('Seaton',),
#  ('Milledgeville',),
#  ('East China',),
#  ('Prince Frederick',),
#  ('Pomona Park',),
#  ('Gretna',),
#  ('Yazoo City',),
#  ('Zionsville',),
#  ('Rio Oso',),
#  ('Jolon',),
#  ('Childs',),
#  ('Shreveport',),
#  ('Forest',),
#  ('Sizerock',),
#  ('Buffalo Creek',),
#  ('Algonac',),
#  ('Onaway',),
#  ('Irvington',),
#  ('Winsted',),
#  ('Woodbury',),
#  ('Samantha',),
#  ('Hackleburg',),
#  ('Soldier',),
#  ('Arrowsmith',),
#  ('Columbus',),
#  ('Bentonville',),
#  ('Kirkland',),
#  ('Grosse Pointe',),
#  ('Wilton',),
#  ('Busby',),
#  ('Robertsdale',),
#  ('Dale',),
#  ('Reeds',),
#  ('Hayfork',),
#  ('Mcbrides',),
#  ('Lee Center',),
#  ('Tennessee',),
#  ('Henderson',),
#  ('Udall',),
#  ('Palm Desert',),
#  ('Benedict',),
#  ('Oakfield',),
#  ('Tamms',),
#  ('Haubstadt',),
#  ('Chokio',),
#  ('Clancy',),
#  ('Scotts Valley',),
#  ('Norwood',),
#  ('Elkton',),
#  ('Bertha',),
#  ('Bridgeport',),
#  ('Cherry',),
#  ('Regina',),
#  ('Griffin',),
#  ('Pine Bluff',),
#  ('Mascotte',),
#  ('Baldwin',),
#  ('Netawaka',),
#  ('East Irvine',),
#  ('Pony',),
#  ('Franklin',),
#  ('Amo',),
#  ('Vulcan',),
#  ('Prairie Du Rocher',),
#  ('Alanson',),
#  ('Delta',),
#  ('Carver',),
#  ('Paron',),
#  ('Winchester',),
#  ('Jerome',),
#  ('Baton Rouge',),
#  ('Greenview',),
#  ('Lucerne Valley',),
#  ('Cromwell',),
#  ('Quinter',),
#  ('Whitewater',),
#  ('Round Pond',),
#  ('Clarkdale',),
#  ('Rockton',),
#  ('Pheba',),
#  ('Eleele',),
#  ('Auburn',),
#  ('North Berwick',),
#  ('Oconee',),
#  ('Grandville',),
#  ('Susanville',),
#  ('Rosie',),
#  ('Verona',),
#  ('Richland',),
#  ('Fremont',),
#  ('Philipsburg',),
#  ('Kensett',),
#  ('De Tour Village',),
#  ('Koleen',),
#  ('Winslow',),
#  ('Reasnor',),
#  ('West Grove',),
#  ('Frankfort Heights',),
#  ('Bono',),
#  ('Biggsville',),
#  ('Linthicum Heights',),
#  ('Marysville',),
#  ('Cape Girardeau',),
#  ('Pengilly',),
#  ('Newton Center',),
#  ('Crane Lake',),
#  ('Newbury',),
#  ('Kismet',),
#  ('Canton',),
#  ('Clipper Mills',),
#  ('Grayslake',),
#  ('Pierre Part',),
#  ('Bison',),
#  ('Bellevue',),
#  ('Ridgway',),
#  ('South Britain',),
#  ('Rydal',),
#  ('Lynnville',),
#  ('Deerfield',),
#  ('Montreal',),
#  ('Hope',),
#  ('Aliso Viejo',),
#  ('Gowrie',),
#  ('Andersonville',),
#  ('Knob Lick',),
#  ('Crouseville',),
#  ('Cranks',),
#  ('Rives Junction',),
#  ('Ledyard',),
#  ('Norway',),
#  ('Eros',),
#  ('Rantoul',),
#  ('Richmond Hill',),
#  ('Fredericktown',),
#  ('Glen Carbon',),
#  ('Fredericksburg',),
#  ('Mc Henry',),
#  ('Eriline',),
#  ('Wellington',),
#  ('Hoffman Estates',),
#  ('Howard Lake',),
#  ('Edgewater',),
#  ('Ducor',),
#  ('Salem',),
#  ('Sturdivant',),
#  ('Hagatna',),
#  ('East Haddam',),
#  ('Eastlake',),
#  ('Larkspur',),
#  ('Patriot',),
#  ('Corriganville',),
#  ('Carlos',),
#  ('Addison',),
#  ('Tarzana',),
#  ('Grapevine',),
#  ('Kanorado',),
#  ('Climax',),
#  ('Curdsville',),
#  ('Southport',),
#  ('Compton',),
#  ('Notasulga',),
#  ('Rumsey',),
#  ('Rogers',),
#  ('Pleasant Grove',),
#  ('Everton',),
#  ('Skanee',),
#  ('Springerville',),
#  ('Libertytown',),
#  ('Church Creek',),
#  ('Yellow Pine',),
#  ('Dumont',),
#  ('Gales Ferry',),
#  ('Ravenna',),
#  ('Williams',),
#  ('Decatur',),
#  ('Holbrook',),
#  ('Sherrill',),
#  ('Brownsdale',),
#  ('Linden',),
#  ('Sedgwick',),
#  ('Fort Atkinson',),
#  ('Peachtree City',),
#  ('Rocheport',),
#  ('West Somerset',),
#  ('Clovis',),
#  ('Heyburn',),
#  ('Peabody',),
#  ('Marion Junction',),
#  ('Randall',),
#  ('Hayesville',),
#  ('Jordan',),
#  ('White Horse Beach',),
#  ('Greenville',),
#  ('Macy',),
#  ('Flowood',),
#  ('Deep River',),
#  ('Napoleon',),
#  ('Leavenworth',),
#  ('Coldwater',),
#  ('Weldon',),
#  ('Yellville',),
#  ('Turners Falls',),
#  ('Delray Beach',),
#  ('Eustis',),
#  ('Mineral Point',),
#  ('Weldona',),
#  ('Midpines',),
#  ('Cascade',),
#  ('Tefft',),
#  ('Showell',),
#  ('Bayville',),
#  ('Brighton',),
#  ('Grimes',),
#  ('Nubieber',),
#  ('North Monmouth',),
#  ('Harmony',),
#  ('Beaufort',),
#  ('Arispe',),
#  ('Union Star',),
#  ('Humeston',),
#  ('Baileyville',),
#  ('Lakeville',),
#  ('Firebrick',),
#  ('Pico Rivera',),
#  ('Ludington',),
#  ('Channing',),
#  ('West Baden Springs',),
#  ('Pawnee',),
#  ('Melber',),
#  ('Bainbridge',),
#  ('Sanders',),
#  ('Ottertail',),
#  ('Dupo',),
#  ('Montrose',),
#  ('Schleswig',),
#  ('Harbor Springs',),
#  ('Richmond',),
#  ('Ermine',),
#  ('Siler',),
#  ('Reeves',),
#  ('Clifton',),
#  ('Casco',),
#  ('Crescent City',),
#  ('Madisonville',),
#  ('Albion',),
#  ('Lismore',),
#  ('Athens',),
#  ('Eufaula',),
#  ('Panther Burn',),
#  ('Hanscom Afb',),
#  ('Wildie',),
#  ('Mosca',),
#  ('Bennington',),
#  ('Lottie',),
#  ('Garland',),
#  ('Clutier',),
#  ('Lupton',),
#  ('Northfield',),
#  ('Daleville',),
#  ('Osage City',),
#  ('Cuba',),
#  ('Norris',),
#  ('Clopton',),
#  ('Renville',),
#  ('Saint Paul',),
#  ('Kirksville',),
#  ('Kingsland',),
#  ('Fairview',),
#  ('Lydia',),
#  ('Bridgton',),
#  ('Brownstown',),
#  ('Monona',),
#  ('Hartland',),
#  ('Andover',),
#  ('Lakota',),
#  ('Grand Terrace',),
#  ('Mesick',),
#  ('Dryden',),
#  ('Beverly',),
#  ('Marine On Saint Croix',),
#  ('Pocahontas',),
#  ('Fort Meade',),
#  ('Hayneville',),
#  ('Yoder',),
#  ('Gatewood',),
#  ('Madden',),
#  ('Losantville',),
#  ('Cheswold',),
#  ('Caseville',),
#  ('Pomona',),
#  ('Hopkinsville',),
#  ('Jack',),
#  ('Dixie',),
#  ('Hillside',),
#  ('Hawarden',),
#  ('Cannonsburg',),
#  ('Osborne',),
#  ('Elm Grove',),
#  ('Atlantic Mine',),
#  ('North Branford',),
#  ('New Liberty',),
#  ('Woodstock Valley',),
#  ('Farmington',),
#  ('Honolulu',),
#  ('Pfeifer',),
#  ('Oshtemo',),
#  ('Gridley',),
#  ('Fulton',),
#  ('Winter Park',),
#  ('Monroe',),
#  ('Del Mar',),
#  ('Greens Fork',),
#  ('Garden City',),
#  ('Blue River',),
#  ('New Ross',),
#  ('Brilliant',),
#  ('Archie',),
#  ('Olmitz',),
#  ('Allerton',),
#  ('Norphlet',),
#  ('Mechanic Falls',),
#  ('North Middletown',),
#  ('Keyes',),
#  ('Equality',),
#  ('Neon',),
#  ('Calhoun',),
#  ('Alpine',),
#  ('Mullan',),
#  ('Coalgood',),
#  ('Walnut',),
#  ('Saint Petersburg',),
#  ('Ojai',),
#  ('Julian',),
#  ('Veedersburg',),
#  ('Orange Park',),
#  ('Payson',),
#  ('Windom',),
#  ('Urbana',),
#  ('Ludlow',),
#  ('Lindsay',),
#  ('Palatka',),
#  ('Bristol',),
#  ('Ukiah',),
#  ('Yuma',),
#  ('Zachary',),
#  ('Esmond',),
#  ('Waresboro',),
#  ('Hills',),
#  ('Montgomery City',),
#  ('Delavan',),
#  ('Magnolia',),
#  ('Byron',),
#  ('Dundee',),
#  ('Eureka Springs',),
#  ('Baker',),
#  ('Hyde Park',),
#  ('Groveoak',),
#  ('Kenner',),
#  ('Many',),
#  ('Berryton',),
#  ('Chilhowee',),
#  ('Newark',),
#  ('Cowgill',),
#  ('Novinger',),
#  ('Goodman',),
#  ('Cobalt',),
#  ('South Haven',)]

# %% [markdown]
# ## Problem 11: Query the list of CITY names from STATION that do not start with vowels and do not end with vowels. Your result cannot contain duplicates.

# %%
# %%sql
#
# SELECT DISTINCT(city)
# FROM station
# WHERE (LOWER(CITY) NOT LIKE 'a%' or LOWER(CITY) LIKE 'e%' or LOWER(CITY) LIKE 'i%' or LOWER(CITY) LIKE 'o%'or LOWER(CITY) LIKE 'u%')
# AND (LOWER(CITY) NOT LIKE '%a' or LOWER(CITY) LIKE '%e' or LOWER(CITY) LIKE '%i' or LOWER(CITY) LIKE '%o'or LOWER(CITY) LIKE '%u');
# Out:
#  * sqlite:///Problem_set_02.db
# Done.
# [('Kissee Mills',),
#  ('Loma Mar',),
#  ('Sandy Hook',),
#  ('Tipton',),
#  ('Turner',),
#  ('Slidell',),
#  ('Negreet',),
#  ('Glencoe',),
#  ('Chignik Lagoon',),
#  ('Pelahatchie',),
#  ('Hanna City',),
#  ('Dorrance',),
#  ('Monument',),
#  ('Manchester',),
#  ('Prescott',),
#  ('Graettinger',),
#  ('Cahone',),
#  ('Sturgis',),
#  ('Upperco',),
#  ('Highwood',),
#  ('Waipahu',),
#  ('Bowdon',),
#  ('Tyler',),
#  ('Watkins',),
#  ('Republic',),
#  ('Millville',),
#  ('Bowdon Junction',),
#  ('Morenci',),
#  ('South El Monte',),
#  ('Hoskinston',),
#  ('Talbert',),
#  ('Mccomb',),
#  ('Kirk',),
#  ('Carlock',),
#  ('Seward',),
#  ('Gustine',),
#  ('Delano',),
#  ('Saint Elmo',),
#  ('Roy',),
#  ('Pattonsburg',),
#  ('Centertown',),
#  ('Norvell',),
#  ('Raymondville',),
#  ('Beaver Island',),
#  ('Odin',),
#  ('Jemison',),
#  ('West Hills',),
#  ('Wickliffe',),
#  ('Culdesac',),
#  ('Roselawn',),
#  ('Forest Lakes',),
#  ('San Simeon',),
#  ('Little Rock',),
#  ('Portland',),
#  ('New Century',),
#  ('Hampden',),
#  ('Pine City',),
#  ('Sandborn',),
#  ('Seaton',),
#  ('Milledgeville',),
#  ('Prince Frederick',),
#  ('Pomona Park',),
#  ('Yazoo City',),
#  ('Zionsville',),
#  ('Rio Oso',),
#  ('Jolon',),
#  ('Childs',),
#  ('Shreveport',),
#  ('Forest',),
#  ('Sizerock',),
#  ('Buffalo Creek',),
#  ('Onaway',),
#  ('Irvington',),
#  ('Winsted',),
#  ('Woodbury',),
#  ('Hackleburg',),
#  ('Soldier',),
#  ('Columbus',),
#  ('Bentonville',),
#  ('Kirkland',),
#  ('Grosse Pointe',),
#  ('Wilton',),
#  ('Busby',),
#  ('Robertsdale',),
#  ('Dale',),
#  ('Reeds',),
#  ('Hayfork',),
#  ('Mcbrides',),
#  ('Lee Center',),
#  ('Tennessee',),
#  ('Henderson',),
#  ('Udall',),
#  ('Palm Desert',),
#  ('Benedict',),
#  ('Oakfield',),
#  ('Tamms',),
#  ('Haubstadt',),
#  ('Chokio',),
#  ('Clancy',),
#  ('Scotts Valley',),
#  ('Norwood',),
#  ('Elkton',),
#  ('Bridgeport',),
#  ('Cherry',),
#  ('Griffin',),
#  ('Pine Bluff',),
#  ('Mascotte',),
#  ('Baldwin',),
#  ('East Irvine',),
#  ('Pony',),
#  ('Franklin',),
#  ('Vulcan',),
#  ('Prairie Du Rocher',),
#  ('Carver',),
#  ('Paron',),
#  ('Winchester',),
#  ('Jerome',),
#  ('Baton Rouge',),
#  ('Greenview',),
#  ('Lucerne Valley',),
#  ('Cromwell',),
#  ('Quinter',),
#  ('Whitewater',),
#  ('Round Pond',),
#  ('Clarkdale',),
#  ('Rockton',),
#  ('Eleele',),
#  ('North Berwick',),
#  ('Oconee',),
#  ('Grandville',),
#  ('Susanville',),
#  ('Rosie',),
#  ('Richland',),
#  ('Fremont',),
#  ('Philipsburg',),
#  ('Kensett',),
#  ('De Tour Village',),
#  ('Koleen',),
#  ('Winslow',),
#  ('Reasnor',),
#  ('West Grove',),
#  ('Frankfort Heights',),
#  ('Bono',),
#  ('Biggsville',),
#  ('Linthicum Heights',),
#  ('Marysville',),
#  ('Cape Girardeau',),
#  ('Pengilly',),
#  ('Newton Center',),
#  ('Crane Lake',),
#  ('Newbury',),
#  ('Kismet',),
#  ('Canton',),
#  ('Clipper Mills',),
#  ('Grayslake',),
#  ('Pierre Part',),
#  ('Bison',),
#  ('Bellevue',),
#  ('Ridgway',),
#  ('South Britain',),
#  ('Rydal',),
#  ('Lynnville',),
#  ('Deerfield',),
#  ('Montreal',),
#  ('Hope',),
#  ('Gowrie',),
#  ('Knob Lick',),
#  ('Crouseville',),
#  ('Cranks',),
#  ('Rives Junction',),
#  ('Ledyard',),
#  ('Norway',),
#  ('Eros',),
#  ('Rantoul',),
#  ('Richmond Hill',),
#  ('Fredericktown',),
#  ('Glen Carbon',),
#  ('Fredericksburg',),
#  ('Mc Henry',),
#  ('Eriline',),
#  ('Wellington',),
#  ('Hoffman Estates',),
#  ('Howard Lake',),
#  ('Edgewater',),
#  ('Ducor',),
#  ('Salem',),
#  ('Sturdivant',),
#  ('East Haddam',),
#  ('Eastlake',),
#  ('Larkspur',),
#  ('Patriot',),
#  ('Corriganville',),
#  ('Carlos',),
#  ('Grapevine',),
#  ('Kanorado',),
#  ('Climax',),
#  ('Curdsville',),
#  ('Southport',),
#  ('Compton',),
#  ('Rumsey',),
#  ('Rogers',),
#  ('Pleasant Grove',),
#  ('Everton',),
#  ('Skanee',),
#  ('Springerville',),
#  ('Libertytown',),
#  ('Church Creek',),
#  ('Yellow Pine',),
#  ('Dumont',),
#  ('Gales Ferry',),
#  ('Williams',),
#  ('Decatur',),
#  ('Holbrook',),
#  ('Sherrill',),
#  ('Brownsdale',),
#  ('Linden',),
#  ('Sedgwick',),
#  ('Fort Atkinson',),
#  ('Peachtree City',),
#  ('Rocheport',),
#  ('West Somerset',),
#  ('Clovis',),
#  ('Heyburn',),
#  ('Peabody',),
#  ('Marion Junction',),
#  ('Randall',),
#  ('Hayesville',),
#  ('Jordan',),
#  ('White Horse Beach',),
#  ('Greenville',),
#  ('Macy',),
#  ('Flowood',),
#  ('Deep River',),
#  ('Napoleon',),
#  ('Leavenworth',),
#  ('Coldwater',),
#  ('Weldon',),
#  ('Yellville',),
#  ('Turners Falls',),
#  ('Delray Beach',),
#  ('Eustis',),
#  ('Mineral Point',),
#  ('Midpines',),
#  ('Cascade',),
#  ('Tefft',),
#  ('Showell',),
#  ('Bayville',),
#  ('Brighton',),
#  ('Grimes',),
#  ('Nubieber',),
#  ('North Monmouth',),
#  ('Harmony',),
#  ('Beaufort',),
#  ('Union Star',),
#  ('Humeston',),
#  ('Baileyville',),
#  ('Lakeville',),
#  ('Firebrick',),
#  ('Ludington',),
#  ('Channing',),
#  ('West Baden Springs',),
#  ('Pawnee',),
#  ('Melber',),
#  ('Bainbridge',),
#  ('Sanders',),
#  ('Ottertail',),
#  ('Dupo',),
#  ('Montrose',),
#  ('Schleswig',),
#  ('Harbor Springs',),
#  ('Richmond',),
#  ('Ermine',),
#  ('Siler',),
#  ('Reeves',),
#  ('Clifton',),
#  ('Casco',),
#  ('Crescent City',),
#  ('Madisonville',),
#  ('Lismore',),
#  ('Panther Burn',),
#  ('Hanscom Afb',),
#  ('Wildie',),
#  ('Bennington',),
#  ('Lottie',),
#  ('Garland',),
#  ('Clutier',),
#  ('Lupton',),
#  ('Northfield',),
#  ('Daleville',),
#  ('Osage City',),
#  ('Norris',),
#  ('Clopton',),
#  ('Renville',),
#  ('Saint Paul',),
#  ('Kirksville',),
#  ('Kingsland',),
#  ('Fairview',),
#  ('Bridgton',),
#  ('Brownstown',),
#  ('Hartland',),
#  ('Grand Terrace',),
#  ('Mesick',),
#  ('Dryden',),
#  ('Beverly',),
#  ('Marine On Saint Croix',),
#  ('Pocahontas',),
#  ('Fort Meade',),
#  ('Hayneville',),
#  ('Yoder',),
#  ('Gatewood',),
#  ('Madden',),
#  ('Losantville',),
#  ('Cheswold',),
#  ('Caseville',),
#  ('Hopkinsville',),
#  ('Jack',),
#  ('Dixie',),
#  ('Hillside',),
#  ('Hawarden',),
#  ('Cannonsburg',),
#  ('Osborne',),
#  ('Elm Grove',),
#  ('North Branford',),
#  ('New Liberty',),
#  ('Woodstock Valley',),
#  ('Farmington',),
#  ('Honolulu',),
#  ('Pfeifer',),
#  ('Oshtemo',),
#  ('Gridley',),
#  ('Fulton',),
#  ('Winter Park',),
#  ('Monroe',),
#  ('Del Mar',),
#  ('Greens Fork',),
#  ('Garden City',),
#  ('Blue River',),
#  ('New Ross',),
#  ('Brilliant',),
#  ('Olmitz',),
#  ('Norphlet',),
#  ('Mechanic Falls',),
#  ('North Middletown',),
#  ('Keyes',),
#  ('Equality',),
#  ('Neon',),
#  ('Calhoun',),
#  ('Mullan',),
#  ('Coalgood',),
#  ('Walnut',),
#  ('Saint Petersburg',),
#  ('Ojai',),
#  ('Julian',),
#  ('Veedersburg',),
#  ('Orange Park',),
#  ('Payson',),
#  ('Windom',),
#  ('Ludlow',),
#  ('Lindsay',),
#  ('Bristol',),
#  ('Ukiah',),
#  ('Zachary',),
#  ('Esmond',),
#  ('Waresboro',),
#  ('Hills',),
#  ('Montgomery City',),
#  ('Delavan',),
#  ('Byron',),
#  ('Dundee',),
#  ('Eureka Springs',),
#  ('Baker',),
#  ('Hyde Park',),
#  ('Groveoak',),
#  ('Kenner',),
#  ('Many',),
#  ('Berryton',),
#  ('Chilhowee',),
#  ('Newark',),
#  ('Cowgill',),
#  ('Novinger',),
#  ('Goodman',),
#  ('Cobalt',),
#  ('South Haven',)]
